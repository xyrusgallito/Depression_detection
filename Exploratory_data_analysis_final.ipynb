# %%
#reading the xlsx file that contains the SDS result in the participants

import pandas as pd
gen_dir = "/Users/xaichotic/Library/CloudStorage/OneDrive-NorthumbriaUniversity-ProductionAzureAD/Term3/"

path = gen_dir + "Data_EDA/vn5nknh3mn-2/"

# read the Excel file
scale_file = pd.ExcelFile(path + 'scale.xlsx')
print(scale_file.sheet_names)

#reading SDS sheet only 
sds_df = pd.read_excel(scale_file, sheet_name='SDS')

sds_df
# Out:
# ['Readme', 'ERQ', 'SDS', 'POMS', 'PSQI', 'CESAF']
#     ID     Sex  Age (years)    Complete                Date  \
# 0    1  Female           24    Finished  2018/4/13 16:53:06
# 1    2  Female           23    Finished   2018/4/17 9:34:22
# 2    3  Female           21    Finished   2018/4/17 9:46:14
# 3    4  Female           28    Finished  2018/4/17 12:09:17
# 4    5  Female           25    Finished  2018/4/17 17:00:57
# 5    6  Female           25    Finished  2018/4/17 21:17:32
# 6    7  Female           25    Finished  2018/4/18 11:57:31
# 7    8    Male           22    Finished  2018/4/18 18:30:54
# 8    9  Female           26    Finished  2018/4/20 23:10:44
# 9   10  Female           25    Finished  2018/4/19 22:32:46
# 10  11  Female           24    Finished  2018/4/19 22:31:22
# 11  12    Male           22    Finished  2018/4/20 12:26:02
# 12  13    Male           25    Finished  2018/4/20 21:23:37
# 13  14    Male           23    Finished  2018/4/22 16:04:52
# ...

# %%
#checking for missing values
sds_missing = sds_df.isnull().sum()

#creating a table with missing value counts
sds_missing_table = pd.DataFrame({'Missing Values': sds_missing})
sds_missing_table.index.name = 'Column'
sds_missing_table.sort_values('Missing Values', ascending=False, inplace=True)

#displaying the table
display(sds_missing_table.style.set_caption('Number of missing values per column'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_04e3c">
#   <caption>Number of missing values per column</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04e3c_level0_col0" class="col_heading level0 col0" >Missing Values</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Column</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04e3c_level0_row0" class="row_heading level0 row0" >9. My heart beats faster than usual.</th>
#       <td id="T_04e3c_row0_col0" class="data row0 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_04e3c_level0_row1" class="row_heading level0 row1" >10. I get tired for no reason.</th>
#       <td id="T_04e3c_row1_col0" class="data row1 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_04e3c_level0_row2" class="row_heading level0 row2" >20. I still enjoy the things I used to do.</th>
# ...

# %%
#checking for missing values
print(sds_df.isnull().sum())

for col in sds_df.columns:
    null_rows = sds_df[sds_df[col].isnull()].index.tolist()
    if null_rows:
        print(f"Missing values in {col} column belong to IDs: {null_rows}")
    else:
        print(f"No missing values in {col} column")
# Out:
# ID                                                                                 0
# Sex                                                                                0
# Age (years)                                                                        0
# Complete                                                                           0
# Date                                                                               1
# 1. I feel down-hearted and blue.                                                   1
# 2. Morning is when I feel the best.                                                1
# 3. I have crying spells or feel like it.                                           1
# 4. I have trouble sleeping at night.                                               1
# 5. I eat as much as I used to.                                                     1
# 6. I still enjoy sex.                                                              1
# ...

# %%
#dropping rows with missing values
sds_df2 = sds_df.dropna()

#checking if there are any missing values left
print(sds_df2.isnull().sum())
# Out:
# ID                                                                                 0
# Sex                                                                                0
# Age (years)                                                                        0
# Complete                                                                           0
# Date                                                                               0
# 1. I feel down-hearted and blue.                                                   0
# 2. Morning is when I feel the best.                                                0
# 3. I have crying spells or feel like it.                                           0
# 4. I have trouble sleeping at night.                                               0
# 5. I eat as much as I used to.                                                     0
# 6. I still enjoy sex.                                                              0
# ...

# %%
#renaming columns

sds_df3 = sds_df2.rename(columns={'Age (years)': 'Age', 
                          '1. I feel down-hearted and blue.' : 'Q1' , 
                          '2. Morning is when I feel the best.': 'Q2', 
                          '3. I have crying spells or feel like it.': 'Q3', 
                          '4. I have trouble sleeping at night.': 'Q4',
                          '5. I eat as much as I used to.': 'Q5', 
                          '6. I still enjoy sex.': 'Q6',
                          '7. I notice that I am losing weight.': 'Q7',
                          '8. I have trouble with constipation.': 'Q8',
                          '9. My heart beats faster than usual.': 'Q9',
                          '10. I get tired for no reason.': 'Q10',
                          '11. My mind is as clear as it used to be.': 'Q11',
                          '12. I find it easy to do the things I used to.': 'Q12',
                          '13. I am restless and can’t keep still.': 'Q13',
                          '14. I feel hopeful about the future.': 'Q14',
                          '15. I am more irritable than usual.': 'Q15',
                          '16. I find it easy to make decisions.': 'Q16',
                          '17. I feel that I am useful and needed.': 'Q17',
                          '18. My life is pretty full.': 'Q18',
                          '19. I feel that others would be better off if I were dead.': 'Q19',
                          '20. I still enjoy the things I used to do.': 'Q20',
                          'SDS Score (score * 1.25) (2, 5, 6, 11, 12, 14, 16, 17, 18, and 20 are reversed)':
                        'SDS_score_orig'})

# %%
#creating a dataframe of column names
cols_df = pd.DataFrame({'Original Columns': sds_df2.columns})

#creating a dataframe of column names
cols_df2 = pd.DataFrame({'Renamed Columns': sds_df3.columns})

#combining the dataframes by index
combined_df = pd.concat([cols_df, cols_df2], axis=1)

#combined dataframe
print(combined_df)
# Out:
#                                      Original Columns Renamed Columns
# 0                                                  ID              ID
# 1                                                 Sex             Sex
# 2                                         Age (years)             Age
# 3                                            Complete        Complete
# 4                                                Date            Date
# 5                    1. I feel down-hearted and blue.              Q1
# 6                 2. Morning is when I feel the best.              Q2
# 7            3. I have crying spells or feel like it.              Q3
# 8                4. I have trouble sleeping at night.              Q4
# 9                      5. I eat as much as I used to.              Q5
# 10                              6. I still enjoy sex.              Q6
# 11               7. I notice that I am losing weight.              Q7
# ...

# %%
#setting condition
condition = (sds_df3['SDS_score_orig'] >= 50)

#creating new column "Category"
sds_df3['Category'] = np.where(condition, 1, 0)

# %%
#displaying the data type of each column
print(sds_df3.dtypes)

#Changing the data types to categorical for 'Sex' and 'Category' columns
sds_df3['Sex'] = sds_df3['Sex'].astype('category')
sds_df3['Category'] = sds_df3['Category'].astype('category')

print(sds_df3.dtypes)
# Out:
# ID                  int64
# Sex                object
# Age                 int64
# Complete           object
# Date               object
# Q1                float64
# Q2                float64
# Q3                float64
# Q4                float64
# Q5                float64
# Q6                float64
# Q7                float64
# Q8                float64
# Q9                float64
# Q10               float64
# Q11               float64
# Q12               float64
# Q13               float64
# Q14               float64
# Q15               float64
# Q16               float64
# Q17               float64
# Q18               float64
# Q19               float64
# Q20               float64
# SDS_score_orig    float64
# Category            int64
# dtype: object
# ID                   int64
# Sex               category
# Age                  int64
# Complete            object
# Date                object
# Q1                 float64
# Q2                 float64
# ...

# %%
# sds_df3

# %%
#changing the data type of "Category" column to categorical
sds_df3['Category'] = sds_df3['Category'].astype('category')

#calculating the frequency of the "Category" column
category_freq = sds_df3['Category'].value_counts()

# plot the frequency as a bar chart with a title
plt.bar(category_freq.index, category_freq.values)
plt.title("Frequency Distribution of Category",fontsize=15)
plt.xlabel("Category")
plt.ylabel("Frequency")

#adding text labels on top of each bar showing the total count
for i, v in enumerate(category_freq.values):
    plt.text(i, v, str(v), ha='center')
    
#setting the labels of the x-axis to HC and DS
plt.xticks([0, 1], ['HC', 'DS'])
plt.show()

# %%
# sds_df3

# %%
sds_df3.describe(include = "all")
# Out:
#                ID     Sex        Age  Complete                Date         Q1  \
# count   88.000000      88  88.000000        88                  88  88.000000
# unique        NaN       2        NaN         1                  88        NaN
# top           NaN  Female        NaN  Finished  2018/4/13 16:53:06        NaN
# freq          NaN      57        NaN        88                   1        NaN
# mean    45.068182     NaN  23.693182       NaN                 NaN   1.806818
# std     25.976026     NaN   2.135405       NaN                 NaN   0.522108
# min      1.000000     NaN  18.000000       NaN                 NaN   1.000000
# 25%     22.750000     NaN  22.000000       NaN                 NaN   1.750000
# 50%     45.500000     NaN  24.000000       NaN                 NaN   2.000000
# 75%     67.250000     NaN  25.000000       NaN                 NaN   2.000000
# max     89.000000     NaN  31.000000       NaN                 NaN   3.000000
#
# ...

# %%
#counting the values of the Gender variable
sds_df3_counts = sds_df3['Sex'].value_counts()

#plotting as bar chart
plt.bar(sds_df3_counts.index, sds_df3_counts.values)
plt.xlabel('Sex')
plt.ylabel('Frequency')

#adding counts on top of the bars
for i, v in enumerate(sds_df3_counts.values):
    plt.text(i, v+1, str(v), horizontalalignment='center')

#setting xticks with values of the gender variable
plt.xticks(range(len(sds_df3_counts.index)), sds_df3_counts.index)
plt.title('Frequency Distribution of Sex',fontsize=15)
plt.figure(figsize=(10,5))
plt.show()

# %%
sds_df3['Sex'].dtype
# Out:
# CategoricalDtype(categories=['Female', 'Male'], ordered=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#creating a grouped bar plot
sns.catplot(x='Sex', hue='Category', kind='count', data=sds_df3)

#adding labels and title
plt.xlabel('Sex')
plt.ylabel('Count')
plt.title('Frequency Distribution of Sex and Category',fontsize=15)

#displaying the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#creating a countplot
sns.countplot(x='Sex', hue='Category', data=sds_df3)

#adding total count of each category on top of the bars
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), 
            int(p.get_height()), 
            fontsize=12, color='black', ha='center', va='bottom')

#setting xtick labels
ax.set_xticklabels(['Female', 'Male'])
plt.xlabel('Sex')
plt.ylabel('Count')
plt.title('Frequency Distribution of Sex and Category', fontsize=15)

#setting the legend
plt.legend(title='Category', labels=['Healthy Controls', 'Depressed Subjects'])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#creating a violin plot
sns.violinplot(x='Category', y='Age', data=sds_df3)

#adding labels and title
plt.xlabel('Category')
plt.ylabel('Age')
plt.title('Age Distribution by Category', fontsize=15)

#changing the x-axis tick labels
plt.gca().set_xticklabels(['HC', 'DS'])
plt.show()

# %%
#counting the numbers of subfolder in E4 and ECG

path1 = gen_dir + 'Data_EDA/vn5nknh3mn-2/E4'
path2 = gen_dir + 'Data_EDA/vn5nknh3mn-2/ECG_experiment'

subfolders1 = next(os.walk(path1))[1]
subfolders2 = next(os.walk(path2))[1]
print(len(subfolders1))
print(len(subfolders2))
# Out:
# 67
# 82

# %%
#combing the list of filenames in E4 and ECG to get the common files

#getting a list of all subdirectories in the specified directory
subdirs_E4 = [d for d in os.listdir(path1) if os.path.isdir(os.path.join(path1, d))]
subdirs_ECG = [d for d in os.listdir(path2) if os.path.isdir(os.path.join(path2, d))]

#creating a DataFrame to store the subdirectory names
df_E4 = pd.DataFrame({'Subfolder': subdirs_E4})
df_ECG = pd.DataFrame({'Subfolder': subdirs_ECG})

# display the DataFrame
# print(df_E4)
# print(df_ECG)

#getting unique values in each column of df_E4 and df_ECG
e4_values = df_E4.stack().unique()
ecg_values = df_ECG.stack().unique()

#checking which values are present in both dataframes
common_values = set(e4_values).intersection(set(ecg_values))
common_df = pd.DataFrame(common_values)

print(common_df.shape)
# Out:
# (63, 1)

# %%
#using one-hot encoding for 'Sex' and 'Category" columns saving it to sds_df4
sds_df4 = pd.get_dummies(sds_df3, columns=['Sex', 'Category'])

# %%
#using corr() to check the relationship between variables

selected_cols = ['Age', 'SDS_score_orig', 'Sex_Female','Sex_Male', 'Category_0', 'Category_1']
selected_df = sds_df4[selected_cols]
selected_df.corr()
# Out:
#                      Age  SDS_score_orig  Sex_Female  Sex_Male  Category_0  \
# Age             1.000000       -0.085431    0.184743 -0.184743   -0.081847
# SDS_score_orig -0.085431        1.000000   -0.070287  0.070287   -0.788835
# Sex_Female      0.184743       -0.070287    1.000000 -1.000000   -0.060437
# Sex_Male       -0.184743        0.070287   -1.000000  1.000000    0.060437
# Category_0     -0.081847       -0.788835   -0.060437  0.060437    1.000000
# Category_1      0.081847        0.788835    0.060437 -0.060437   -1.000000
#
#                 Category_1
# Age               0.081847
# SDS_score_orig    0.788835
# Sex_Female        0.060437
# Sex_Male         -0.060437
# Category_0       -1.000000
# Category_1        1.000000

# %%
#using seaborn for much better visualization for the correlation test

import seaborn as sns
import matplotlib.pyplot as plt

#selecting the columns to include in the correlation matrix
selected_cols = ['Age', 'Sex_Female', 'Sex_Male', 'Category_0', 'Category_1']
selected_df = sds_df4[selected_cols]

#computing the correlation matrix
corr_matrix = selected_df.corr()

#creating a heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')

#adding title
plt.title('Correlation Matrix for Selected Columns', fontsize=15)

#displaying the plot
plt.show()

# %%
#using pairplot to get the summary and general view of the ECSMP dataset

import seaborn as sns

#using one-hot encoding for 'Sex' only column saving it to sds_df5
sds_df5 = pd.get_dummies(sds_df3, columns=['Sex'])

#using sds_df3
plot = sns.pairplot(sds_df5, vars=['Age', 'SDS_score_orig', 'Sex_Male', 'Sex_Female'], hue="Category")
plot.fig.suptitle("Pairplot of SDS Dataset", fontsize = 15)
plot.savefig(gen_dir + "figures/pairplot.png")
plt.figure(figsize=(10,5))
plt.show()
