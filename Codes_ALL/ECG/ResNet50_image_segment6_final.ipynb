# %%
# pip install librosa

# %%
#pip install opencv-python

# %%
# #This is for STFT

# import os
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import librosa
# import librosa.display
# from PIL import Image

# # Set the input and output directories
# gen_dir = "/Users/xaichotic/Library/CloudStorage/OneDrive-NorthumbriaUniversity-ProductionAzureAD/Term3/"

# input_folder = os.path.join(gen_dir, "Data_ALL/ECG/ECG_csv_files_labeled_baseline6_pantompkins")
# output_folder = os.path.join(gen_dir, "Data_ALL/ECG_images_baseline6_STFT")

# # Create output directory if it does not exist
# if not os.path.exists(output_folder):
#     os.makedirs(output_folder)

# # Define the parameters for the STFT
# n_fft = 1024
# hop_length = 512

# # Loop through all the CSV files in the folder
# for filename in os.listdir(input_folder):
#     if filename.endswith(".csv"):
#         # Load the CSV file as a NumPy array
#         file_path = os.path.join(input_folder, filename)
#         ecg_signal = pd.read_csv(file_path, header=None).values.flatten()

#         # Compute the STFT
#         stft = librosa.stft(ecg_signal, n_fft=n_fft, hop_length=hop_length)
#         stft_mag_db = librosa.amplitude_to_db(np.abs(stft), ref=np.max)

#         # Normalize the STFT to [0, 1] range
#         stft_norm = (stft_mag_db - np.min(stft_mag_db)) / np.ptp(stft_mag_db)

#         # Convert the STFT to a 8-bit grayscale image
#         stft_img = (stft_norm * 255).astype(np.uint8)

#         # Save the image as a PNG file
#         output_filename = os.path.splitext(filename)[0] + ".png"
#         output_path = os.path.join(output_folder, output_filename)
#         Image.fromarray(stft_img, mode="L").save(output_path)

#         print(f"Processed {filename} and saved {output_filename}")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.12.0

# %%
#counting the length of the files EDA
#62, it matches the number of files in csv

gen_dir = "/Users/w20009829/OneDrive - Northumbria University - Production Azure AD/Term3/"

# Set the input and output directories
#gen_dir = "/Users/xaichotic/Library/CloudStorage/OneDrive-NorthumbriaUniversity-ProductionAzureAD/Term3/"

import os
folder_path = os.path.join(gen_dir, "Data_ALL/ECG_images_segment6_STFT")

# Count the number of files in the folder
num_files = len([f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))])

print(f"There are {num_files} files in the {folder_path} folder.")
# Out:
# There are 81 files in the /Users/w20009829/OneDrive - Northumbria University - Production Azure AD/Term3/Data_ALL/ECG_images_segment6_STFT folder.

# %%
import os

data_dir = os.path.join(gen_dir, "Data_ALL/ECG_images_segment6_STFT")

class_counts = {0: 0, 1: 0}

for file_name in os.listdir(data_dir):
    if file_name.endswith(".png"):
        class_label = int(file_name.split("_")[-1].split(".")[0])
        class_counts[class_label] += 1

print(f"Class 0: {class_counts[0]} files")
print(f"Class 1: {class_counts[1]} files")
# Out:
# Class 0: 56 files
# Class 1: 25 files

# %%
import cv2
import numpy as np
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

# Set the data directory path
data_dir = os.path.join(gen_dir, "Data_ALL/ECG_images_segment6_STFT")

X = []
y = []

# Go through all the files in the directory
for file_name in os.listdir(data_dir):
    if file_name.endswith(".png"):
        # Extract the label from the file name
        label = int(file_name.split("_")[-1][0])
        # Load the image file and preprocess it
        file_path = os.path.join(data_dir, file_name)
        img_gray = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
        img_gray = cv2.resize(img_gray, (224, 224))
        img_rgb = cv2.cvtColor(img_gray, cv2.COLOR_GRAY2RGB) # Convert grayscale to RGB
        img_rgb = np.array(img_rgb).reshape(-1)
        # Save the preprocessed image and label in a list
        X.append(img_rgb)
        y.append(label)

# Convert the data to numpy arrays
X = np.array(X)
y = np.array(y)

# %%
from imblearn.under_sampling import RandomUnderSampler

# Apply random under-sampling to the data
rus = RandomUnderSampler()
X_resampled, y_resampled = rus.fit_resample(X, y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# %%
# Print the shape and class counts of the resampled data
print("Resampled data shape:", X_resampled.shape)
unique, counts = np.unique(y_resampled, return_counts=True)
print("Class counts:", dict(zip(unique, counts)))
# Out:
# Resampled data shape: (50, 150528)
# Class counts: {0: 25, 1: 25}

# %%
# Count the number of instances for each class in the resampled training data
class_counts = np.bincount(y_resampled)
print("Class distribution after Random Undersampling:", class_counts)
# Out:
# Class distribution after Random Undersampling: [25 25]

# %%
# Reshape the data into a 4D tensor
X_train = X_train.reshape((-1, 224, 224, 3))
X_test = X_test.reshape((-1, 224, 224, 3))

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (40, 224, 224, 3)
# (40,)
# (10, 224, 224, 3)
# (10,)

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam, SGD, RMSprop

import tensorflow as tf
import random

# Set the random seeds for reproducibility
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

batch_size = 32
neurons = 256

# Create ResNet50 model
resnet_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of ResNet50 model
for layer in resnet_model.layers:
    layer.trainable = False

# Add custom layers on top of ResNet50 model
model = Sequential()
model.add(resnet_model)
model.add(Flatten())
model.add(Dense(neurons, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
#opt = SGD(learning_rate=0.001)
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# Set up early stopping
#early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
early_stopping = EarlyStopping(monitor='val_loss', restore_best_weights=True, verbose=1, patience=10)

# Train the model with early stopping
history = model.fit(X_train, y_train, 
                    epochs=25, 
                    batch_size=batch_size, 
                    validation_data=(X_test, y_test), 
                    callbacks=[early_stopping])

test_loss, test_acc = model.evaluate(X_test, y_test)
print("Test loss:", test_loss)
print("Test accuracy:", test_acc)
# Out:
# Epoch 1/25
# 2/2 [==============================] - 5s 2s/step - loss: 22.3572 - accuracy: 0.5250 - val_loss: 39.6177 - val_accuracy: 0.3000
# Epoch 2/25
# 2/2 [==============================] - 2s 940ms/step - loss: 36.0979 - accuracy: 0.5750 - val_loss: 11.1837 - val_accuracy: 0.5000
# Epoch 3/25
# 2/2 [==============================] - 2s 849ms/step - loss: 16.0549 - accuracy: 0.6750 - val_loss: 45.8171 - val_accuracy: 0.3000
# Epoch 4/25
# 2/2 [==============================] - 2s 938ms/step - loss: 14.4530 - accuracy: 0.6750 - val_loss: 9.2626 - val_accuracy: 0.5000
# Epoch 5/25
# 2/2 [==============================] - 2s 832ms/step - loss: 12.2479 - accuracy: 0.6500 - val_loss: 13.7846 - val_accuracy: 0.4000
# Epoch 6/25
# 2/2 [==============================] - 2s 832ms/step - loss: 13.5708 - accuracy: 0.7250 - val_loss: 46.7362 - val_accuracy: 0.3000
# Epoch 7/25
# 2/2 [==============================] - 2s 970ms/step - loss: 10.7282 - accuracy: 0.7750 - val_loss: 8.8203 - val_accuracy: 0.6000
# Epoch 8/25
# 2/2 [==============================] - 2s 942ms/step - loss: 2.9012 - accuracy: 0.8000 - val_loss: 6.3468 - val_accuracy: 0.7000
# Epoch 9/25
# 2/2 [==============================] - 2s 829ms/step - loss: 3.9020 - accuracy: 0.8500 - val_loss: 8.5384 - val_accuracy: 0.5000
# Epoch 10/25
# 2/2 [==============================] - 2s 890ms/step - loss: 1.0249 - accuracy: 0.8500 - val_loss: 11.8503 - val_accuracy: 0.6000
# Epoch 11/25
# 2/2 [==============================] - 2s 1s/step - loss: 2.7842 - accuracy: 0.9000 - val_loss: 6.1597 - val_accuracy: 0.6000
# Epoch 12/25
# 2/2 [==============================] - 2s 859ms/step - loss: 2.6906 - accuracy: 0.8750 - val_loss: 14.0495 - val_accuracy: 0.5000
# Epoch 13/25
# 2/2 [==============================] - 2s 880ms/step - loss: 2.0235 - accuracy: 0.9000 - val_loss: 11.8888 - val_accuracy: 0.6000
# Epoch 14/25
# 2/2 [==============================] - 2s 857ms/step - loss: 1.8750 - accuracy: 0.8500 - val_loss: 9.1159 - val_accuracy: 0.5000
# Epoch 15/25
# 2/2 [==============================] - 2s 907ms/step - loss: 1.7505 - accuracy: 0.9250 - val_loss: 22.4481 - val_accuracy: 0.4000
# Epoch 16/25
# 2/2 [==============================] - 2s 921ms/step - loss: 2.6123 - accuracy: 0.9250 - val_loss: 14.5923 - val_accuracy: 0.6000
# Epoch 17/25
# 2/2 [==============================] - 2s 946ms/step - loss: 1.9916 - accuracy: 0.9000 - val_loss: 20.4609 - val_accuracy: 0.3000
# Epoch 18/25
# 2/2 [==============================] - 2s 959ms/step - loss: 0.3595 - accuracy: 0.9750 - val_loss: 13.9118 - val_accuracy: 0.5000
# Epoch 19/25
# 2/2 [==============================] - 2s 936ms/step - loss: 0.8950 - accuracy: 0.9500 - val_loss: 23.7794 - val_accuracy: 0.3000
# Epoch 20/25
# 2/2 [==============================] - 2s 936ms/step - loss: 2.3437 - accuracy: 0.8000 - val_loss: 15.7298 - val_accuracy: 0.2000
# Epoch 21/25
# 2/2 [==============================] - ETA: 0s - loss: 0.8235 - accuracy: 0.9500Restoring model weights from the end of the best epoch: 11.
# 2/2 [==============================] - 2s 1s/step - loss: 0.8235 - accuracy: 0.9500 - val_loss: 10.0116 - val_accuracy: 0.4000
# Epoch 21: early stopping
# 1/1 [==============================] - 0s 441ms/step - loss: 6.1597 - accuracy: 0.6000
# Test loss: 6.1597161293029785
# Test accuracy: 0.6000000238418579

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score

# Get the predictions
y_pred = model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)

# Print the confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)
print(cm)

# Print the classification report
print(classification_report(y_test, y_pred_classes))

# Print the ROC AUC score
roc_auc = roc_auc_score(y_test, y_pred)
print('ROC AUC:', roc_auc)

import matplotlib.pyplot as plt

# Get the training and validation loss and accuracy values from the history object
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# Create the figure and axis objects
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Plot the training and validation loss
ax1.plot(train_loss, label='Training Loss')
ax1.plot(val_loss, label='Validation Loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()

# Plot the training and validation accuracy
ax2.plot(train_acc, label='Training Accuracy')
ax2.plot(val_acc, label='Validation Accuracy')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()

# Show the plot
plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step
# [[0 3]
#  [1 6]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.67      0.86      0.75         7
#
#     accuracy                           0.60        10
#    macro avg       0.33      0.43      0.38        10
# weighted avg       0.47      0.60      0.53        10
#
# ROC AUC: 0.4285714285714286

# %% [markdown]
# cross-validation

# %%
#model for basic CNN

import numpy as np
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, BatchNormalization, MaxPooling1D, Dropout, Dense, Flatten
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold

# Set the random seeds for reproducibility
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

batch_size = 32
num_folds = 10
n_epochs =20
neurons = 256

# Create ResNet50 model
resnet_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of ResNet50 model
for layer in resnet_model.layers:
    layer.trainable = False

# Add custom layers on top of ResNet50 model
model = Sequential()
model.add(resnet_model)
model.add(Flatten())
model.add(Dense(neurons, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# Define the CNN model
def create_model():
    model = Sequential()
    model.add(resnet_model)
    model.add(Flatten())
    model.add(Dense(neurons, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
    return model

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score
import numpy as np
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, BatchNormalization, MaxPooling1D, Dropout, Dense, Flatten
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold

# Set the random seeds for reproducibility
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state = 42)

#K-fold cross-validation lists
score_list = []
precision_list = []
recall_list = []
f1_score_list = []
confusion_matrix_list = []
specificity_list = []
ROC_AUC_list = []


for fold, (train_idx, val_idx) in enumerate(kfold.split(X_train, y_train)):
    #splitting the data into train and validation sets for this fold
    X_train_fold, y_train_fold = X_train[train_idx], y_train[train_idx]
    X_val_fold, y_val_fold = X_train[val_idx], y_train[val_idx]
    
    #defining the early stopping callback
    early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True, verbose=1)
    
    #training the model for this fold
    model = create_model()
    history = model.fit(X_train_fold, y_train_fold, epochs=n_epochs, batch_size=batch_size, 
                        validation_data=(X_val_fold, y_val_fold), callbacks=[early_stop], verbose=1)
    
    #predicting the classes for the validation set for this fold
    y_pred = model.predict(X_val_fold)
    y_pred_classes = (y_pred > 0.5).astype(int)
    
    #calculating precision, recall, specificity, F1 score, AUC, and confusion matrix for this fold
    precision_list.append(precision_score(y_val_fold, y_pred_classes))
    recall_list.append(recall_score(y_val_fold, y_pred_classes))
    f1_score_list.append(f1_score(y_val_fold, y_pred_classes))
    #tp, fp, fn, tn = confusion_matrix(y_val_fold, y_pred_classes).ravel()
    tn, fp, fn, tp = confusion_matrix(y_val_fold, y_pred_classes).ravel()
    specificity = tn / (tn + fp)
    specificity_list.append(specificity)
    ROC_AUC_list.append(roc_auc_score(y_val_fold, y_pred))
    confusion_matrix_list.append(confusion_matrix(y_val_fold, y_pred_classes))

    #evaluating the model on the test set for this fold
    #_, test_acc = model.evaluate(X_test, y_test)
    _, test_acc = model.evaluate(X_val_fold, y_val_fold)

    score_list.append(test_acc)
    
    #printing the metrics and confusion matrix for this fold
    print(f'Fold {fold + 1}: Accuracy = {test_acc:.4f}, \
      Precision = {precision_list[-1]:.4f}, \
      Recall = {recall_list[-1]:.4f}, \
      Specificity = {specificity_list[-1]:.4f}, \
      AUC = {ROC_AUC_list[-1]:.4f}, \
      F1 Score = {f1_score_list[-1]:.4f}')
    print(f'Confusion matrix:\n{confusion_matrix_list[-1]}')
    
#Print the average scores for all folds

print(f'Average Accuracy: {np.mean(score_list):.4f} +/- {np.std(score_list):.4f}')
print(f'Average Precision: {np.mean(precision_list):.4f} +/- {np.std(precision_list):.4f}')
print(f'Average Recall/Sensitivity: {np.mean(recall_list):.4f} +/- {np.std(recall_list):.4f}')
print(f'Average Specificity: {np.mean(specificity_list):.4f} +/- {np.std(specificity_list):.4f}')
print(f'Average F1-score: {np.mean(f1_score_list):.4f} +/- {np.std(f1_score_list):.4f}')
print(f'Average ROC_AUC score: {np.mean(ROC_AUC_list):.4f} +/- {np.std(ROC_AUC_list):.4f}')

#printing the overall confusion matrix

overall_cm = np.sum(confusion_matrix_list, axis=0)
print(f'Overall confusion matrix:\n{overall_cm}')
# Out:
# Epoch 1/20
# 2/2 [==============================] - 5s 1s/step - loss: 22.8448 - accuracy: 0.4444 - val_loss: 133.5674 - val_accuracy: 0.2500
# Epoch 2/20
# 2/2 [==============================] - 2s 618ms/step - loss: 46.4467 - accuracy: 0.6667 - val_loss: 40.5189 - val_accuracy: 0.7500
# Epoch 3/20
# 2/2 [==============================] - 2s 600ms/step - loss: 76.3108 - accuracy: 0.5000 - val_loss: 7.0097 - val_accuracy: 0.7500
# Epoch 4/20
# 2/2 [==============================] - 2s 489ms/step - loss: 17.9976 - accuracy: 0.6944 - val_loss: 9.4875 - val_accuracy: 0.7500
# Epoch 5/20
# 2/2 [==============================] - 2s 492ms/step - loss: 7.0621 - accuracy: 0.7222 - val_loss: 19.8647 - val_accuracy: 0.7500
# Epoch 6/20
# 2/2 [==============================] - ETA: 0s - loss: 7.6941 - accuracy: 0.7500Restoring model weights from the end of the best epoch: 3.
# 2/2 [==============================] - 2s 576ms/step - loss: 7.6941 - accuracy: 0.7500 - val_loss: 32.1114 - val_accuracy: 0.7500
# Epoch 6: early stopping
# 1/1 [==============================] - 1s 795ms/step
# C:\Anaconda3\envs\xyrus\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 1/1 [==============================] - 0s 178ms/step - loss: 7.0097 - accuracy: 0.7500
# Fold 1: Accuracy = 0.7500,       Precision = 0.0000,       Recall = 0.0000,       Specificity = 1.0000,       AUC = 1.0000,       F1 Score = 0.0000
# Confusion matrix:
# [[3 0]
#  [1 0]]
# Epoch 1/20
# 2/2 [==============================] - 5s 1s/step - loss: 18.4071 - accuracy: 0.5556 - val_loss: 14.6952 - val_accuracy: 0.2500
# Epoch 2/20
# 2/2 [==============================] - 2s 608ms/step - loss: 12.1996 - accuracy: 0.6667 - val_loss: 2.9991 - val_accuracy: 0.7500
# Epoch 3/20
# 2/2 [==============================] - 2s 482ms/step - loss: 21.3719 - accuracy: 0.6667 - val_loss: 18.6826 - val_accuracy: 0.5000
# Epoch 4/20
# 2/2 [==============================] - 2s 489ms/step - loss: 22.3820 - accuracy: 0.6667 - val_loss: 40.7565 - val_accuracy: 0.5000
# Epoch 5/20
# 2/2 [==============================] - ETA: 0s - loss: 8.6442 - accuracy: 0.8056Restoring model weights from the end of the best epoch: 2.
# 2/2 [==============================] - 2s 548ms/step - loss: 8.6442 - accuracy: 0.8056 - val_loss: 25.7668 - val_accuracy: 0.5000
# Epoch 5: early stopping
# 1/1 [==============================] - 1s 798ms/step
# C:\Anaconda3\envs\xyrus\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 1/1 [==============================] - 0s 202ms/step - loss: 2.9991 - accuracy: 0.7500
# Fold 2: Accuracy = 0.7500,       Precision = 0.0000,       Recall = 0.0000,       Specificity = 1.0000,       AUC = 0.6667,       F1 Score = 0.0000
# Confusion matrix:
# [[3 0]
#  [1 0]]
# Epoch 1/20
# 2/2 [==============================] - 5s 1s/step - loss: 32.2249 - accuracy: 0.3889 - val_loss: 27.5835 - val_accuracy: 0.5000
# Epoch 2/20
# 2/2 [==============================] - 2s 495ms/step - loss: 15.9509 - accuracy: 0.6389 - val_loss: 55.2054 - val_accuracy: 0.5000
# Epoch 3/20
# 2/2 [==============================] - 2s 611ms/step - loss: 54.4178 - accuracy: 0.6111 - val_loss: 20.4945 - val_accuracy: 0.5000
# Epoch 4/20
# 2/2 [==============================] - 2s 507ms/step - loss: 25.0977 - accuracy: 0.6944 - val_loss: 37.2055 - val_accuracy: 0.5000
# Epoch 5/20
# 2/2 [==============================] - 2s 619ms/step - loss: 28.6076 - accuracy: 0.5833 - val_loss: 16.3800 - val_accuracy: 0.5000
# Epoch 6/20
# 2/2 [==============================] - 2s 490ms/step - loss: 11.5575 - accuracy: 0.7500 - val_loss: 22.6422 - val_accuracy: 0.5000
# Epoch 7/20
# 2/2 [==============================] - 2s 496ms/step - loss: 17.9914 - accuracy: 0.6389 - val_loss: 38.8541 - val_accuracy: 0.5000
# Epoch 8/20
# 2/2 [==============================] - 2s 638ms/step - loss: 14.1172 - accuracy: 0.7222 - val_loss: 3.7127 - val_accuracy: 0.7500
# Epoch 9/20
# 2/2 [==============================] - 2s 529ms/step - loss: 8.6538 - accuracy: 0.7500 - val_loss: 39.4087 - val_accuracy: 0.5000
# Epoch 10/20
# 2/2 [==============================] - 2s 530ms/step - loss: 14.2605 - accuracy: 0.7500 - val_loss: 4.9830 - val_accuracy: 0.7500
# Epoch 11/20
# 2/2 [==============================] - 2s 653ms/step - loss: 7.1147 - accuracy: 0.7778 - val_loss: 0.8473 - val_accuracy: 0.7500
# Epoch 12/20
# 2/2 [==============================] - 2s 503ms/step - loss: 1.2042 - accuracy: 0.9722 - val_loss: 11.0549 - val_accuracy: 0.5000
# Epoch 13/20
# 2/2 [==============================] - 2s 508ms/step - loss: 3.1202e-04 - accuracy: 1.0000 - val_loss: 11.0273 - val_accuracy: 0.5000
# Epoch 14/20
# 2/2 [==============================] - ETA: 0s - loss: 1.3596 - accuracy: 0.9167Restoring model weights from the end of the best epoch: 11.
# 2/2 [==============================] - 2s 604ms/step - loss: 1.3596 - accuracy: 0.9167 - val_loss: 5.0712 - val_accuracy: 0.5000
# Epoch 14: early stopping
# 1/1 [==============================] - 1s 860ms/step
# 1/1 [==============================] - 0s 189ms/step - loss: 0.8473 - accuracy: 0.7500
# Fold 3: Accuracy = 0.7500,       Precision = 1.0000,       Recall = 0.5000,       Specificity = 1.0000,       AUC = 1.0000,       F1 Score = 0.6667
# Confusion matrix:
# [[2 0]
#  [1 1]]
# Epoch 1/20
# 2/2 [==============================] - 5s 2s/step - loss: 45.4341 - accuracy: 0.4444 - val_loss: 75.4442 - val_accuracy: 0.5000
# Epoch 2/20
# 2/2 [==============================] - 2s 746ms/step - loss: 65.8949 - accuracy: 0.5833 - val_loss: 3.9521 - val_accuracy: 0.5000
# Epoch 3/20
# 2/2 [==============================] - 2s 560ms/step - loss: 7.4519 - accuracy: 0.6111 - val_loss: 5.4704 - val_accuracy: 0.7500
# Epoch 4/20
# 2/2 [==============================] - 2s 553ms/step - loss: 5.6595 - accuracy: 0.5833 - val_loss: 10.5745 - val_accuracy: 0.5000
# Epoch 5/20
# 2/2 [==============================] - ETA: 0s - loss: 2.8345 - accuracy: 0.7778Restoring model weights from the end of the best epoch: 2.
# 2/2 [==============================] - 2s 619ms/step - loss: 2.8345 - accuracy: 0.7778 - val_loss: 4.5407 - val_accuracy: 0.5000
# Epoch 5: early stopping
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000013343F18670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 818ms/step
# 1/1 [==============================] - 0s 190ms/step - loss: 3.9521 - accuracy: 0.5000
# Fold 4: Accuracy = 0.5000,       Precision = 0.5000,       Recall = 0.5000,       Specificity = 0.5000,       AUC = 0.5000,       F1 Score = 0.5000
# Confusion matrix:
# [[1 1]
#  [1 1]]
# Epoch 1/20
# 2/2 [==============================] - 5s 1s/step - loss: 13.0569 - accuracy: 0.4444 - val_loss: 90.3855 - val_accuracy: 0.5000
# Epoch 2/20
# 2/2 [==============================] - 2s 660ms/step - loss: 51.9735 - accuracy: 0.5833 - val_loss: 13.4943 - val_accuracy: 0.5000
# Epoch 3/20
# 2/2 [==============================] - 2s 510ms/step - loss: 25.4088 - accuracy: 0.6389 - val_loss: 32.9969 - val_accuracy: 0.5000
# Epoch 4/20
# 2/2 [==============================] - 2s 510ms/step - loss: 30.9729 - accuracy: 0.5833 - val_loss: 13.7131 - val_accuracy: 0.2500
# Epoch 5/20
# 2/2 [==============================] - 2s 650ms/step - loss: 6.1767 - accuracy: 0.7778 - val_loss: 12.8235 - val_accuracy: 0.5000
# Epoch 6/20
# 2/2 [==============================] - 2s 524ms/step - loss: 3.3621 - accuracy: 0.8611 - val_loss: 25.5408 - val_accuracy: 0.5000
# Epoch 7/20
# 2/2 [==============================] - 2s 522ms/step - loss: 3.1665 - accuracy: 0.8889 - val_loss: 17.8429 - val_accuracy: 0.2500
# Epoch 8/20
# 2/2 [==============================] - ETA: 0s - loss: 3.6321 - accuracy: 0.8889Restoring model weights from the end of the best epoch: 5.
# 2/2 [==============================] - 2s 585ms/step - loss: 3.6321 - accuracy: 0.8889 - val_loss: 15.3429 - val_accuracy: 0.5000
# Epoch 8: early stopping
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001334097FF70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 797ms/step
# 1/1 [==============================] - 0s 186ms/step - loss: 12.8235 - accuracy: 0.5000
# Fold 5: Accuracy = 0.5000,       Precision = 0.5000,       Recall = 1.0000,       Specificity = 0.0000,       AUC = 0.6250,       F1 Score = 0.6667
# Confusion matrix:
# [[0 2]
#  [0 2]]
# Epoch 1/20
# 2/2 [==============================] - 5s 2s/step - loss: 9.8562 - accuracy: 0.5278 - val_loss: 11.6831 - val_accuracy: 0.7500
# Epoch 2/20
# 2/2 [==============================] - 2s 511ms/step - loss: 12.2623 - accuracy: 0.8056 - val_loss: 18.7931 - val_accuracy: 0.7500
# Epoch 3/20
# 2/2 [==============================] - 2s 651ms/step - loss: 15.6264 - accuracy: 0.6944 - val_loss: 11.2003 - val_accuracy: 0.7500
# Epoch 4/20
# 2/2 [==============================] - 2s 519ms/step - loss: 7.9291 - accuracy: 0.7500 - val_loss: 62.9944 - val_accuracy: 0.5000
# Epoch 5/20
# 2/2 [==============================] - 2s 519ms/step - loss: 60.2041 - accuracy: 0.6111 - val_loss: 33.1567 - val_accuracy: 0.7500
# Epoch 6/20
# 2/2 [==============================] - ETA: 0s - loss: 17.4318 - accuracy: 0.6389Restoring model weights from the end of the best epoch: 3.
# 2/2 [==============================] - 2s 591ms/step - loss: 17.4318 - accuracy: 0.6389 - val_loss: 21.2499 - val_accuracy: 0.5000
# Epoch 6: early stopping
# 1/1 [==============================] - 1s 799ms/step
# 1/1 [==============================] - 0s 185ms/step - loss: 11.2003 - accuracy: 0.7500
# Fold 6: Accuracy = 0.7500,       Precision = 0.6667,       Recall = 1.0000,       Specificity = 0.5000,       AUC = 0.7500,       F1 Score = 0.8000
# Confusion matrix:
# [[1 1]
#  [0 2]]
# Epoch 1/20
# 2/2 [==============================] - 5s 1s/step - loss: 59.0083 - accuracy: 0.3889 - val_loss: 70.7837 - val_accuracy: 0.5000
# Epoch 2/20
# 2/2 [==============================] - 2s 610ms/step - loss: 50.9060 - accuracy: 0.6111 - val_loss: 11.1348 - val_accuracy: 0.5000
# Epoch 3/20
# 2/2 [==============================] - 2s 487ms/step - loss: 8.5231 - accuracy: 0.6944 - val_loss: 75.1492 - val_accuracy: 0.5000
# Epoch 4/20
# 2/2 [==============================] - 2s 513ms/step - loss: 50.2806 - accuracy: 0.5556 - val_loss: 23.2191 - val_accuracy: 0.5000
# Epoch 5/20
# 2/2 [==============================] - ETA: 0s - loss: 18.3570 - accuracy: 0.5556Restoring model weights from the end of the best epoch: 2.
# 2/2 [==============================] - 2s 588ms/step - loss: 18.3570 - accuracy: 0.5556 - val_loss: 25.5420 - val_accuracy: 0.5000
# Epoch 5: early stopping
# 1/1 [==============================] - 1s 802ms/step
# 1/1 [==============================] - 0s 183ms/step - loss: 11.1348 - accuracy: 0.5000
# Fold 7: Accuracy = 0.5000,       Precision = 0.5000,       Recall = 1.0000,       Specificity = 0.0000,       AUC = 0.3750,       F1 Score = 0.6667
# Confusion matrix:
# [[0 2]
#  [0 2]]
# Epoch 1/20
# 2/2 [==============================] - 5s 1s/step - loss: 29.0887 - accuracy: 0.4167 - val_loss: 117.8433 - val_accuracy: 0.5000
# Epoch 2/20
# 2/2 [==============================] - 2s 613ms/step - loss: 76.6117 - accuracy: 0.5556 - val_loss: 41.7163 - val_accuracy: 0.5000
# Epoch 3/20
# 2/2 [==============================] - 2s 604ms/step - loss: 26.4718 - accuracy: 0.7222 - val_loss: 6.7065 - val_accuracy: 0.5000
# Epoch 4/20
# 2/2 [==============================] - 2s 506ms/step - loss: 17.3942 - accuracy: 0.6667 - val_loss: 14.3669 - val_accuracy: 0.0000e+00
# Epoch 5/20
# 2/2 [==============================] - 2s 520ms/step - loss: 8.3446 - accuracy: 0.8056 - val_loss: 39.6428 - val_accuracy: 0.5000
# Epoch 6/20
# 2/2 [==============================] - ETA: 0s - loss: 9.2994 - accuracy: 0.7778Restoring model weights from the end of the best epoch: 3.
# 2/2 [==============================] - 2s 595ms/step - loss: 9.2994 - accuracy: 0.7778 - val_loss: 114.2860 - val_accuracy: 0.5000
# Epoch 6: early stopping
# 1/1 [==============================] - 1s 815ms/step
# 1/1 [==============================] - 0s 182ms/step - loss: 6.7065 - accuracy: 0.5000
# Fold 8: Accuracy = 0.5000,       Precision = 0.5000,       Recall = 0.5000,       Specificity = 0.5000,       AUC = 0.5000,       F1 Score = 0.5000
# Confusion matrix:
# [[1 1]
#  [1 1]]
# Epoch 1/20
# 2/2 [==============================] - 5s 1s/step - loss: 32.6509 - accuracy: 0.5556 - val_loss: 126.2278 - val_accuracy: 0.5000
# Epoch 2/20
# 2/2 [==============================] - 2s 632ms/step - loss: 72.9912 - accuracy: 0.5556 - val_loss: 40.0298 - val_accuracy: 0.2500
# Epoch 3/20
# 2/2 [==============================] - 2s 533ms/step - loss: 17.5952 - accuracy: 0.6944 - val_loss: 55.3098 - val_accuracy: 0.5000
# Epoch 4/20
# 2/2 [==============================] - 2s 648ms/step - loss: 46.1052 - accuracy: 0.5556 - val_loss: 29.5718 - val_accuracy: 0.5000
# Epoch 5/20
# 2/2 [==============================] - 2s 527ms/step - loss: 6.5591 - accuracy: 0.7778 - val_loss: 37.3571 - val_accuracy: 0.5000
# Epoch 6/20
# 2/2 [==============================] - 2s 647ms/step - loss: 14.3538 - accuracy: 0.7500 - val_loss: 16.1072 - val_accuracy: 0.5000
# Epoch 7/20
# 2/2 [==============================] - 2s 520ms/step - loss: 5.7604 - accuracy: 0.8333 - val_loss: 21.3364 - val_accuracy: 0.5000
# Epoch 8/20
# 2/2 [==============================] - 2s 655ms/step - loss: 7.0235 - accuracy: 0.7778 - val_loss: 14.0363 - val_accuracy: 0.2500
# Epoch 9/20
# 2/2 [==============================] - 2s 552ms/step - loss: 5.1723 - accuracy: 0.8333 - val_loss: 25.9074 - val_accuracy: 0.5000
# Epoch 10/20
# 2/2 [==============================] - 2s 539ms/step - loss: 7.1778 - accuracy: 0.7778 - val_loss: 49.7389 - val_accuracy: 0.5000
# Epoch 11/20
# 2/2 [==============================] - 2s 643ms/step - loss: 27.8231 - accuracy: 0.6389 - val_loss: 13.9128 - val_accuracy: 0.2500
# Epoch 12/20
# 2/2 [==============================] - 2s 517ms/step - loss: 6.4785 - accuracy: 0.8889 - val_loss: 18.7970 - val_accuracy: 0.7500
# Epoch 13/20
# 2/2 [==============================] - 2s 644ms/step - loss: 2.9293 - accuracy: 0.9444 - val_loss: 9.4537 - val_accuracy: 0.5000
# Epoch 14/20
# 2/2 [==============================] - 2s 525ms/step - loss: 2.8257 - accuracy: 0.9167 - val_loss: 16.7052 - val_accuracy: 0.5000
# Epoch 15/20
# 2/2 [==============================] - 2s 526ms/step - loss: 5.0826 - accuracy: 0.7778 - val_loss: 26.2415 - val_accuracy: 0.5000
# Epoch 16/20
# 2/2 [==============================] - 2s 656ms/step - loss: 4.1789 - accuracy: 0.8889 - val_loss: 3.7178 - val_accuracy: 0.5000
# Epoch 17/20
# 2/2 [==============================] - 2s 555ms/step - loss: 0.3372 - accuracy: 0.9444 - val_loss: 15.7062 - val_accuracy: 0.7500
# Epoch 18/20
# 2/2 [==============================] - 2s 618ms/step - loss: 4.6618 - accuracy: 0.9167 - val_loss: 6.5100 - val_accuracy: 0.7500
# Epoch 19/20
# 2/2 [==============================] - ETA: 0s - loss: 3.2642 - accuracy: 0.9444Restoring model weights from the end of the best epoch: 16.
# 2/2 [==============================] - 2s 621ms/step - loss: 3.2642 - accuracy: 0.9444 - val_loss: 8.3377 - val_accuracy: 0.7500
# Epoch 19: early stopping
# 1/1 [==============================] - 1s 821ms/step
# 1/1 [==============================] - 0s 194ms/step - loss: 3.7178 - accuracy: 0.5000
# Fold 9: Accuracy = 0.5000,       Precision = 0.5000,       Recall = 0.5000,       Specificity = 0.5000,       AUC = 0.7500,       F1 Score = 0.5000
# Confusion matrix:
# [[1 1]
#  [1 1]]
# Epoch 1/20
# 2/2 [==============================] - 5s 1s/step - loss: 20.6474 - accuracy: 0.5278 - val_loss: 43.2621 - val_accuracy: 0.5000
# Epoch 2/20
# 2/2 [==============================] - 2s 672ms/step - loss: 18.2330 - accuracy: 0.6111 - val_loss: 11.2910 - val_accuracy: 0.2500
# Epoch 3/20
# 2/2 [==============================] - 2s 546ms/step - loss: 18.1287 - accuracy: 0.6667 - val_loss: 23.7136 - val_accuracy: 0.0000e+00
# Epoch 4/20
# 2/2 [==============================] - 2s 572ms/step - loss: 12.9353 - accuracy: 0.7500 - val_loss: 18.4006 - val_accuracy: 0.5000
# Epoch 5/20
# 2/2 [==============================] - ETA: 0s - loss: 17.0427 - accuracy: 0.7500Restoring model weights from the end of the best epoch: 2.
# 2/2 [==============================] - 2s 618ms/step - loss: 17.0427 - accuracy: 0.7500 - val_loss: 33.8585 - val_accuracy: 0.5000
# Epoch 5: early stopping
# 1/1 [==============================] - 1s 818ms/step
# 1/1 [==============================] - 0s 191ms/step - loss: 11.2910 - accuracy: 0.2500
# Fold 10: Accuracy = 0.2500,       Precision = 0.3333,       Recall = 0.5000,       Specificity = 0.0000,       AUC = 0.0000,       F1 Score = 0.4000
# Confusion matrix:
# [[0 2]
#  [1 1]]
# Average Accuracy: 0.5750 +/- 0.1601
# Average Precision: 0.4500 +/- 0.2794
# Average Recall/Sensitivity: 0.5500 +/- 0.3500
# Average Specificity: 0.5000 +/- 0.3873
# Average F1-score: 0.4700 +/- 0.2597
# Average ROC_AUC score: 0.6167 +/- 0.2825
# Overall confusion matrix:
# [[12 10]
#  [ 7 11]]
