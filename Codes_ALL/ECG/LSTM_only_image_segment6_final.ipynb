# %%
# pip install librosa

# %%
#pip install opencv-python

# %%
# #This is for STFT

# import os
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import librosa
# import librosa.display
# from PIL import Image

# # Set the input and output directories
# gen_dir = "/Users/xaichotic/Library/CloudStorage/OneDrive-NorthumbriaUniversity-ProductionAzureAD/Term3/"

# input_folder = os.path.join(gen_dir, "Data_ALL/ECG/ECG_csv_files_labeled_baseline6_pantompkins")
# output_folder = os.path.join(gen_dir, "Data_ALL/ECG_images_baseline6_STFT")

# # Create output directory if it does not exist
# if not os.path.exists(output_folder):
#     os.makedirs(output_folder)

# # Define the parameters for the STFT
# n_fft = 1024
# hop_length = 512

# # Loop through all the CSV files in the folder
# for filename in os.listdir(input_folder):
#     if filename.endswith(".csv"):
#         # Load the CSV file as a NumPy array
#         file_path = os.path.join(input_folder, filename)
#         ecg_signal = pd.read_csv(file_path, header=None).values.flatten()

#         # Compute the STFT
#         stft = librosa.stft(ecg_signal, n_fft=n_fft, hop_length=hop_length)
#         stft_mag_db = librosa.amplitude_to_db(np.abs(stft), ref=np.max)

#         # Normalize the STFT to [0, 1] range
#         stft_norm = (stft_mag_db - np.min(stft_mag_db)) / np.ptp(stft_mag_db)

#         # Convert the STFT to a 8-bit grayscale image
#         stft_img = (stft_norm * 255).astype(np.uint8)

#         # Save the image as a PNG file
#         output_filename = os.path.splitext(filename)[0] + ".png"
#         output_path = os.path.join(output_folder, output_filename)
#         Image.fromarray(stft_img, mode="L").save(output_path)

#         print(f"Processed {filename} and saved {output_filename}")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.12.0

# %%
#counting the length of the files EDA
#62, it matches the number of files in csv

gen_dir = "/Users/w20009829/OneDrive - Northumbria University - Production Azure AD/Term3/"

# Set the input and output directories
#gen_dir = "/Users/xaichotic/Library/CloudStorage/OneDrive-NorthumbriaUniversity-ProductionAzureAD/Term3/"

import os
folder_path = os.path.join(gen_dir, "Data_ALL/ECG_images_segment6_STFT")

# Count the number of files in the folder
num_files = len([f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))])

print(f"There are {num_files} files in the {folder_path} folder.")
# Out:
# There are 81 files in the /Users/w20009829/OneDrive - Northumbria University - Production Azure AD/Term3/Data_ALL/ECG_images_segment6_STFT folder.

# %%
import os

data_dir = os.path.join(gen_dir, "Data_ALL/ECG_images_segment6_STFT")

class_counts = {0: 0, 1: 0}

for file_name in os.listdir(data_dir):
    if file_name.endswith(".png"):
        class_label = int(file_name.split("_")[-1].split(".")[0])
        class_counts[class_label] += 1

print(f"Class 0: {class_counts[0]} files")
print(f"Class 1: {class_counts[1]} files")
# Out:
# Class 0: 56 files
# Class 1: 25 files

# %%
import cv2
import numpy as np
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

# Set the data directory path
data_dir = os.path.join(gen_dir, "Data_ALL/ECG_images_segment6_STFT")

X = []
y = []

# Go through all the files in the directory
for file_name in os.listdir(data_dir):
    if file_name.endswith(".png"):
        # Extract the label from the file name
        label = int(file_name.split("_")[-1][0])
        # Load the image file and preprocess it
        file_path = os.path.join(data_dir, file_name)
        img = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
        img = cv2.resize(img, (224, 224))
        img = np.array(img).reshape(-1)
        # Save the preprocessed image and label in a list
        X.append(img)
        y.append(label)

# Convert the data to numpy arrays
X = np.array(X)
y = np.array(y)

# %%
from imblearn.under_sampling import RandomUnderSampler

# Apply random under-sampling to the data
rus = RandomUnderSampler()
X_resampled, y_resampled = rus.fit_resample(X, y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# %%
# Print the shape and class counts of the resampled data
print("Resampled data shape:", X_resampled.shape)
unique, counts = np.unique(y_resampled, return_counts=True)
print("Class counts:", dict(zip(unique, counts)))
# Out:
# Resampled data shape: (50, 50176)
# Class counts: {0: 25, 1: 25}

# %%
# Count the number of instances for each class in the resampled training data
class_counts = np.bincount(y_resampled)
print("Class distribution after Random Undersampling:", class_counts)
# Out:
# Class distribution after Random Undersampling: [25 25]

# %%
# Reshape the data into a 4D tensor
X_train = X_train.reshape((-1, 224, 224, 1))
X_test = X_test.reshape((-1, 224, 224, 1))

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (40, 224, 224, 1)
# (40,)
# (10, 224, 224, 1)
# (10,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adagrad
import numpy as np

import tensorflow as tf

import random
# Set the random seeds for reproducibility
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

batch_size = 32
lstm_units = 32
neurons = 256

# Reshape the input data
X_train = np.reshape(X_train, (X_train.shape[0], 224, 224))
X_test = np.reshape(X_test, (X_test.shape[0], 224, 224))

# Define the model architecture
model = Sequential()
model.add(LSTM(lstm_units, input_shape=(224, 224)))
model.add(Dropout(0.5))
model.add(Dense(neurons, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(neurons*2, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

model.summary()

opt = SGD(learning_rate = 0.001)

# Compile the model
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# Set up early stopping
early_stopping = EarlyStopping(monitor='val_loss', restore_best_weights=True, verbose=1, patience=10)

# Train the model with early stopping
history = model.fit(X_train, y_train, 
                    epochs=25, 
                    batch_size=batch_size, 
                    validation_data=(X_test, y_test), 
                    callbacks=[early_stopping])

test_loss, test_acc = model.evaluate(X_test, y_test)
print("Test loss:", test_loss)
print("Test accuracy:", test_acc)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 32)                32896
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense (Dense)               (None, 256)               8448
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 512)               131584
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 173,441
# Trainable params: 173,441
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 2/2 [==============================] - 3s 625ms/step - loss: 0.7778 - accuracy: 0.4000 - val_loss: 0.7117 - val_accuracy: 0.3000
# Epoch 2/25
# 2/2 [==============================] - 0s 66ms/step - loss: 0.7236 - accuracy: 0.4500 - val_loss: 0.6705 - val_accuracy: 0.8000
# Epoch 3/25
# 2/2 [==============================] - 0s 66ms/step - loss: 0.6616 - accuracy: 0.7000 - val_loss: 0.6957 - val_accuracy: 0.4000
# Epoch 4/25
# 2/2 [==============================] - 0s 67ms/step - loss: 0.6590 - accuracy: 0.6000 - val_loss: 0.6504 - val_accuracy: 0.6000
# Epoch 5/25
# 2/2 [==============================] - 0s 68ms/step - loss: 0.6199 - accuracy: 0.7000 - val_loss: 0.6320 - val_accuracy: 0.8000
# Epoch 6/25
# 2/2 [==============================] - 0s 72ms/step - loss: 0.6687 - accuracy: 0.6000 - val_loss: 0.6075 - val_accuracy: 0.8000
# Epoch 7/25
# 2/2 [==============================] - 0s 64ms/step - loss: 0.6628 - accuracy: 0.5000 - val_loss: 0.5704 - val_accuracy: 0.9000
# Epoch 8/25
# 2/2 [==============================] - 0s 64ms/step - loss: 0.6217 - accuracy: 0.7000 - val_loss: 0.5707 - val_accuracy: 0.8000
# Epoch 9/25
# 2/2 [==============================] - 0s 63ms/step - loss: 0.6386 - accuracy: 0.5750 - val_loss: 0.6340 - val_accuracy: 0.5000
# Epoch 10/25
# 2/2 [==============================] - 0s 68ms/step - loss: 0.6035 - accuracy: 0.6500 - val_loss: 0.5483 - val_accuracy: 0.7000
# Epoch 11/25
# 2/2 [==============================] - 0s 65ms/step - loss: 0.6104 - accuracy: 0.6750 - val_loss: 0.5821 - val_accuracy: 0.7000
# Epoch 12/25
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5461 - accuracy: 0.7500 - val_loss: 0.6433 - val_accuracy: 0.6000
# Epoch 13/25
# 2/2 [==============================] - 0s 76ms/step - loss: 0.5122 - accuracy: 0.8000 - val_loss: 0.5004 - val_accuracy: 0.8000
# Epoch 14/25
# 2/2 [==============================] - 0s 65ms/step - loss: 0.4800 - accuracy: 0.7250 - val_loss: 0.5672 - val_accuracy: 0.8000
# Epoch 15/25
# 2/2 [==============================] - 0s 66ms/step - loss: 0.5385 - accuracy: 0.7000 - val_loss: 0.5341 - val_accuracy: 0.8000
# Epoch 16/25
# 2/2 [==============================] - 0s 65ms/step - loss: 0.4277 - accuracy: 0.7750 - val_loss: 0.5772 - val_accuracy: 0.7000
# Epoch 17/25
# 2/2 [==============================] - 0s 65ms/step - loss: 0.3815 - accuracy: 0.8250 - val_loss: 0.5338 - val_accuracy: 0.7000
# Epoch 18/25
# 2/2 [==============================] - 0s 65ms/step - loss: 0.5225 - accuracy: 0.7250 - val_loss: 0.5964 - val_accuracy: 0.8000
# Epoch 19/25
# 2/2 [==============================] - 0s 66ms/step - loss: 0.4145 - accuracy: 0.8250 - val_loss: 0.6538 - val_accuracy: 0.6000
# Epoch 20/25
# 2/2 [==============================] - 0s 66ms/step - loss: 0.5247 - accuracy: 0.7250 - val_loss: 0.5128 - val_accuracy: 0.8000
# Epoch 21/25
# 2/2 [==============================] - 0s 67ms/step - loss: 0.3852 - accuracy: 0.8250 - val_loss: 0.4992 - val_accuracy: 0.8000
# Epoch 22/25
# 2/2 [==============================] - 0s 68ms/step - loss: 0.3336 - accuracy: 0.8750 - val_loss: 0.4980 - val_accuracy: 0.8000
# Epoch 23/25
# 2/2 [==============================] - 0s 68ms/step - loss: 0.3288 - accuracy: 0.8500 - val_loss: 0.5537 - val_accuracy: 0.7000
# Epoch 24/25
# 2/2 [==============================] - 0s 64ms/step - loss: 0.2562 - accuracy: 0.8750 - val_loss: 0.6034 - val_accuracy: 0.7000
# Epoch 25/25
# 2/2 [==============================] - 0s 65ms/step - loss: 0.3503 - accuracy: 0.8000 - val_loss: 0.4286 - val_accuracy: 0.8000
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4286 - accuracy: 0.8000
# Test loss: 0.428572416305542
# Test accuracy: 0.800000011920929

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score

# Get the predictions
y_pred = model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)

# Print the confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)
print(cm)

# Print the classification report
print(classification_report(y_test, y_pred_classes))

# Calculate specificity
tn, fp, fn, tp = cm.ravel()
specificity = tn / (tn + fp)
print('Specificity:', specificity)

# Print the ROC AUC score
roc_auc = roc_auc_score(y_test, y_pred)
print('ROC AUC:', roc_auc)

import matplotlib.pyplot as plt

# Get the training and validation loss and accuracy values from the history object
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# Create the figure and axis objects
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Plot the training and validation loss
ax1.plot(train_loss, label='Training Loss')
ax1.plot(val_loss, label='Validation Loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()

# Plot the training and validation accuracy
ax2.plot(train_acc, label='Training Accuracy')
ax2.plot(val_acc, label='Validation Accuracy')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()

# Show the plot
plt.show()
# Out:
# 1/1 [==============================] - 0s 465ms/step
# [[2 1]
#  [1 6]]
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67         3
#            1       0.86      0.86      0.86         7
#
#     accuracy                           0.80        10
#    macro avg       0.76      0.76      0.76        10
# weighted avg       0.80      0.80      0.80        10
#
# Specificity: 0.6666666666666666
# ROC AUC: 0.8571428571428571

# %% [markdown]
# cross-validation

# %%
import numpy as np
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, BatchNormalization, MaxPooling1D, Dropout, Dense, Flatten
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold

import random
# Set the random seeds for reproducibility
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

batch_size = 32
lstm_units = 32
num_folds = 5
n_epochs = 20
neurons = 256

# Reshape the input data
X_train = np.reshape(X_train, (X_train.shape[0], 224, 224))
X_test = np.reshape(X_test, (X_test.shape[0], 224, 224))

# Define the model architecture
def create_model():
    model = Sequential()
    model.add(LSTM(lstm_units, input_shape=(224, 224)))
    model.add(Dropout(0.5))
    model.add(Dense(neurons, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(neurons*2, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
    return model

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score
import numpy as np
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, BatchNormalization, MaxPooling1D, Dropout, Dense, Flatten
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold

# Set the random seeds for reproducibility
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state = 42)

#K-fold cross-validation lists
score_list = []
precision_list = []
recall_list = []
f1_score_list = []
confusion_matrix_list = []
specificity_list = []
ROC_AUC_list = []


for fold, (train_idx, val_idx) in enumerate(kfold.split(X_train, y_train)):
    #splitting the data into train and validation sets for this fold
    X_train_fold, y_train_fold = X_train[train_idx], y_train[train_idx]
    X_val_fold, y_val_fold = X_train[val_idx], y_train[val_idx]
    
    #defining the early stopping callback
    early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True, verbose=1)
    
    #training the model for this fold
    model = create_model()
    history = model.fit(X_train_fold, y_train_fold, epochs=n_epochs, batch_size=batch_size, 
                        validation_data=(X_val_fold, y_val_fold), callbacks=[early_stop], verbose=1)
    
    #predicting the classes for the validation set for this fold
    y_pred = model.predict(X_val_fold)
    y_pred_classes = (y_pred > 0.5).astype(int)
    
    #calculating precision, recall, specificity, F1 score, AUC, and confusion matrix for this fold
    precision_list.append(precision_score(y_val_fold, y_pred_classes))
    recall_list.append(recall_score(y_val_fold, y_pred_classes))
    f1_score_list.append(f1_score(y_val_fold, y_pred_classes))
    #tp, fp, fn, tn = confusion_matrix(y_val_fold, y_pred_classes).ravel()
    tn, fp, fn, tp = confusion_matrix(y_val_fold, y_pred_classes).ravel()
    specificity = tn / (tn + fp)
    specificity_list.append(specificity)
    ROC_AUC_list.append(roc_auc_score(y_val_fold, y_pred))
    confusion_matrix_list.append(confusion_matrix(y_val_fold, y_pred_classes))

    #evaluating the model on the test set for this fold
    #_, test_acc = model.evaluate(X_test, y_test)
    _, test_acc = model.evaluate(X_val_fold, y_val_fold)

    score_list.append(test_acc)
    
    #printing the metrics and confusion matrix for this fold
    print(f'Fold {fold + 1}: Accuracy = {test_acc:.4f}, \
      Precision = {precision_list[-1]:.4f}, \
      Recall = {recall_list[-1]:.4f}, \
      Specificity = {specificity_list[-1]:.4f}, \
      AUC = {ROC_AUC_list[-1]:.4f}, \
      F1 Score = {f1_score_list[-1]:.4f}')
    print(f'Confusion matrix:\n{confusion_matrix_list[-1]}')
    
#Print the average scores for all folds

print(f'Average Accuracy: {np.mean(score_list):.4f} +/- {np.std(score_list):.4f}')
print(f'Average Precision: {np.mean(precision_list):.4f} +/- {np.std(precision_list):.4f}')
print(f'Average Recall/Sensitivity: {np.mean(recall_list):.4f} +/- {np.std(recall_list):.4f}')
print(f'Average Specificity: {np.mean(specificity_list):.4f} +/- {np.std(specificity_list):.4f}')
print(f'Average F1-score: {np.mean(f1_score_list):.4f} +/- {np.std(f1_score_list):.4f}')
print(f'Average ROC_AUC score: {np.mean(ROC_AUC_list):.4f} +/- {np.std(ROC_AUC_list):.4f}')

#printing the overall confusion matrix

overall_cm = np.sum(confusion_matrix_list, axis=0)
print(f'Overall confusion matrix:\n{overall_cm}')
# Out:
# Epoch 1/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.7276 - accuracy: 0.4688 - val_loss: 0.6989 - val_accuracy: 0.5000
# Epoch 2/20
# 1/1 [==============================] - 0s 83ms/step - loss: 0.7456 - accuracy: 0.4375 - val_loss: 0.6984 - val_accuracy: 0.3750
# Epoch 3/20
# 1/1 [==============================] - 0s 79ms/step - loss: 0.6778 - accuracy: 0.6562 - val_loss: 0.7048 - val_accuracy: 0.5000
# Epoch 4/20
# 1/1 [==============================] - 0s 79ms/step - loss: 0.6684 - accuracy: 0.6250 - val_loss: 0.7121 - val_accuracy: 0.5000
# Epoch 5/20
# 1/1 [==============================] - 0s 84ms/step - loss: 0.6702 - accuracy: 0.6875 - val_loss: 0.6862 - val_accuracy: 0.5000
# Epoch 6/20
# 1/1 [==============================] - 0s 80ms/step - loss: 0.6992 - accuracy: 0.5625 - val_loss: 0.6805 - val_accuracy: 0.5000
# Epoch 7/20
# 1/1 [==============================] - 0s 75ms/step - loss: 0.6183 - accuracy: 0.6875 - val_loss: 0.6985 - val_accuracy: 0.3750
# Epoch 8/20
# 1/1 [==============================] - 0s 74ms/step - loss: 0.6773 - accuracy: 0.5938 - val_loss: 0.7262 - val_accuracy: 0.5000
# Epoch 9/20
# 1/1 [==============================] - ETA: 0s - loss: 0.6490 - accuracy: 0.6250Restoring model weights from the end of the best epoch: 6.
# 1/1 [==============================] - 0s 82ms/step - loss: 0.6490 - accuracy: 0.6250 - val_loss: 0.7271 - val_accuracy: 0.5000
# Epoch 9: early stopping
# 1/1 [==============================] - 0s 404ms/step
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6805 - accuracy: 0.5000
# Fold 1: Accuracy = 0.5000,       Precision = 0.4286,       Recall = 1.0000,       Specificity = 0.2000,       AUC = 0.8000,       F1 Score = 0.6000
# Confusion matrix:
# [[1 4]
#  [0 3]]
# Epoch 1/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.7143 - accuracy: 0.4688 - val_loss: 0.6489 - val_accuracy: 0.8750
# Epoch 2/20
# 1/1 [==============================] - 0s 75ms/step - loss: 0.6835 - accuracy: 0.4375 - val_loss: 0.6487 - val_accuracy: 0.8750
# Epoch 3/20
# 1/1 [==============================] - 0s 72ms/step - loss: 0.7229 - accuracy: 0.5312 - val_loss: 0.6463 - val_accuracy: 0.7500
# Epoch 4/20
# 1/1 [==============================] - 0s 78ms/step - loss: 0.7216 - accuracy: 0.5000 - val_loss: 0.6243 - val_accuracy: 1.0000
# Epoch 5/20
# 1/1 [==============================] - 0s 70ms/step - loss: 0.7481 - accuracy: 0.4688 - val_loss: 0.6436 - val_accuracy: 0.8750
# Epoch 6/20
# 1/1 [==============================] - 0s 69ms/step - loss: 0.7238 - accuracy: 0.5312 - val_loss: 0.6320 - val_accuracy: 0.8750
# Epoch 7/20
# 1/1 [==============================] - 0s 69ms/step - loss: 0.6972 - accuracy: 0.5625 - val_loss: 0.6208 - val_accuracy: 1.0000
# Epoch 8/20
# 1/1 [==============================] - 0s 72ms/step - loss: 0.7521 - accuracy: 0.3438 - val_loss: 0.6097 - val_accuracy: 0.8750
# Epoch 9/20
# 1/1 [==============================] - 0s 71ms/step - loss: 0.6672 - accuracy: 0.6250 - val_loss: 0.6242 - val_accuracy: 0.7500
# Epoch 10/20
# 1/1 [==============================] - 0s 65ms/step - loss: 0.6632 - accuracy: 0.6250 - val_loss: 0.6194 - val_accuracy: 0.8750
# Epoch 11/20
# 1/1 [==============================] - 0s 66ms/step - loss: 0.6573 - accuracy: 0.6562 - val_loss: 0.5926 - val_accuracy: 0.8750
# Epoch 12/20
# 1/1 [==============================] - 0s 65ms/step - loss: 0.6245 - accuracy: 0.6250 - val_loss: 0.5639 - val_accuracy: 0.8750
# Epoch 13/20
# 1/1 [==============================] - 0s 63ms/step - loss: 0.6620 - accuracy: 0.6562 - val_loss: 0.5440 - val_accuracy: 1.0000
# Epoch 14/20
# 1/1 [==============================] - 0s 70ms/step - loss: 0.6504 - accuracy: 0.5938 - val_loss: 0.5326 - val_accuracy: 1.0000
# Epoch 15/20
# 1/1 [==============================] - 0s 64ms/step - loss: 0.6444 - accuracy: 0.5938 - val_loss: 0.5249 - val_accuracy: 1.0000
# Epoch 16/20
# 1/1 [==============================] - 0s 65ms/step - loss: 0.6526 - accuracy: 0.5000 - val_loss: 0.5219 - val_accuracy: 0.8750
# Epoch 17/20
# 1/1 [==============================] - 0s 67ms/step - loss: 0.5930 - accuracy: 0.6250 - val_loss: 0.5013 - val_accuracy: 0.8750
# Epoch 18/20
# 1/1 [==============================] - 0s 66ms/step - loss: 0.6313 - accuracy: 0.7188 - val_loss: 0.4732 - val_accuracy: 1.0000
# Epoch 19/20
# 1/1 [==============================] - 0s 66ms/step - loss: 0.5364 - accuracy: 0.8125 - val_loss: 0.4772 - val_accuracy: 0.8750
# Epoch 20/20
# 1/1 [==============================] - 0s 69ms/step - loss: 0.5253 - accuracy: 0.8125 - val_loss: 0.4329 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 416ms/step
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4329 - accuracy: 1.0000
# Fold 2: Accuracy = 1.0000,       Precision = 1.0000,       Recall = 1.0000,       Specificity = 1.0000,       AUC = 1.0000,       F1 Score = 1.0000
# Confusion matrix:
# [[5 0]
#  [0 3]]
# Epoch 1/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.6932 - accuracy: 0.6562 - val_loss: 0.7043 - val_accuracy: 0.5000
# Epoch 2/20
# 1/1 [==============================] - 0s 74ms/step - loss: 0.6761 - accuracy: 0.5938 - val_loss: 0.6809 - val_accuracy: 0.5000
# Epoch 3/20
# 1/1 [==============================] - 0s 74ms/step - loss: 0.6489 - accuracy: 0.6250 - val_loss: 0.6714 - val_accuracy: 0.7500
# Epoch 4/20
# 1/1 [==============================] - 0s 71ms/step - loss: 0.6392 - accuracy: 0.6250 - val_loss: 0.6785 - val_accuracy: 0.6250
# Epoch 5/20
# 1/1 [==============================] - 0s 69ms/step - loss: 0.6470 - accuracy: 0.6250 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 6/20
# 1/1 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.5312Restoring model weights from the end of the best epoch: 3.
# 1/1 [==============================] - 0s 69ms/step - loss: 0.6937 - accuracy: 0.5312 - val_loss: 0.6895 - val_accuracy: 0.6250
# Epoch 6: early stopping
# 1/1 [==============================] - 0s 405ms/step
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6714 - accuracy: 0.7500
# Fold 3: Accuracy = 0.7500,       Precision = 0.7500,       Recall = 0.7500,       Specificity = 0.7500,       AUC = 0.7500,       F1 Score = 0.7500
# Confusion matrix:
# [[3 1]
#  [1 3]]
# Epoch 1/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.7557 - accuracy: 0.3750 - val_loss: 0.6980 - val_accuracy: 0.5000
# Epoch 2/20
# 1/1 [==============================] - 0s 71ms/step - loss: 0.7250 - accuracy: 0.4688 - val_loss: 0.7005 - val_accuracy: 0.2500
# Epoch 3/20
# 1/1 [==============================] - 0s 78ms/step - loss: 0.6861 - accuracy: 0.6250 - val_loss: 0.7015 - val_accuracy: 0.5000
# Epoch 4/20
# 1/1 [==============================] - ETA: 0s - loss: 0.6957 - accuracy: 0.5000Restoring model weights from the end of the best epoch: 1.
# 1/1 [==============================] - 0s 74ms/step - loss: 0.6957 - accuracy: 0.5000 - val_loss: 0.6983 - val_accuracy: 0.5000
# Epoch 4: early stopping
# 1/1 [==============================] - 1s 694ms/step
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6980 - accuracy: 0.5000
# Fold 4: Accuracy = 0.5000,       Precision = 0.5000,       Recall = 0.7500,       Specificity = 0.2500,       AUC = 0.5625,       F1 Score = 0.6000
# Confusion matrix:
# [[1 3]
#  [1 3]]
# Epoch 1/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.7139 - accuracy: 0.4062 - val_loss: 0.7019 - val_accuracy: 0.3750
# Epoch 2/20
# 1/1 [==============================] - 0s 76ms/step - loss: 0.6846 - accuracy: 0.5312 - val_loss: 0.6948 - val_accuracy: 0.5000
# Epoch 3/20
# 1/1 [==============================] - 0s 69ms/step - loss: 0.6937 - accuracy: 0.4062 - val_loss: 0.6973 - val_accuracy: 0.5000
# Epoch 4/20
# 1/1 [==============================] - 0s 69ms/step - loss: 0.6972 - accuracy: 0.5938 - val_loss: 0.6810 - val_accuracy: 0.7500
# Epoch 5/20
# 1/1 [==============================] - 0s 66ms/step - loss: 0.7169 - accuracy: 0.6250 - val_loss: 0.6860 - val_accuracy: 0.5000
# Epoch 6/20
# 1/1 [==============================] - 0s 68ms/step - loss: 0.6296 - accuracy: 0.6250 - val_loss: 0.6896 - val_accuracy: 0.5000
# Epoch 7/20
# 1/1 [==============================] - 0s 69ms/step - loss: 0.6950 - accuracy: 0.5312 - val_loss: 0.6791 - val_accuracy: 0.6250
# Epoch 8/20
# 1/1 [==============================] - 0s 69ms/step - loss: 0.6350 - accuracy: 0.6875 - val_loss: 0.6719 - val_accuracy: 0.6250
# Epoch 9/20
# 1/1 [==============================] - 0s 69ms/step - loss: 0.6864 - accuracy: 0.5312 - val_loss: 0.6669 - val_accuracy: 0.6250
# Epoch 10/20
# 1/1 [==============================] - 0s 68ms/step - loss: 0.6400 - accuracy: 0.6875 - val_loss: 0.6659 - val_accuracy: 0.6250
# Epoch 11/20
# 1/1 [==============================] - 0s 68ms/step - loss: 0.6285 - accuracy: 0.6250 - val_loss: 0.6831 - val_accuracy: 0.6250
# Epoch 12/20
# 1/1 [==============================] - 0s 66ms/step - loss: 0.6041 - accuracy: 0.6250 - val_loss: 0.6722 - val_accuracy: 0.6250
# Epoch 13/20
# 1/1 [==============================] - ETA: 0s - loss: 0.5301 - accuracy: 0.8438Restoring model weights from the end of the best epoch: 10.
# 1/1 [==============================] - 0s 70ms/step - loss: 0.5301 - accuracy: 0.8438 - val_loss: 0.6684 - val_accuracy: 0.6250
# Epoch 13: early stopping
# 1/1 [==============================] - 0s 431ms/step
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6659 - accuracy: 0.6250
# Fold 5: Accuracy = 0.6250,       Precision = 0.6000,       Recall = 0.7500,       Specificity = 0.5000,       AUC = 0.6875,       F1 Score = 0.6667
# Confusion matrix:
# [[2 2]
#  [1 3]]
# Average Accuracy: 0.6750 +/- 0.1871
# Average Precision: 0.6557 +/- 0.2032
# Average Recall/Sensitivity: 0.8500 +/- 0.1225
# Average Specificity: 0.5400 +/- 0.3023
# Average F1-score: 0.7233 +/- 0.1489
# Average ROC_AUC score: 0.7600 +/- 0.1439
# Overall confusion matrix:
# [[12 10]
#  [ 3 15]]

# %%
import seaborn as sns

sns.set(font_scale=1.4) # adjust font size as needed
sns.heatmap(overall_cm, annot=True, annot_kws={"size": 16}, cmap='Blues', fmt='g')
# Out:
# <Axes: >

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np

import tensorflow as tf

import random
# Set the random seeds for reproducibility
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

batch_size = 32
lstm_units = 32
neurons = 256

# Reshape the input data
X_train = np.reshape(X_train, (X_train.shape[0], 224, 224))
X_test = np.reshape(X_test, (X_test.shape[0], 224, 224))

# Define the model architecture
model = Sequential()
model.add(LSTM(lstm_units, input_shape=(224, 224)))
model.add(Dropout(0.5))
model.add(Dense(neurons, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(neurons*2, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
# model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model.summary()

# Compile the model
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# Set up early stopping
early_stopping = EarlyStopping(monitor='val_loss', restore_best_weights=True, verbose=1, patience=10)

# Train the model with early stopping
history = model.fit(X_train, y_train, 
                    epochs=20, 
                    batch_size=batch_size, 
                    validation_data=(X_test, y_test), 
                    callbacks=[early_stopping])

test_loss, test_acc = model.evaluate(X_test, y_test)
print("Test loss:", test_loss)
print("Test accuracy:", test_acc)
# Out:
# Model: "sequential_125"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_125 (LSTM)             (None, 32)                32896
#
#  dropout_375 (Dropout)       (None, 32)                0
#
#  dense_375 (Dense)           (None, 256)               8448
#
#  dropout_376 (Dropout)       (None, 256)               0
#
#  dense_376 (Dense)           (None, 512)               131584
#
#  dropout_377 (Dropout)       (None, 512)               0
#
#  dense_377 (Dense)           (None, 1)                 513
#
# =================================================================
# Total params: 173,441
# Trainable params: 173,441
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 3/3 [==============================] - 3s 337ms/step - loss: 0.7088 - accuracy: 0.5455 - val_loss: 0.6386 - val_accuracy: 0.8824
# Epoch 2/20
# 3/3 [==============================] - 0s 62ms/step - loss: 0.6836 - accuracy: 0.5455 - val_loss: 0.6661 - val_accuracy: 0.6471
# Epoch 3/20
# 3/3 [==============================] - 0s 56ms/step - loss: 0.6636 - accuracy: 0.6250 - val_loss: 0.7266 - val_accuracy: 0.3529
# Epoch 4/20
# 3/3 [==============================] - 0s 56ms/step - loss: 0.6646 - accuracy: 0.6250 - val_loss: 0.6402 - val_accuracy: 0.7059
# Epoch 5/20
# 3/3 [==============================] - 0s 57ms/step - loss: 0.6473 - accuracy: 0.6250 - val_loss: 0.6238 - val_accuracy: 0.7647
# Epoch 6/20
# 3/3 [==============================] - 0s 56ms/step - loss: 0.6474 - accuracy: 0.6477 - val_loss: 0.5845 - val_accuracy: 0.7647
# Epoch 7/20
# 3/3 [==============================] - 0s 56ms/step - loss: 0.6030 - accuracy: 0.6818 - val_loss: 0.5763 - val_accuracy: 0.8235
# Epoch 8/20
# 3/3 [==============================] - 0s 57ms/step - loss: 0.6651 - accuracy: 0.5909 - val_loss: 0.5564 - val_accuracy: 0.8235
# Epoch 9/20
# 3/3 [==============================] - 0s 56ms/step - loss: 0.6258 - accuracy: 0.5909 - val_loss: 0.5760 - val_accuracy: 0.7647
# Epoch 10/20
# 3/3 [==============================] - 0s 56ms/step - loss: 0.5935 - accuracy: 0.6818 - val_loss: 0.5685 - val_accuracy: 0.7059
# Epoch 11/20
# 3/3 [==============================] - 0s 56ms/step - loss: 0.5749 - accuracy: 0.7273 - val_loss: 0.5362 - val_accuracy: 0.7059
# Epoch 12/20
# 3/3 [==============================] - 0s 54ms/step - loss: 0.5678 - accuracy: 0.6591 - val_loss: 0.5537 - val_accuracy: 0.7647
# Epoch 13/20
# 3/3 [==============================] - 0s 56ms/step - loss: 0.4884 - accuracy: 0.7727 - val_loss: 0.5033 - val_accuracy: 0.7059
# Epoch 14/20
# 3/3 [==============================] - 0s 57ms/step - loss: 0.5214 - accuracy: 0.7386 - val_loss: 0.5479 - val_accuracy: 0.6471
# Epoch 15/20
# 3/3 [==============================] - 0s 58ms/step - loss: 0.4198 - accuracy: 0.8295 - val_loss: 0.4963 - val_accuracy: 0.7059
# Epoch 16/20
# 3/3 [==============================] - 0s 56ms/step - loss: 0.3975 - accuracy: 0.8409 - val_loss: 0.5372 - val_accuracy: 0.7647
# Epoch 17/20
# 3/3 [==============================] - 0s 57ms/step - loss: 0.4670 - accuracy: 0.7614 - val_loss: 0.5015 - val_accuracy: 0.7059
# Epoch 18/20
# 3/3 [==============================] - 0s 57ms/step - loss: 0.4464 - accuracy: 0.7841 - val_loss: 0.4653 - val_accuracy: 0.7647
# Epoch 19/20
# 3/3 [==============================] - 0s 57ms/step - loss: 0.3786 - accuracy: 0.8182 - val_loss: 0.5077 - val_accuracy: 0.8235
# Epoch 20/20
# 3/3 [==============================] - 0s 56ms/step - loss: 0.3886 - accuracy: 0.8295 - val_loss: 0.5531 - val_accuracy: 0.7059
# 1/1 [==============================] - 0s 28ms/step - loss: 0.5531 - accuracy: 0.7059
# Test loss: 0.553142786026001
# Test accuracy: 0.7058823704719543

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score

# Get the predictions
y_pred = model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)

# Print the confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)
print(cm)

# Print the classification report
print(classification_report(y_test, y_pred_classes))

# Calculate specificity
tn, fp, fn, tp = cm.ravel()
specificity = tn / (tn + fp)
print('Specificity:', specificity)

# Print the ROC AUC score
roc_auc = roc_auc_score(y_test, y_pred)
print('ROC AUC:', roc_auc)

import matplotlib.pyplot as plt

# Get the training and validation loss and accuracy values from the history object
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# Create the figure and axis objects
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Plot the training and validation loss
ax1.plot(train_loss, label='Training Loss')
ax1.plot(val_loss, label='Validation Loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()

# Plot the training and validation accuracy
ax2.plot(train_acc, label='Training Accuracy')
ax2.plot(val_acc, label='Validation Accuracy')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()

# Show the plot
plt.show()
# Out:
# 1/1 [==============================] - 0s 453ms/step
# [[9 3]
#  [2 3]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.75      0.78        12
#            1       0.50      0.60      0.55         5
#
#     accuracy                           0.71        17
#    macro avg       0.66      0.68      0.66        17
# weighted avg       0.72      0.71      0.71        17
#
# Specificity: 0.75
# ROC AUC: 0.8

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score
import numpy as np
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, BatchNormalization, MaxPooling1D, Dropout, Dense, Flatten
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold

# Set the random seeds for reproducibility
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

#K-fold cross-validation lists
score_list = []
precision_list = []
recall_list = []
f1_score_list = []
confusion_matrix_list = []
specificity_list = []
ROC_AUC_list = []

for fold, (train_idx, val_idx) in enumerate(kfold.split(X_train, y_train)):
    #splitting the data into train and validation sets for this fold
    X_train_fold, y_train_fold = X_train[train_idx], y_train[train_idx]
    X_val_fold, y_val_fold = X_train[val_idx], y_train[val_idx]

    #defining the early stopping callback
    early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True, verbose=1)

    #training the model for this fold
    model = create_model()
    history = model.fit(X_train_fold, y_train_fold, epochs=n_epochs, batch_size=batch_size, 
                        validation_data=(X_val_fold, y_val_fold), callbacks=[early_stop], verbose=1)

    #predicting the classes for the validation set for this fold
    y_pred = model.predict(X_val_fold)
    y_pred_classes = (y_pred > 0.5).astype(int)

    #calculating precision, recall, specificity, F1 score, AUC, and confusion matrix for this fold
    precision_list.append(precision_score(y_val_fold, y_pred_classes))
    recall_list.append(recall_score(y_val_fold, y_pred_classes))
    f1_score_list.append(f1_score(y_val_fold, y_pred_classes))
    tn, fp, fn, tp = confusion_matrix(y_val_fold, y_pred_classes).ravel()
    specificity = tn / (tn + fp)
    specificity_list.append(specificity)
    ROC_AUC_list.append(roc_auc_score(y_val_fold, y_pred))
    confusion_matrix_list.append(confusion_matrix(y_val_fold, y_pred_classes))

    #evaluating the model on the test set for this fold
    #_, test_acc = model.evaluate(X_test, y_test)
    _, test_acc = model.evaluate(X_val_fold, y_val_fold)
    score_list.append(test_acc)

    # Save the model
    model.save(f"model_fold_{fold + 1}.h5")

    #printing the metrics and confusion matrix for this fold
    print(f'Fold {fold + 1}: Accuracy = {test_acc:.4f}, \
      Precision = {precision_list[-1]:.4f}, \
      Recall = {recall_list[-1]:.4f}, \
      Specificity = {specificity_list[-1]:.4f}, \
      AUC = {ROC_AUC_list[-1]:.4f}, \
      F1 Score = {f1_score_list[-1]:.4f}')
    print(f'Confusion matrix:\n{confusion_matrix_list[-1]}')

#Print the average scores for all folds

print(f'Average Accuracy: {np.mean(score_list):.4f} +/- {np.std(score_list):.4f}')
print(f'Average Precision: {np.mean(precision_list):.4f} +/- {np.std(precision_list):.4f}')
print(f'Average Recall/Sensitivity: {np.mean(recall_list):.4f} +/- {np.std(recall_list):.4f}')
print(f'Average Specificity: {np.mean(specificity_list):.4f} +/- {np.std(specificity_list):.4f}')
print(f'Average F1-score: {np.mean(f1_score_list):.4f} +/- {np.std(f1_score_list):.4f}')
print(f'Average ROC_AUC score: {np.mean(ROC_AUC_list):.4f} +/- {np.std(ROC_AUC_list):.4f}')

#printing the overall confusion matrix

overall_cm = np.sum(confusion_matrix_list, axis=0)
print(f'Overall confusion matrix:\n{overall_cm}')
# Out:
# Epoch 1/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.7276 - accuracy: 0.4688 - val_loss: 0.6989 - val_accuracy: 0.5000
# Epoch 2/20
# 1/1 [==============================] - 0s 80ms/step - loss: 0.7456 - accuracy: 0.4375 - val_loss: 0.6984 - val_accuracy: 0.3750
# Epoch 3/20
# 1/1 [==============================] - 0s 77ms/step - loss: 0.6778 - accuracy: 0.6562 - val_loss: 0.7048 - val_accuracy: 0.5000
# Epoch 4/20
# 1/1 [==============================] - 0s 72ms/step - loss: 0.6684 - accuracy: 0.6250 - val_loss: 0.7121 - val_accuracy: 0.5000
# Epoch 5/20
# 1/1 [==============================] - 0s 72ms/step - loss: 0.6702 - accuracy: 0.6875 - val_loss: 0.6862 - val_accuracy: 0.5000
# Epoch 6/20
# 1/1 [==============================] - 0s 72ms/step - loss: 0.6992 - accuracy: 0.5625 - val_loss: 0.6805 - val_accuracy: 0.5000
# Epoch 7/20
# 1/1 [==============================] - 0s 75ms/step - loss: 0.6183 - accuracy: 0.6875 - val_loss: 0.6985 - val_accuracy: 0.3750
# Epoch 8/20
# 1/1 [==============================] - 0s 69ms/step - loss: 0.6773 - accuracy: 0.5938 - val_loss: 0.7262 - val_accuracy: 0.5000
# Epoch 9/20
# 1/1 [==============================] - ETA: 0s - loss: 0.6490 - accuracy: 0.6250Restoring model weights from the end of the best epoch: 6.
# 1/1 [==============================] - 0s 81ms/step - loss: 0.6490 - accuracy: 0.6250 - val_loss: 0.7271 - val_accuracy: 0.5000
# Epoch 9: early stopping
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6805 - accuracy: 0.5000
# Fold 1: Accuracy = 0.5000,       Precision = 0.4286,       Recall = 1.0000,       Specificity = 0.2000,       AUC = 0.8000,       F1 Score = 0.6000
# Confusion matrix:
# [[1 4]
#  [0 3]]
# Epoch 1/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.7143 - accuracy: 0.4688 - val_loss: 0.6489 - val_accuracy: 0.8750
# Epoch 2/20
# 1/1 [==============================] - 0s 80ms/step - loss: 0.6835 - accuracy: 0.4375 - val_loss: 0.6487 - val_accuracy: 0.8750
# Epoch 3/20
# 1/1 [==============================] - 0s 82ms/step - loss: 0.7229 - accuracy: 0.5312 - val_loss: 0.6463 - val_accuracy: 0.7500
# Epoch 4/20
# 1/1 [==============================] - 0s 75ms/step - loss: 0.7216 - accuracy: 0.5000 - val_loss: 0.6243 - val_accuracy: 1.0000
# Epoch 5/20
# 1/1 [==============================] - 0s 74ms/step - loss: 0.7481 - accuracy: 0.4688 - val_loss: 0.6436 - val_accuracy: 0.8750
# Epoch 6/20
# 1/1 [==============================] - 0s 70ms/step - loss: 0.7238 - accuracy: 0.5312 - val_loss: 0.6320 - val_accuracy: 0.8750
# Epoch 7/20
# 1/1 [==============================] - 0s 73ms/step - loss: 0.6972 - accuracy: 0.5625 - val_loss: 0.6208 - val_accuracy: 1.0000
# Epoch 8/20
# 1/1 [==============================] - 0s 74ms/step - loss: 0.7521 - accuracy: 0.3438 - val_loss: 0.6097 - val_accuracy: 0.8750
# Epoch 9/20
# 1/1 [==============================] - 0s 74ms/step - loss: 0.6672 - accuracy: 0.6250 - val_loss: 0.6242 - val_accuracy: 0.7500
# Epoch 10/20
# 1/1 [==============================] - 0s 71ms/step - loss: 0.6632 - accuracy: 0.6250 - val_loss: 0.6194 - val_accuracy: 0.8750
# Epoch 11/20
# 1/1 [==============================] - 0s 72ms/step - loss: 0.6573 - accuracy: 0.6562 - val_loss: 0.5926 - val_accuracy: 0.8750
# Epoch 12/20
# 1/1 [==============================] - 0s 73ms/step - loss: 0.6245 - accuracy: 0.6250 - val_loss: 0.5639 - val_accuracy: 0.8750
# Epoch 13/20
# 1/1 [==============================] - 0s 74ms/step - loss: 0.6620 - accuracy: 0.6562 - val_loss: 0.5440 - val_accuracy: 1.0000
# Epoch 14/20
# 1/1 [==============================] - 0s 76ms/step - loss: 0.6504 - accuracy: 0.5938 - val_loss: 0.5326 - val_accuracy: 1.0000
# Epoch 15/20
# 1/1 [==============================] - 0s 72ms/step - loss: 0.6444 - accuracy: 0.5938 - val_loss: 0.5249 - val_accuracy: 1.0000
# Epoch 16/20
# 1/1 [==============================] - 0s 74ms/step - loss: 0.6526 - accuracy: 0.5000 - val_loss: 0.5219 - val_accuracy: 0.8750
# Epoch 17/20
# 1/1 [==============================] - 0s 72ms/step - loss: 0.5930 - accuracy: 0.6250 - val_loss: 0.5013 - val_accuracy: 0.8750
# Epoch 18/20
# 1/1 [==============================] - 0s 72ms/step - loss: 0.6313 - accuracy: 0.7188 - val_loss: 0.4732 - val_accuracy: 1.0000
# Epoch 19/20
# 1/1 [==============================] - 0s 73ms/step - loss: 0.5364 - accuracy: 0.8125 - val_loss: 0.4772 - val_accuracy: 0.8750
# Epoch 20/20
# 1/1 [==============================] - 0s 74ms/step - loss: 0.5253 - accuracy: 0.8125 - val_loss: 0.4329 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4329 - accuracy: 1.0000
# Fold 2: Accuracy = 1.0000,       Precision = 1.0000,       Recall = 1.0000,       Specificity = 1.0000,       AUC = 1.0000,       F1 Score = 1.0000
# Confusion matrix:
# [[5 0]
#  [0 3]]
# Epoch 1/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.6932 - accuracy: 0.6562 - val_loss: 0.7043 - val_accuracy: 0.5000
# Epoch 2/20
# 1/1 [==============================] - 0s 78ms/step - loss: 0.6761 - accuracy: 0.5938 - val_loss: 0.6809 - val_accuracy: 0.5000
# Epoch 3/20
# 1/1 [==============================] - 0s 73ms/step - loss: 0.6489 - accuracy: 0.6250 - val_loss: 0.6714 - val_accuracy: 0.7500
# Epoch 4/20
# 1/1 [==============================] - 0s 71ms/step - loss: 0.6392 - accuracy: 0.6250 - val_loss: 0.6785 - val_accuracy: 0.6250
# Epoch 5/20
# 1/1 [==============================] - 0s 71ms/step - loss: 0.6470 - accuracy: 0.6250 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 6/20
# 1/1 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.5312Restoring model weights from the end of the best epoch: 3.
# 1/1 [==============================] - 0s 76ms/step - loss: 0.6937 - accuracy: 0.5312 - val_loss: 0.6895 - val_accuracy: 0.6250
# Epoch 6: early stopping
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6714 - accuracy: 0.7500
# Fold 3: Accuracy = 0.7500,       Precision = 0.7500,       Recall = 0.7500,       Specificity = 0.7500,       AUC = 0.7500,       F1 Score = 0.7500
# Confusion matrix:
# [[3 1]
#  [1 3]]
# Epoch 1/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.7557 - accuracy: 0.3750 - val_loss: 0.6980 - val_accuracy: 0.5000
# Epoch 2/20
# 1/1 [==============================] - 0s 79ms/step - loss: 0.7250 - accuracy: 0.4688 - val_loss: 0.7005 - val_accuracy: 0.2500
# Epoch 3/20
# 1/1 [==============================] - 0s 76ms/step - loss: 0.6861 - accuracy: 0.6250 - val_loss: 0.7015 - val_accuracy: 0.5000
# Epoch 4/20
# 1/1 [==============================] - ETA: 0s - loss: 0.6957 - accuracy: 0.5000Restoring model weights from the end of the best epoch: 1.
# 1/1 [==============================] - 0s 74ms/step - loss: 0.6957 - accuracy: 0.5000 - val_loss: 0.6983 - val_accuracy: 0.5000
# Epoch 4: early stopping
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6980 - accuracy: 0.5000
# Fold 4: Accuracy = 0.5000,       Precision = 0.5000,       Recall = 0.7500,       Specificity = 0.2500,       AUC = 0.5625,       F1 Score = 0.6000
# Confusion matrix:
# [[1 3]
#  [1 3]]
# Epoch 1/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.7139 - accuracy: 0.4062 - val_loss: 0.7019 - val_accuracy: 0.3750
# Epoch 2/20
# 1/1 [==============================] - 0s 81ms/step - loss: 0.6846 - accuracy: 0.5312 - val_loss: 0.6948 - val_accuracy: 0.5000
# Epoch 3/20
# 1/1 [==============================] - 0s 78ms/step - loss: 0.6937 - accuracy: 0.4062 - val_loss: 0.6973 - val_accuracy: 0.5000
# Epoch 4/20
# 1/1 [==============================] - 0s 77ms/step - loss: 0.6972 - accuracy: 0.5938 - val_loss: 0.6810 - val_accuracy: 0.7500
# Epoch 5/20
# 1/1 [==============================] - 0s 76ms/step - loss: 0.7169 - accuracy: 0.6250 - val_loss: 0.6860 - val_accuracy: 0.5000
# Epoch 6/20
# 1/1 [==============================] - 0s 73ms/step - loss: 0.6296 - accuracy: 0.6250 - val_loss: 0.6896 - val_accuracy: 0.5000
# Epoch 7/20
# 1/1 [==============================] - 0s 76ms/step - loss: 0.6950 - accuracy: 0.5312 - val_loss: 0.6791 - val_accuracy: 0.6250
# Epoch 8/20
# 1/1 [==============================] - 0s 78ms/step - loss: 0.6350 - accuracy: 0.6875 - val_loss: 0.6719 - val_accuracy: 0.6250
# Epoch 9/20
# 1/1 [==============================] - 0s 73ms/step - loss: 0.6864 - accuracy: 0.5312 - val_loss: 0.6669 - val_accuracy: 0.6250
# Epoch 10/20
# 1/1 [==============================] - 0s 73ms/step - loss: 0.6400 - accuracy: 0.6875 - val_loss: 0.6659 - val_accuracy: 0.6250
# Epoch 11/20
# 1/1 [==============================] - 0s 72ms/step - loss: 0.6285 - accuracy: 0.6250 - val_loss: 0.6831 - val_accuracy: 0.6250
# Epoch 12/20
# 1/1 [==============================] - 0s 73ms/step - loss: 0.6041 - accuracy: 0.6250 - val_loss: 0.6722 - val_accuracy: 0.6250
# Epoch 13/20
# 1/1 [==============================] - ETA: 0s - loss: 0.5301 - accuracy: 0.8438Restoring model weights from the end of the best epoch: 10.
# 1/1 [==============================] - 0s 75ms/step - loss: 0.5301 - accuracy: 0.8438 - val_loss: 0.6684 - val_accuracy: 0.6250
# Epoch 13: early stopping
# 1/1 [==============================] - 0s 428ms/step
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6659 - accuracy: 0.6250
# Fold 5: Accuracy = 0.6250,       Precision = 0.6000,       Recall = 0.7500,       Specificity = 0.5000,       AUC = 0.6875,       F1 Score = 0.6667
# Confusion matrix:
# [[2 2]
#  [1 3]]
# Average Accuracy: 0.6750 +/- 0.1871
# Average Precision: 0.6557 +/- 0.2032
# Average Recall/Sensitivity: 0.8500 +/- 0.1225
# Average Specificity: 0.5400 +/- 0.3023
# Average F1-score: 0.7233 +/- 0.1489
# Average ROC_AUC score: 0.7600 +/- 0.1439
# Overall confusion matrix:
# [[12 10]
#  [ 3 15]]
