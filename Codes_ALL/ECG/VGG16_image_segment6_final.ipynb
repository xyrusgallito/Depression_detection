# %%
# pip install librosa

# %%
#pip install opencv-python

# %%
# #This is for STFT

# import os
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import librosa
# import librosa.display
# from PIL import Image

# # Set the input and output directories
# gen_dir = "/Users/xaichotic/Library/CloudStorage/OneDrive-NorthumbriaUniversity-ProductionAzureAD/Term3/"

# input_folder = os.path.join(gen_dir, "Data_ALL/ECG/ECG_csv_files_labeled_baseline6_pantompkins")
# output_folder = os.path.join(gen_dir, "Data_ALL/ECG_images_baseline6_STFT")

# # Create output directory if it does not exist
# if not os.path.exists(output_folder):
#     os.makedirs(output_folder)

# # Define the parameters for the STFT
# n_fft = 1024
# hop_length = 512

# # Loop through all the CSV files in the folder
# for filename in os.listdir(input_folder):
#     if filename.endswith(".csv"):
#         # Load the CSV file as a NumPy array
#         file_path = os.path.join(input_folder, filename)
#         ecg_signal = pd.read_csv(file_path, header=None).values.flatten()

#         # Compute the STFT
#         stft = librosa.stft(ecg_signal, n_fft=n_fft, hop_length=hop_length)
#         stft_mag_db = librosa.amplitude_to_db(np.abs(stft), ref=np.max)

#         # Normalize the STFT to [0, 1] range
#         stft_norm = (stft_mag_db - np.min(stft_mag_db)) / np.ptp(stft_mag_db)

#         # Convert the STFT to a 8-bit grayscale image
#         stft_img = (stft_norm * 255).astype(np.uint8)

#         # Save the image as a PNG file
#         output_filename = os.path.splitext(filename)[0] + ".png"
#         output_path = os.path.join(output_folder, output_filename)
#         Image.fromarray(stft_img, mode="L").save(output_path)

#         print(f"Processed {filename} and saved {output_filename}")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.12.0

# %%
#counting the length of the files EDA
#62, it matches the number of files in csv

gen_dir = "/Users/w20009829/OneDrive - Northumbria University - Production Azure AD/Term3/"

# Set the input and output directories
#gen_dir = "/Users/xaichotic/Library/CloudStorage/OneDrive-NorthumbriaUniversity-ProductionAzureAD/Term3/"

import os
folder_path = os.path.join(gen_dir, "Data_ALL/ECG_images_segment6_STFT")

# Count the number of files in the folder
num_files = len([f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))])

print(f"There are {num_files} files in the {folder_path} folder.")
# Out:
# There are 81 files in the /Users/w20009829/OneDrive - Northumbria University - Production Azure AD/Term3/Data_ALL/ECG_images_segment6_STFT folder.

# %%
import os

data_dir = os.path.join(gen_dir, "Data_ALL/ECG_images_segment6_STFT")

class_counts = {0: 0, 1: 0}

for file_name in os.listdir(data_dir):
    if file_name.endswith(".png"):
        class_label = int(file_name.split("_")[-1].split(".")[0])
        class_counts[class_label] += 1

print(f"Class 0: {class_counts[0]} files")
print(f"Class 1: {class_counts[1]} files")
# Out:
# Class 0: 56 files
# Class 1: 25 files

# %%
import cv2
import numpy as np
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

# Set the data directory path
data_dir = os.path.join(gen_dir, "Data_ALL/ECG_images_segment6_STFT")

X = []
y = []

# Go through all the files in the directory
for file_name in os.listdir(data_dir):
    if file_name.endswith(".png"):
        # Extract the label from the file name
        label = int(file_name.split("_")[-1][0])
        # Load the image file and preprocess it
        file_path = os.path.join(data_dir, file_name)
        img_gray = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
        img_gray = cv2.resize(img_gray, (224, 224))
        img_rgb = cv2.cvtColor(img_gray, cv2.COLOR_GRAY2RGB) # Convert grayscale to RGB
        img_rgb = np.array(img_rgb).reshape(-1)
        # Save the preprocessed image and label in a list
        X.append(img_rgb)
        y.append(label)

# Convert the data to numpy arrays
X = np.array(X)
y = np.array(y)

# %%
from imblearn.under_sampling import RandomUnderSampler

# Apply random under-sampling to the data
rus = RandomUnderSampler()
X_resampled, y_resampled = rus.fit_resample(X, y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# %%
# Print the shape and class counts of the resampled data
print("Resampled data shape:", X_resampled.shape)
unique, counts = np.unique(y_resampled, return_counts=True)
print("Class counts:", dict(zip(unique, counts)))
# Out:
# Resampled data shape: (50, 150528)
# Class counts: {0: 25, 1: 25}

# %%
# Count the number of instances for each class in the resampled training data
class_counts = np.bincount(y_resampled)
print("Class distribution after Random Undersampling:", class_counts)
# Out:
# Class distribution after Random Undersampling: [25 25]

# %%
# Reshape the data into a 4D tensor
X_train = X_train.reshape((-1, 224, 224, 3))
X_test = X_test.reshape((-1, 224, 224, 3))

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (40, 224, 224, 3)
# (40,)
# (10, 224, 224, 3)
# (10,)

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adagrad
from tensorflow.keras.callbacks import EarlyStopping

import tensorflow as tf
import random

# Set the random seeds for reproducibility
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

batch_size = 32

# Create VGG16 model
vgg_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of VGG16 model
for layer in vgg_model.layers:
    layer.trainable = False

# Add custom layers on top of VGG16 model
model = Sequential()
model.add(vgg_model)
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
opt = SGD(learning_rate=0.001)
#opt = SGD(learning_rate=0.0001)
#opt = SGD(learning_rate=0.01)
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])

# Set up early stopping
early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

# Train the model with early stopping
history = model.fit(X_train, y_train, 
                    epochs=25, 
                    batch_size=batch_size, 
                    validation_data=(X_test, y_test), 
                    callbacks=[early_stopping])

test_loss, test_acc = model.evaluate(X_test, y_test)
print("Test loss:", test_loss)
print("Test accuracy:", test_acc)
# Out:
# Epoch 1/25
# 2/2 [==============================] - 9s 3s/step - loss: 10.3353 - accuracy: 0.4750 - val_loss: 9.7167 - val_accuracy: 0.3000
# Epoch 2/25
# 2/2 [==============================] - 7s 3s/step - loss: 7.3127 - accuracy: 0.5000 - val_loss: 6.0657 - val_accuracy: 0.3000
# Epoch 3/25
# 2/2 [==============================] - 6s 2s/step - loss: 6.0605 - accuracy: 0.4750 - val_loss: 4.9095 - val_accuracy: 0.3000
# Epoch 4/25
# 2/2 [==============================] - 5s 2s/step - loss: 1.4676 - accuracy: 0.6250 - val_loss: 2.5685 - val_accuracy: 0.3000
# Epoch 5/25
# 2/2 [==============================] - 4s 2s/step - loss: 1.4307 - accuracy: 0.6250 - val_loss: 1.1823 - val_accuracy: 0.4000
# Epoch 6/25
# 2/2 [==============================] - 4s 2s/step - loss: 0.7195 - accuracy: 0.7250 - val_loss: 1.2146 - val_accuracy: 0.3000
# Epoch 7/25
# 2/2 [==============================] - 4s 2s/step - loss: 0.9241 - accuracy: 0.6500 - val_loss: 1.0183 - val_accuracy: 0.3000
# Epoch 8/25
# 2/2 [==============================] - 4s 2s/step - loss: 0.4348 - accuracy: 0.8250 - val_loss: 1.6527 - val_accuracy: 0.3000
# Epoch 9/25
# 2/2 [==============================] - 4s 2s/step - loss: 0.2788 - accuracy: 0.8750 - val_loss: 1.1279 - val_accuracy: 0.1000
# Epoch 10/25
# 2/2 [==============================] - 4s 2s/step - loss: 0.3336 - accuracy: 0.8500 - val_loss: 1.1842 - val_accuracy: 0.1000
# Epoch 11/25
# 2/2 [==============================] - 4s 2s/step - loss: 0.2433 - accuracy: 0.8750 - val_loss: 1.2790 - val_accuracy: 0.3000
# Epoch 12/25
# 2/2 [==============================] - 4s 2s/step - loss: 0.1881 - accuracy: 0.9500 - val_loss: 2.5031 - val_accuracy: 0.3000
# Epoch 13/25
# 2/2 [==============================] - 4s 2s/step - loss: 0.3897 - accuracy: 0.7750 - val_loss: 1.2700 - val_accuracy: 0.1000
# Epoch 14/25
# 2/2 [==============================] - 4s 2s/step - loss: 0.1935 - accuracy: 0.9500 - val_loss: 1.3679 - val_accuracy: 0.1000
# Epoch 15/25
# 2/2 [==============================] - 4s 2s/step - loss: 0.1407 - accuracy: 0.9750 - val_loss: 1.4153 - val_accuracy: 0.2000
# Epoch 16/25
# 2/2 [==============================] - 4s 2s/step - loss: 0.1372 - accuracy: 0.9500 - val_loss: 1.6433 - val_accuracy: 0.2000
# Epoch 17/25
# 2/2 [==============================] - 4s 1s/step - loss: 0.1307 - accuracy: 0.9750 - val_loss: 1.7642 - val_accuracy: 0.3000
# Epoch 17: early stopping
# 1/1 [==============================] - 1s 811ms/step - loss: 1.7642 - accuracy: 0.3000
# Test loss: 1.7642332315444946
# Test accuracy: 0.30000001192092896

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score

# Get the predictions
y_pred = model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)

# Print the confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)
print(cm)

# Print the classification report
print(classification_report(y_test, y_pred_classes))

# Print the ROC AUC score
roc_auc = roc_auc_score(y_test, y_pred)
print('ROC AUC:', roc_auc)

import matplotlib.pyplot as plt

# Get the training and validation loss and accuracy values from the history object
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# Create the figure and axis objects
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Plot the training and validation loss
ax1.plot(train_loss, label='Training Loss')
ax1.plot(val_loss, label='Validation Loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()

# Plot the training and validation accuracy
ax2.plot(train_acc, label='Training Accuracy')
ax2.plot(val_acc, label='Validation Accuracy')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()

# Show the plot
plt.show()
# Out:
# 1/1 [==============================] - 1s 829ms/step
# [[3 0]
#  [7 0]]
#               precision    recall  f1-score   support
#
#            0       0.30      1.00      0.46         3
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.30        10
#    macro avg       0.15      0.50      0.23        10
# weighted avg       0.09      0.30      0.14        10
#
# ROC AUC: 0.23809523809523814
# C:\Anaconda3\envs\xyrus\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Anaconda3\envs\xyrus\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Anaconda3\envs\xyrus\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# cross-validation

# %%
#model for basic CNN

import numpy as np
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, BatchNormalization, MaxPooling1D, Dropout, Dense, Flatten
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold

# Set the random seeds for reproducibility
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)


batch_size = 32
num_folds = 10
n_epochs =20
neurons = 256

# Create VGG16 model
vgg_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of VGG16 model
for layer in vgg_model.layers:
    layer.trainable = False

# Define the CNN model
def create_model():
    model = Sequential()
    model.add(vgg_model)
    model.add(Flatten())
    model.add(Dense(neurons, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer=SGD(learning_rate=0.001), metrics=['accuracy'])
    return model

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score
import numpy as np
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, BatchNormalization, MaxPooling1D, Dropout, Dense, Flatten
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold

# Set the random seeds for reproducibility
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state = 42)

#K-fold cross-validation lists
score_list = []
precision_list = []
recall_list = []
f1_score_list = []
confusion_matrix_list = []
specificity_list = []
ROC_AUC_list = []


for fold, (train_idx, val_idx) in enumerate(kfold.split(X_train, y_train)):
    #splitting the data into train and validation sets for this fold
    X_train_fold, y_train_fold = X_train[train_idx], y_train[train_idx]
    X_val_fold, y_val_fold = X_train[val_idx], y_train[val_idx]
    
    #defining the early stopping callback
    early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True, verbose=1)
    
    #training the model for this fold
    model = create_model()
    history = model.fit(X_train_fold, y_train_fold, epochs=n_epochs, batch_size=batch_size, 
                        validation_data=(X_val_fold, y_val_fold), callbacks=[early_stop], verbose=1)
    
    #predicting the classes for the validation set for this fold
    y_pred = model.predict(X_val_fold)
    y_pred_classes = (y_pred > 0.5).astype(int)
    
    #calculating precision, recall, specificity, F1 score, AUC, and confusion matrix for this fold
    precision_list.append(precision_score(y_val_fold, y_pred_classes))
    recall_list.append(recall_score(y_val_fold, y_pred_classes))
    f1_score_list.append(f1_score(y_val_fold, y_pred_classes))
    #tp, fp, fn, tn = confusion_matrix(y_val_fold, y_pred_classes).ravel()
    tn, fp, fn, tp = confusion_matrix(y_val_fold, y_pred_classes).ravel()
    specificity = tn / (tn + fp)
    specificity_list.append(specificity)
    ROC_AUC_list.append(roc_auc_score(y_val_fold, y_pred))
    confusion_matrix_list.append(confusion_matrix(y_val_fold, y_pred_classes))

    #evaluating the model on the test set for this fold
    #_, test_acc = model.evaluate(X_test, y_test)
    _, test_acc = model.evaluate(X_val_fold, y_val_fold)

    score_list.append(test_acc)
    
    #printing the metrics and confusion matrix for this fold
    print(f'Fold {fold + 1}: Accuracy = {test_acc:.4f}, \
      Precision = {precision_list[-1]:.4f}, \
      Recall = {recall_list[-1]:.4f}, \
      Specificity = {specificity_list[-1]:.4f}, \
      AUC = {ROC_AUC_list[-1]:.4f}, \
      F1 Score = {f1_score_list[-1]:.4f}')
    print(f'Confusion matrix:\n{confusion_matrix_list[-1]}')
    
#Print the average scores for all folds

print(f'Average Accuracy: {np.mean(score_list):.4f} +/- {np.std(score_list):.4f}')
print(f'Average Precision: {np.mean(precision_list):.4f} +/- {np.std(precision_list):.4f}')
print(f'Average Recall/Sensitivity: {np.mean(recall_list):.4f} +/- {np.std(recall_list):.4f}')
print(f'Average Specificity: {np.mean(specificity_list):.4f} +/- {np.std(specificity_list):.4f}')
print(f'Average F1-score: {np.mean(f1_score_list):.4f} +/- {np.std(f1_score_list):.4f}')
print(f'Average ROC_AUC score: {np.mean(ROC_AUC_list):.4f} +/- {np.std(ROC_AUC_list):.4f}')

#printing the overall confusion matrix

overall_cm = np.sum(confusion_matrix_list, axis=0)
print(f'Overall confusion matrix:\n{overall_cm}')
# Out:
# Epoch 1/20
# 2/2 [==============================] - 5s 1s/step - loss: 3.8698 - accuracy: 0.5278 - val_loss: 13.6238 - val_accuracy: 0.7500
# Epoch 2/20
# 2/2 [==============================] - 5s 985ms/step - loss: 25.1325 - accuracy: 0.4167 - val_loss: 14.1065 - val_accuracy: 0.7500
# Epoch 3/20
# 2/2 [==============================] - 5s 1s/step - loss: 24.3251 - accuracy: 0.5000 - val_loss: 8.1187 - val_accuracy: 0.7500
# Epoch 4/20
# 2/2 [==============================] - 6s 2s/step - loss: 11.2406 - accuracy: 0.5278 - val_loss: 5.8399 - val_accuracy: 0.2500
# Epoch 5/20
# 2/2 [==============================] - 6s 2s/step - loss: 4.8246 - accuracy: 0.5000 - val_loss: 6.0035 - val_accuracy: 0.2500
# Epoch 6/20
# 2/2 [==============================] - 7s 2s/step - loss: 1.7208 - accuracy: 0.6111 - val_loss: 2.7507 - val_accuracy: 0.5000
# Epoch 7/20
# 2/2 [==============================] - 7s 2s/step - loss: 1.2360 - accuracy: 0.6944 - val_loss: 1.9332 - val_accuracy: 0.2500
# Epoch 8/20
# 2/2 [==============================] - 7s 2s/step - loss: 1.6431 - accuracy: 0.5833 - val_loss: 8.9987 - val_accuracy: 0.2500
# Epoch 9/20
# 2/2 [==============================] - 7s 2s/step - loss: 3.1538 - accuracy: 0.5278 - val_loss: 1.9113 - val_accuracy: 0.5000
# Epoch 10/20
# 2/2 [==============================] - 9s 2s/step - loss: 0.2155 - accuracy: 0.8333 - val_loss: 4.9353 - val_accuracy: 0.2500
# Epoch 11/20
# 2/2 [==============================] - 8s 2s/step - loss: 1.2528 - accuracy: 0.7222 - val_loss: 1.7987 - val_accuracy: 0.7500
# Epoch 12/20
# 2/2 [==============================] - 7s 2s/step - loss: 2.3589 - accuracy: 0.6111 - val_loss: 1.2397 - val_accuracy: 0.5000
# Epoch 13/20
# 2/2 [==============================] - 7s 2s/step - loss: 0.4770 - accuracy: 0.7778 - val_loss: 1.8799 - val_accuracy: 0.7500
# Epoch 14/20
# 2/2 [==============================] - 5s 808ms/step - loss: 1.3784 - accuracy: 0.6111 - val_loss: 1.7167 - val_accuracy: 0.2500
# Epoch 15/20
# 2/2 [==============================] - ETA: 0s - loss: 0.3410 - accuracy: 0.8889Restoring model weights from the end of the best epoch: 12.
# 2/2 [==============================] - 6s 2s/step - loss: 0.3410 - accuracy: 0.8889 - val_loss: 1.7685 - val_accuracy: 0.2500
# Epoch 15: early stopping
# 1/1 [==============================] - 1s 614ms/step
# 1/1 [==============================] - 1s 588ms/step - loss: 1.2397 - accuracy: 0.5000
# Fold 1: Accuracy = 0.5000,       Precision = 0.0000,       Recall = 0.0000,       Specificity = 0.6667,       AUC = 0.0000,       F1 Score = 0.0000
# Confusion matrix:
# [[2 1]
#  [1 0]]
# Epoch 1/20
# 2/2 [==============================] - 8s 2s/step - loss: 2.8175 - accuracy: 0.6944 - val_loss: 45.8482 - val_accuracy: 0.2500
# Epoch 2/20
# 2/2 [==============================] - 6s 2s/step - loss: 28.2374 - accuracy: 0.5278 - val_loss: 8.6610 - val_accuracy: 0.2500
# Epoch 3/20
# 2/2 [==============================] - 6s 2s/step - loss: 6.9711 - accuracy: 0.4722 - val_loss: 0.4594 - val_accuracy: 0.7500
# Epoch 4/20
# 2/2 [==============================] - 6s 1s/step - loss: 4.1683 - accuracy: 0.6111 - val_loss: 4.0355 - val_accuracy: 0.7500
# Epoch 5/20
# 2/2 [==============================] - 6s 1s/step - loss: 6.5265 - accuracy: 0.5833 - val_loss: 5.9158 - val_accuracy: 0.7500
# Epoch 6/20
# 2/2 [==============================] - ETA: 0s - loss: 5.8292 - accuracy: 0.6389Restoring model weights from the end of the best epoch: 3.
# 2/2 [==============================] - 6s 969ms/step - loss: 5.8292 - accuracy: 0.6389 - val_loss: 3.1440 - val_accuracy: 0.7500
# Epoch 6: early stopping
# 1/1 [==============================] - 1s 961ms/step
# 1/1 [==============================] - 0s 421ms/step - loss: 0.4594 - accuracy: 0.7500
# Fold 2: Accuracy = 0.7500,       Precision = 0.5000,       Recall = 1.0000,       Specificity = 0.6667,       AUC = 1.0000,       F1 Score = 0.6667
# Confusion matrix:
# [[2 1]
#  [0 1]]
# Epoch 1/20
# 2/2 [==============================] - 7s 2s/step - loss: 4.1072 - accuracy: 0.3889 - val_loss: 35.0752 - val_accuracy: 0.5000
# Epoch 2/20
# 2/2 [==============================] - 7s 1s/step - loss: 24.7441 - accuracy: 0.5000 - val_loss: 4.3814 - val_accuracy: 0.2500
# Epoch 3/20
# 2/2 [==============================] - 6s 1s/step - loss: 6.4351 - accuracy: 0.5556 - val_loss: 20.9581 - val_accuracy: 0.5000
# Epoch 4/20
# 2/2 [==============================] - 6s 2s/step - loss: 16.6115 - accuracy: 0.4444 - val_loss: 38.1420 - val_accuracy: 0.5000
# Epoch 5/20
# 2/2 [==============================] - ETA: 0s - loss: 24.5169 - accuracy: 0.5556Restoring model weights from the end of the best epoch: 2.
# 2/2 [==============================] - 6s 2s/step - loss: 24.5169 - accuracy: 0.5556 - val_loss: 7.2503 - val_accuracy: 0.2500
# Epoch 5: early stopping
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 800ms/step - loss: 4.3814 - accuracy: 0.2500
# Fold 3: Accuracy = 0.2500,       Precision = 0.0000,       Recall = 0.0000,       Specificity = 0.5000,       AUC = 0.2500,       F1 Score = 0.0000
# Confusion matrix:
# [[1 1]
#  [2 0]]
# Epoch 1/20
# 2/2 [==============================] - 9s 2s/step - loss: 11.9918 - accuracy: 0.4444 - val_loss: 10.2452 - val_accuracy: 0.5000
# Epoch 2/20
# 2/2 [==============================] - 7s 2s/step - loss: 9.8431 - accuracy: 0.5833 - val_loss: 3.9627 - val_accuracy: 0.5000
# Epoch 3/20
# 2/2 [==============================] - 5s 910ms/step - loss: 4.5975 - accuracy: 0.5556 - val_loss: 7.1751 - val_accuracy: 0.5000
# Epoch 4/20
# 2/2 [==============================] - 6s 2s/step - loss: 4.7388 - accuracy: 0.5833 - val_loss: 5.3309 - val_accuracy: 0.5000
# Epoch 5/20
# 2/2 [==============================] - 6s 2s/step - loss: 4.0021 - accuracy: 0.6667 - val_loss: 1.4496 - val_accuracy: 0.5000
# Epoch 6/20
# 2/2 [==============================] - 6s 2s/step - loss: 2.2340 - accuracy: 0.6944 - val_loss: 8.9326 - val_accuracy: 0.5000
# Epoch 7/20
# 2/2 [==============================] - 6s 2s/step - loss: 6.3597 - accuracy: 0.5833 - val_loss: 3.4601 - val_accuracy: 0.5000
# Epoch 8/20
# 2/2 [==============================] - 7s 2s/step - loss: 5.9636 - accuracy: 0.5000 - val_loss: 0.8837 - val_accuracy: 0.2500
# Epoch 9/20
# 2/2 [==============================] - 6s 2s/step - loss: 0.2949 - accuracy: 0.8611 - val_loss: 0.7959 - val_accuracy: 0.5000
# Epoch 10/20
# 2/2 [==============================] - 5s 834ms/step - loss: 1.5306 - accuracy: 0.6667 - val_loss: 4.1927 - val_accuracy: 0.5000
# Epoch 11/20
# 2/2 [==============================] - 6s 2s/step - loss: 3.3454 - accuracy: 0.5833 - val_loss: 2.3186 - val_accuracy: 0.5000
# Epoch 12/20
# 2/2 [==============================] - ETA: 0s - loss: 0.6437 - accuracy: 0.7222Restoring model weights from the end of the best epoch: 9.
# 2/2 [==============================] - 6s 2s/step - loss: 0.6437 - accuracy: 0.7222 - val_loss: 1.5314 - val_accuracy: 0.5000
# Epoch 12: early stopping
# 1/1 [==============================] - 1s 982ms/step
# 1/1 [==============================] - 1s 536ms/step - loss: 0.7959 - accuracy: 0.5000
# Fold 4: Accuracy = 0.5000,       Precision = 0.5000,       Recall = 1.0000,       Specificity = 0.0000,       AUC = 0.7500,       F1 Score = 0.6667
# Confusion matrix:
# [[0 2]
#  [0 2]]
# Epoch 1/20
# 2/2 [==============================] - 9s 2s/step - loss: 3.5607 - accuracy: 0.3889 - val_loss: 30.4775 - val_accuracy: 0.5000
# Epoch 2/20
# 2/2 [==============================] - 6s 2s/step - loss: 28.7515 - accuracy: 0.4444 - val_loss: 8.5440 - val_accuracy: 0.5000
# Epoch 3/20
# 2/2 [==============================] - 7s 2s/step - loss: 7.5881 - accuracy: 0.5556 - val_loss: 8.8962 - val_accuracy: 0.5000
# Epoch 4/20
# 2/2 [==============================] - 7s 2s/step - loss: 10.9088 - accuracy: 0.4444 - val_loss: 2.7341 - val_accuracy: 0.7500
# Epoch 5/20
# 2/2 [==============================] - 6s 2s/step - loss: 7.5791 - accuracy: 0.5833 - val_loss: 1.7664 - val_accuracy: 0.5000
# Epoch 6/20
# 2/2 [==============================] - 7s 2s/step - loss: 2.9628 - accuracy: 0.5556 - val_loss: 8.1996 - val_accuracy: 0.5000
# Epoch 7/20
# 2/2 [==============================] - 5s 860ms/step - loss: 3.8851 - accuracy: 0.6944 - val_loss: 0.6007 - val_accuracy: 0.5000
# Epoch 8/20
# 2/2 [==============================] - 6s 1s/step - loss: 1.5826 - accuracy: 0.7222 - val_loss: 4.6210 - val_accuracy: 0.5000
# Epoch 9/20
# 2/2 [==============================] - 6s 2s/step - loss: 1.1292 - accuracy: 0.6667 - val_loss: 0.8618 - val_accuracy: 0.5000
# Epoch 10/20
# 2/2 [==============================] - ETA: 0s - loss: 0.9819 - accuracy: 0.6944Restoring model weights from the end of the best epoch: 7.
# 2/2 [==============================] - 6s 2s/step - loss: 0.9819 - accuracy: 0.6944 - val_loss: 1.1559 - val_accuracy: 0.5000
# Epoch 10: early stopping
# 1/1 [==============================] - 1s 855ms/step
# C:\Anaconda3\envs\xyrus\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 1/1 [==============================] - 1s 659ms/step - loss: 0.6007 - accuracy: 0.5000
# Fold 5: Accuracy = 0.5000,       Precision = 0.0000,       Recall = 0.0000,       Specificity = 1.0000,       AUC = 1.0000,       F1 Score = 0.0000
# Confusion matrix:
# [[2 0]
#  [2 0]]
# Epoch 1/20
# 2/2 [==============================] - 9s 2s/step - loss: 3.4425 - accuracy: 0.3333 - val_loss: 34.3319 - val_accuracy: 0.5000
# Epoch 2/20
# 2/2 [==============================] - 7s 2s/step - loss: 32.4677 - accuracy: 0.5556 - val_loss: 20.5874 - val_accuracy: 0.5000
# Epoch 3/20
# 2/2 [==============================] - 7s 1s/step - loss: 17.8609 - accuracy: 0.5000 - val_loss: 5.7230 - val_accuracy: 0.2500
# Epoch 4/20
# 2/2 [==============================] - 4s 887ms/step - loss: 7.4794 - accuracy: 0.5000 - val_loss: 8.7548 - val_accuracy: 0.5000
# Epoch 5/20
# 2/2 [==============================] - 6s 1s/step - loss: 9.6840 - accuracy: 0.4722 - val_loss: 0.9007 - val_accuracy: 0.5000
# Epoch 6/20
# 2/2 [==============================] - 6s 2s/step - loss: 2.3742 - accuracy: 0.6944 - val_loss: 1.3669 - val_accuracy: 0.7500
# Epoch 7/20
# 2/2 [==============================] - 7s 2s/step - loss: 2.6581 - accuracy: 0.6667 - val_loss: 4.3261 - val_accuracy: 0.5000
# Epoch 8/20
# 2/2 [==============================] - ETA: 0s - loss: 4.8432 - accuracy: 0.5556Restoring model weights from the end of the best epoch: 5.
# 2/2 [==============================] - 7s 2s/step - loss: 4.8432 - accuracy: 0.5556 - val_loss: 9.4365 - val_accuracy: 0.5000
# Epoch 8: early stopping
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 762ms/step - loss: 0.9007 - accuracy: 0.5000
# Fold 6: Accuracy = 0.5000,       Precision = 0.5000,       Recall = 0.5000,       Specificity = 0.5000,       AUC = 0.7500,       F1 Score = 0.5000
# Confusion matrix:
# [[1 1]
#  [1 1]]
# Epoch 1/20
# 2/2 [==============================] - 9s 2s/step - loss: 9.8880 - accuracy: 0.3056 - val_loss: 28.6492 - val_accuracy: 0.5000
# Epoch 2/20
# 2/2 [==============================] - 6s 1s/step - loss: 23.2108 - accuracy: 0.3889 - val_loss: 26.2846 - val_accuracy: 0.5000
# Epoch 3/20
# 2/2 [==============================] - 6s 1s/step - loss: 16.1227 - accuracy: 0.5278 - val_loss: 6.1136 - val_accuracy: 0.2500
# Epoch 4/20
# 2/2 [==============================] - 7s 1s/step - loss: 2.1971 - accuracy: 0.6667 - val_loss: 7.8210 - val_accuracy: 0.0000e+00
# Epoch 5/20
# 2/2 [==============================] - 6s 1s/step - loss: 3.6101 - accuracy: 0.6667 - val_loss: 11.2828 - val_accuracy: 0.5000
# Epoch 6/20
# 2/2 [==============================] - 7s 1s/step - loss: 6.3078 - accuracy: 0.5278 - val_loss: 4.4762 - val_accuracy: 0.5000
# Epoch 7/20
# 2/2 [==============================] - 6s 1s/step - loss: 2.3297 - accuracy: 0.6667 - val_loss: 3.3304 - val_accuracy: 0.0000e+00
# Epoch 8/20
# 2/2 [==============================] - 6s 1s/step - loss: 1.6853 - accuracy: 0.6667 - val_loss: 2.8309 - val_accuracy: 0.2500
# Epoch 9/20
# 2/2 [==============================] - 4s 843ms/step - loss: 0.8189 - accuracy: 0.6944 - val_loss: 3.5728 - val_accuracy: 0.5000
# Epoch 10/20
# 2/2 [==============================] - 6s 1s/step - loss: 0.7761 - accuracy: 0.7222 - val_loss: 3.1127 - val_accuracy: 0.0000e+00
# Epoch 11/20
# 2/2 [==============================] - ETA: 0s - loss: 0.7062 - accuracy: 0.7500Restoring model weights from the end of the best epoch: 8.
# 2/2 [==============================] - 5s 2s/step - loss: 0.7062 - accuracy: 0.7500 - val_loss: 5.1286 - val_accuracy: 0.5000
# Epoch 11: early stopping
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 746ms/step - loss: 2.8309 - accuracy: 0.2500
# Fold 7: Accuracy = 0.2500,       Precision = 0.0000,       Recall = 0.0000,       Specificity = 0.5000,       AUC = 0.0000,       F1 Score = 0.0000
# Confusion matrix:
# [[1 1]
#  [2 0]]
# Epoch 1/20
# 2/2 [==============================] - 9s 2s/step - loss: 5.0153 - accuracy: 0.4444 - val_loss: 34.1034 - val_accuracy: 0.5000
# Epoch 2/20
# 2/2 [==============================] - 6s 2s/step - loss: 30.8878 - accuracy: 0.5556 - val_loss: 13.8040 - val_accuracy: 0.5000
# Epoch 3/20
# 2/2 [==============================] - 6s 1s/step - loss: 13.3934 - accuracy: 0.5000 - val_loss: 4.2015 - val_accuracy: 0.2500
# Epoch 4/20
# 2/2 [==============================] - 6s 1s/step - loss: 3.4311 - accuracy: 0.6944 - val_loss: 11.2480 - val_accuracy: 0.5000
# Epoch 5/20
# 2/2 [==============================] - 6s 1s/step - loss: 7.7398 - accuracy: 0.6389 - val_loss: 6.8546 - val_accuracy: 0.5000
# Epoch 6/20
# 2/2 [==============================] - ETA: 0s - loss: 6.3149 - accuracy: 0.4722Restoring model weights from the end of the best epoch: 3.
# 2/2 [==============================] - 6s 1s/step - loss: 6.3149 - accuracy: 0.4722 - val_loss: 5.1731 - val_accuracy: 0.5000
# Epoch 6: early stopping
# 1/1 [==============================] - 1s 887ms/step
# 1/1 [==============================] - 1s 777ms/step - loss: 4.2015 - accuracy: 0.2500
# Fold 8: Accuracy = 0.2500,       Precision = 0.0000,       Recall = 0.0000,       Specificity = 0.5000,       AUC = 0.5000,       F1 Score = 0.0000
# Confusion matrix:
# [[1 1]
#  [2 0]]
# Epoch 1/20
# 2/2 [==============================] - 7s 1s/step - loss: 5.6975 - accuracy: 0.4167 - val_loss: 52.3906 - val_accuracy: 0.5000
# Epoch 2/20
# 2/2 [==============================] - 6s 1s/step - loss: 38.1152 - accuracy: 0.5556 - val_loss: 7.3770 - val_accuracy: 0.5000
# Epoch 3/20
# 2/2 [==============================] - 7s 2s/step - loss: 5.6179 - accuracy: 0.6667 - val_loss: 2.3107 - val_accuracy: 0.2500
# Epoch 4/20
# 2/2 [==============================] - 6s 2s/step - loss: 2.5252 - accuracy: 0.7222 - val_loss: 1.9394 - val_accuracy: 0.2500
# Epoch 5/20
# 2/2 [==============================] - 7s 1s/step - loss: 2.8591 - accuracy: 0.6111 - val_loss: 5.3593 - val_accuracy: 0.5000
# Epoch 6/20
# 2/2 [==============================] - 6s 2s/step - loss: 6.1782 - accuracy: 0.4722 - val_loss: 17.9023 - val_accuracy: 0.5000
# Epoch 7/20
# 2/2 [==============================] - ETA: 0s - loss: 10.9713 - accuracy: 0.5000Restoring model weights from the end of the best epoch: 4.
# 2/2 [==============================] - 7s 2s/step - loss: 10.9713 - accuracy: 0.5000 - val_loss: 2.8788 - val_accuracy: 0.7500
# Epoch 7: early stopping
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 409ms/step - loss: 1.9394 - accuracy: 0.2500
# Fold 9: Accuracy = 0.2500,       Precision = 0.3333,       Recall = 0.5000,       Specificity = 0.0000,       AUC = 0.5000,       F1 Score = 0.4000
# Confusion matrix:
# [[0 2]
#  [1 1]]
# Epoch 1/20
# 2/2 [==============================] - 8s 2s/step - loss: 9.4689 - accuracy: 0.3889 - val_loss: 1.1350 - val_accuracy: 0.5000
# Epoch 2/20
# 2/2 [==============================] - 7s 2s/step - loss: 2.2883 - accuracy: 0.5278 - val_loss: 3.1481 - val_accuracy: 0.5000
# Epoch 3/20
# 2/2 [==============================] - 7s 2s/step - loss: 3.7788 - accuracy: 0.4167 - val_loss: 5.8152 - val_accuracy: 0.5000
# Epoch 4/20
# 2/2 [==============================] - ETA: 0s - loss: 4.6918 - accuracy: 0.4444Restoring model weights from the end of the best epoch: 1.
# 2/2 [==============================] - 7s 2s/step - loss: 4.6918 - accuracy: 0.4444 - val_loss: 2.3805 - val_accuracy: 0.0000e+00
# Epoch 4: early stopping
# 1/1 [==============================] - 1s 554ms/step
# 1/1 [==============================] - 0s 455ms/step - loss: 1.1350 - accuracy: 0.5000
# Fold 10: Accuracy = 0.5000,       Precision = 0.5000,       Recall = 1.0000,       Specificity = 0.0000,       AUC = 0.7500,       F1 Score = 0.6667
# Confusion matrix:
# [[0 2]
#  [0 2]]
# Average Accuracy: 0.4250 +/- 0.1601
# Average Precision: 0.2333 +/- 0.2380
# Average Recall/Sensitivity: 0.4000 +/- 0.4359
# Average Specificity: 0.4333 +/- 0.3180
# Average F1-score: 0.2900 +/- 0.3004
# Average ROC_AUC score: 0.5500 +/- 0.3500
# Overall confusion matrix:
# [[10 12]
#  [11  7]]
