# %%
# pip install librosa

# %%
#pip install opencv-python

# %%
#Converting 1D ECG to 2D images (spectrograms) using STFT
#Do not rerun as the converted files are already saved in ~/Data_ALL/ECG_images_baseline6_STFT

# import os
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import librosa
# import librosa.display
# from PIL import Image

# # Set the input and output directories
# gen_dir = "/Users/xaichotic/Library/CloudStorage/OneDrive-NorthumbriaUniversity-ProductionAzureAD/Term3/"

# input_folder = os.path.join(gen_dir, "Data_ALL/ECG/ECG_csv_files_labeled_segment6_pantompkins")
# output_folder = os.path.join(gen_dir, "Data_ALL/ECG_images_segment6_STFT")

# # Create output directory if it does not exist
# if not os.path.exists(output_folder):
#     os.makedirs(output_folder)

# # Define the parameters for the STFT
# n_fft = 1024
# hop_length = 512

# # Loop through all the CSV files in the folder
# for filename in os.listdir(input_folder):
#     if filename.endswith(".csv"):
#         # Load the CSV file as a NumPy array
#         file_path = os.path.join(input_folder, filename)
#         ecg_signal = pd.read_csv(file_path, header=None).values.flatten()

#         # Compute the STFT
#         stft = librosa.stft(ecg_signal, n_fft=n_fft, hop_length=hop_length)
#         stft_mag_db = librosa.amplitude_to_db(np.abs(stft), ref=np.max)

#         # Normalize the STFT to [0, 1] range
#         stft_norm = (stft_mag_db - np.min(stft_mag_db)) / np.ptp(stft_mag_db)

#         # Convert the STFT to a 8-bit grayscale image
#         stft_img = (stft_norm * 255).astype(np.uint8)

#         # Save the image as a PNG file
#         output_filename = os.path.splitext(filename)[0] + ".png"
#         output_path = os.path.join(output_folder, output_filename)
#         Image.fromarray(stft_img, mode="L").save(output_path)

#         print(f"Processed {filename} and saved {output_filename}")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.12.0

# %%
#counting the length of the files EDA
#62, it matches the number of files in csv

gen_dir = "/Users/w20009829/OneDrive - Northumbria University - Production Azure AD/Term3/"

# Set the input and output directories
#gen_dir = "/Users/xaichotic/Library/CloudStorage/OneDrive-NorthumbriaUniversity-ProductionAzureAD/Term3/"

import os
folder_path = os.path.join(gen_dir, "Data_ALL/ECG_images_segment6_STFT")

# Count the number of files in the folder
num_files = len([f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))])

print(f"There are {num_files} files in the {folder_path} folder.")
# Out:
# There are 81 files in the /Users/w20009829/OneDrive - Northumbria University - Production Azure AD/Term3/Data_ALL/ECG_images_segment6_STFT folder.

# %%
import os

data_dir = os.path.join(gen_dir, "Data_ALL/ECG_images_segment6_STFT")

class_counts = {0: 0, 1: 0}

for file_name in os.listdir(data_dir):
    if file_name.endswith(".png"):
        class_label = int(file_name.split("_")[-1].split(".")[0])
        class_counts[class_label] += 1

print(f"Class 0: {class_counts[0]} files")
print(f"Class 1: {class_counts[1]} files")
# Out:
# Class 0: 56 files
# Class 1: 25 files

# %%
import cv2
import numpy as np
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

# Set the data directory path
data_dir = os.path.join(gen_dir, "Data_ALL/ECG_images_segment6_STFT")

X = []
y = []

# Go through all the files in the directory
for file_name in os.listdir(data_dir):
    if file_name.endswith(".png"):
        # Extract the label from the file name
        label = int(file_name.split("_")[-1][0])
        # Load the image file and preprocess it
        file_path = os.path.join(data_dir, file_name)
        img = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
        img = cv2.resize(img, (224, 224))
        img = np.array(img).reshape(-1)
        # Save the preprocessed image and label in a list
        X.append(img)
        y.append(label)

# Convert the data to numpy arrays
X = np.array(X)
y = np.array(y)

# %%
from imblearn.under_sampling import RandomUnderSampler

# Apply random under-sampling to the data
rus = RandomUnderSampler()
X_resampled, y_resampled = rus.fit_resample(X, y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# %%
# Print the shape and class counts of the resampled data
print("Resampled data shape:", X_resampled.shape)
unique, counts = np.unique(y_resampled, return_counts=True)
print("Class counts:", dict(zip(unique, counts)))
# Out:
# Resampled data shape: (50, 50176)
# Class counts: {0: 25, 1: 25}

# %%
# Count the number of instances for each class in the resampled training data
class_counts = np.bincount(y_resampled)
print("Class distribution after Random Undersampling:", class_counts)
# Out:
# Class distribution after Random Undersampling: [25 25]

# %%
# Reshape the data into a 4D tensor
X_train = X_train.reshape((-1, 224, 224, 1))
X_test = X_test.reshape((-1, 224, 224, 1))

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (40, 224, 224, 1)
# (40,)
# (10, 224, 224, 1)
# (10,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization, Bidirectional, LSTM, Reshape, Dropout
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adagrad

import tensorflow as tf
import random

# Set the random seeds for reproducibility
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

filter_size = 32
kernel_size = (3,3)
batch_size = 16
neurons = 256

# Define the model architecture
model = Sequential()
model.add(Conv2D(filter_size, kernel_size, activation='relu', input_shape=(224, 224, 1)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(filter_size*2, kernel_size, activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(filter_size*4, kernel_size, activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.summary()

# Compile the model
model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])

# Set up early stopping
early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

# Train the model with early stopping
history = model.fit(X_train, y_train, 
                    epochs=25, 
                    batch_size=batch_size, 
                    validation_data=(X_test, y_test), 
                    callbacks=[early_stopping])

test_loss, test_acc = model.evaluate(X_test, y_test)
print("Test loss:", test_loss)
print("Test accuracy:", test_acc)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      320
#
#  batch_normalization (BatchN  (None, 222, 222, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  batch_normalization_1 (Batc  (None, 109, 109, 64)     256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 52, 52, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 86528)             0
#
#  dense (Dense)               (None, 256)               22151424
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 22,245,249
# Trainable params: 22,244,801
# Non-trainable params: 448
# _________________________________________________________________
# Epoch 1/25
# 3/3 [==============================] - 3s 561ms/step - loss: 22.5538 - accuracy: 0.5500 - val_loss: 8.9438 - val_accuracy: 0.3000
# Epoch 2/25
# 3/3 [==============================] - 1s 451ms/step - loss: 0.7954 - accuracy: 0.6000 - val_loss: 4.4406 - val_accuracy: 0.3000
# Epoch 3/25
# 3/3 [==============================] - 1s 445ms/step - loss: 0.5962 - accuracy: 0.5750 - val_loss: 3.5289 - val_accuracy: 0.3000
# Epoch 4/25
# 3/3 [==============================] - 1s 447ms/step - loss: 0.5828 - accuracy: 0.5500 - val_loss: 3.8564 - val_accuracy: 0.3000
# Epoch 5/25
# 3/3 [==============================] - 1s 432ms/step - loss: 0.5490 - accuracy: 0.6250 - val_loss: 3.7608 - val_accuracy: 0.3000
# Epoch 6/25
# 3/3 [==============================] - 1s 438ms/step - loss: 0.5741 - accuracy: 0.7000 - val_loss: 2.1945 - val_accuracy: 0.3000
# Epoch 7/25
# 3/3 [==============================] - 1s 462ms/step - loss: 0.4858 - accuracy: 0.8500 - val_loss: 1.2398 - val_accuracy: 0.3000
# Epoch 8/25
# 3/3 [==============================] - 1s 464ms/step - loss: 0.5031 - accuracy: 0.7500 - val_loss: 1.8140 - val_accuracy: 0.3000
# Epoch 9/25
# 3/3 [==============================] - 1s 453ms/step - loss: 0.4341 - accuracy: 0.8500 - val_loss: 3.0727 - val_accuracy: 0.3000
# Epoch 10/25
# 3/3 [==============================] - 1s 445ms/step - loss: 1.2388 - accuracy: 0.5000 - val_loss: 0.8615 - val_accuracy: 0.3000
# Epoch 11/25
# 3/3 [==============================] - 1s 451ms/step - loss: 0.5205 - accuracy: 0.7000 - val_loss: 0.9141 - val_accuracy: 0.3000
# Epoch 12/25
# 3/3 [==============================] - 1s 458ms/step - loss: 0.5158 - accuracy: 0.7250 - val_loss: 1.8154 - val_accuracy: 0.3000
# Epoch 13/25
# 3/3 [==============================] - 1s 469ms/step - loss: 0.5044 - accuracy: 0.6750 - val_loss: 1.6752 - val_accuracy: 0.3000
# Epoch 14/25
# 3/3 [==============================] - 1s 456ms/step - loss: 0.4736 - accuracy: 0.6750 - val_loss: 1.0957 - val_accuracy: 0.3000
# Epoch 15/25
# 3/3 [==============================] - 1s 459ms/step - loss: 0.4401 - accuracy: 0.9250 - val_loss: 1.5014 - val_accuracy: 0.3000
# Epoch 16/25
# 3/3 [==============================] - 1s 452ms/step - loss: 0.3149 - accuracy: 0.9250 - val_loss: 1.4314 - val_accuracy: 0.3000
# Epoch 17/25
# 3/3 [==============================] - 1s 458ms/step - loss: 0.5455 - accuracy: 0.6500 - val_loss: 0.6353 - val_accuracy: 0.5000
# Epoch 18/25
# 3/3 [==============================] - 1s 464ms/step - loss: 0.6163 - accuracy: 0.5250 - val_loss: 0.8062 - val_accuracy: 0.3000
# Epoch 19/25
# 3/3 [==============================] - 2s 473ms/step - loss: 0.2802 - accuracy: 1.0000 - val_loss: 0.8477 - val_accuracy: 0.3000
# Epoch 20/25
# 3/3 [==============================] - 1s 456ms/step - loss: 0.1371 - accuracy: 1.0000 - val_loss: 0.8930 - val_accuracy: 0.3000
# Epoch 21/25
# 3/3 [==============================] - 1s 456ms/step - loss: 0.0918 - accuracy: 1.0000 - val_loss: 0.7853 - val_accuracy: 0.3000
# Epoch 22/25
# 3/3 [==============================] - 1s 482ms/step - loss: 0.0696 - accuracy: 1.0000 - val_loss: 0.7560 - val_accuracy: 0.3000
# Epoch 23/25
# 3/3 [==============================] - 2s 502ms/step - loss: 0.0406 - accuracy: 1.0000 - val_loss: 0.6935 - val_accuracy: 0.5000
# Epoch 24/25
# 3/3 [==============================] - 2s 489ms/step - loss: 0.0322 - accuracy: 1.0000 - val_loss: 1.0847 - val_accuracy: 0.3000
# Epoch 25/25
# 3/3 [==============================] - 2s 492ms/step - loss: 0.0337 - accuracy: 1.0000 - val_loss: 0.6994 - val_accuracy: 0.5000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.6994 - accuracy: 0.5000
# Test loss: 0.6994474530220032
# Test accuracy: 0.5

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score

# Get the predictions
y_pred = model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)

# Print the confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)
print(cm)

# Print the classification report
print(classification_report(y_test, y_pred_classes))

# Calculate specificity
tn, fp, fn, tp = cm.ravel()
specificity = tn / (tn + fp)
print('Specificity:', specificity)

# Print the ROC AUC score
roc_auc = roc_auc_score(y_test, y_pred)
print('ROC AUC:', roc_auc)

import matplotlib.pyplot as plt

# Get the training and validation loss and accuracy values from the history object
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# Create the figure and axis objects
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Plot the training and validation loss
ax1.plot(train_loss, label='Training Loss')
ax1.plot(val_loss, label='Validation Loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()

# Plot the training and validation accuracy
ax2.plot(train_acc, label='Training Accuracy')
ax2.plot(val_acc, label='Validation Accuracy')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()

# Show the plot
plt.show()
# Out:
# 1/1 [==============================] - 0s 220ms/step
# [[3 0]
#  [5 2]]
#               precision    recall  f1-score   support
#
#            0       0.38      1.00      0.55         3
#            1       1.00      0.29      0.44         7
#
#     accuracy                           0.50        10
#    macro avg       0.69      0.64      0.49        10
# weighted avg       0.81      0.50      0.47        10
#
# Specificity: 1.0
# ROC AUC: 0.6190476190476191

# %% [markdown]
# cross-validation

# %%
#model for basic CNN

import numpy as np
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, BatchNormalization, MaxPooling1D, Dropout, Dense, Flatten
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold

import random
# Set the random seeds for reproducibility
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

filter_size = 32
kernel_size = (3,3)
batch_size = 16
num_folds = 10
n_epochs = 30
neurons = 256

# Define the CNN model
def create_model():
    model = Sequential()
    model.add(Conv2D(filter_size, kernel_size, activation='relu', input_shape=(224, 224, 1)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(filter_size*2, kernel_size, activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(filter_size*4, kernel_size, activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Flatten())
    model.add(Dense(neurons, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
    return model

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score
import numpy as np
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, BatchNormalization, MaxPooling1D, Dropout, Dense, Flatten
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold

# Set the random seeds for reproducibility
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state = 42)

#K-fold cross-validation lists
score_list = []
precision_list = []
recall_list = []
f1_score_list = []
confusion_matrix_list = []
specificity_list = []
ROC_AUC_list = []


for fold, (train_idx, val_idx) in enumerate(kfold.split(X_train, y_train)):
    #splitting the data into train and validation sets for this fold
    X_train_fold, y_train_fold = X_train[train_idx], y_train[train_idx]
    X_val_fold, y_val_fold = X_train[val_idx], y_train[val_idx]
    
    #defining the early stopping callback
    early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True, verbose=1)
    #early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=3)
    
    #training the model for this fold
    model = create_model()
    history = model.fit(X_train_fold, y_train_fold, epochs=n_epochs, batch_size=batch_size, 
                        validation_data=(X_val_fold, y_val_fold), callbacks=[early_stop], verbose=1)
    
    #predicting the classes for the validation set for this fold
    y_pred = model.predict(X_val_fold)
    y_pred_classes = (y_pred > 0.5).astype(int)
    
    #calculating precision, recall, specificity, F1 score, AUC, and confusion matrix for this fold
    precision_list.append(precision_score(y_val_fold, y_pred_classes))
    recall_list.append(recall_score(y_val_fold, y_pred_classes))
    f1_score_list.append(f1_score(y_val_fold, y_pred_classes))
    #tp, fp, fn, tn = confusion_matrix(y_val_fold, y_pred_classes).ravel()
    tn, fp, fn, tp = confusion_matrix(y_val_fold, y_pred_classes).ravel()
    specificity = tn / (tn + fp)
    specificity_list.append(specificity)
    ROC_AUC_list.append(roc_auc_score(y_val_fold, y_pred))
    confusion_matrix_list.append(confusion_matrix(y_val_fold, y_pred_classes))

    #evaluating the model on the test set for this fold
    #_, test_acc = model.evaluate(X_test, y_test)
    _, test_acc = model.evaluate(X_val_fold, y_val_fold)

    score_list.append(test_acc)
    
    #printing the metrics and confusion matrix for this fold
    print(f'Fold {fold + 1}: Accuracy = {test_acc:.4f}, \
      Precision = {precision_list[-1]:.4f}, \
      Recall = {recall_list[-1]:.4f}, \
      Specificity = {specificity_list[-1]:.4f}, \
      AUC = {ROC_AUC_list[-1]:.4f}, \
      F1 Score = {f1_score_list[-1]:.4f}')
    print(f'Confusion matrix:\n{confusion_matrix_list[-1]}')
    
#Print the average scores for all folds

print(f'Average Accuracy: {np.mean(score_list):.4f} +/- {np.std(score_list):.4f}')
print(f'Average Precision: {np.mean(precision_list):.4f} +/- {np.std(precision_list):.4f}')
print(f'Average Recall/Sensitivity: {np.mean(recall_list):.4f} +/- {np.std(recall_list):.4f}')
print(f'Average Specificity: {np.mean(specificity_list):.4f} +/- {np.std(specificity_list):.4f}')
print(f'Average F1-score: {np.mean(f1_score_list):.4f} +/- {np.std(f1_score_list):.4f}')
print(f'Average ROC_AUC score: {np.mean(ROC_AUC_list):.4f} +/- {np.std(ROC_AUC_list):.4f}')

#printing the overall confusion matrix

overall_cm = np.sum(confusion_matrix_list, axis=0)
print(f'Overall confusion matrix:\n{overall_cm}')
# Out:
# Epoch 1/30
# 3/3 [==============================] - 4s 899ms/step - loss: 8.6177 - accuracy: 0.6389 - val_loss: 4.8858 - val_accuracy: 0.2500
# Epoch 2/30
# 3/3 [==============================] - 2s 669ms/step - loss: 5.9492 - accuracy: 0.4444 - val_loss: 1.4495 - val_accuracy: 0.7500
# Epoch 3/30
# 3/3 [==============================] - 2s 660ms/step - loss: 0.6182 - accuracy: 0.5278 - val_loss: 0.9973 - val_accuracy: 0.7500
# Epoch 4/30
# 3/3 [==============================] - 2s 687ms/step - loss: 0.5990 - accuracy: 0.6389 - val_loss: 0.8200 - val_accuracy: 0.7500
# Epoch 5/30
# 3/3 [==============================] - 2s 705ms/step - loss: 0.5669 - accuracy: 0.6944 - val_loss: 0.6813 - val_accuracy: 0.7500
# Epoch 6/30
# 3/3 [==============================] - 2s 676ms/step - loss: 0.5628 - accuracy: 0.7222 - val_loss: 0.5951 - val_accuracy: 0.7500
# Epoch 7/30
# 3/3 [==============================] - 2s 651ms/step - loss: 0.5810 - accuracy: 0.5556 - val_loss: 0.6127 - val_accuracy: 0.7500
# Epoch 8/30
# 3/3 [==============================] - 2s 695ms/step - loss: 0.7024 - accuracy: 0.6667 - val_loss: 0.5741 - val_accuracy: 0.7500
# Epoch 9/30
# 3/3 [==============================] - 2s 648ms/step - loss: 0.4510 - accuracy: 0.8611 - val_loss: 0.6689 - val_accuracy: 0.7500
# Epoch 10/30
# 3/3 [==============================] - 2s 658ms/step - loss: 0.3814 - accuracy: 0.9167 - val_loss: 0.8736 - val_accuracy: 0.2500
# Epoch 11/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3445 - accuracy: 0.8889Restoring model weights from the end of the best epoch: 8.
# 3/3 [==============================] - 2s 648ms/step - loss: 0.3445 - accuracy: 0.8889 - val_loss: 0.8815 - val_accuracy: 0.7500
# Epoch 11: early stopping
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 136ms/step - loss: 0.5741 - accuracy: 0.7500
# C:\Anaconda3\envs\xyrus\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Fold 1: Accuracy = 0.7500,       Precision = 0.0000,       Recall = 0.0000,       Specificity = 1.0000,       AUC = 0.3333,       F1 Score = 0.0000
# Confusion matrix:
# [[3 0]
#  [1 0]]
# Epoch 1/30
# 3/3 [==============================] - 4s 863ms/step - loss: 22.3469 - accuracy: 0.4722 - val_loss: 2.4699 - val_accuracy: 0.2500
# Epoch 2/30
# 3/3 [==============================] - 2s 630ms/step - loss: 2.2070 - accuracy: 0.5556 - val_loss: 0.6147 - val_accuracy: 0.7500
# Epoch 3/30
# 3/3 [==============================] - 1s 398ms/step - loss: 0.6244 - accuracy: 0.6944 - val_loss: 0.6284 - val_accuracy: 0.7500
# Epoch 4/30
# 3/3 [==============================] - 2s 623ms/step - loss: 0.5733 - accuracy: 0.6667 - val_loss: 0.6082 - val_accuracy: 0.7500
# Epoch 5/30
# 3/3 [==============================] - 2s 487ms/step - loss: 0.5754 - accuracy: 0.6389 - val_loss: 0.6498 - val_accuracy: 0.7500
# Epoch 6/30
# 3/3 [==============================] - 2s 688ms/step - loss: 0.5258 - accuracy: 0.7222 - val_loss: 1.3075 - val_accuracy: 0.2500
# Epoch 7/30
# 3/3 [==============================] - ETA: 0s - loss: 0.8097 - accuracy: 0.5556Restoring model weights from the end of the best epoch: 4.
# 3/3 [==============================] - 2s 707ms/step - loss: 0.8097 - accuracy: 0.5556 - val_loss: 0.6639 - val_accuracy: 1.0000
# Epoch 7: early stopping
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 105ms/step - loss: 0.6082 - accuracy: 0.7500
# Fold 2: Accuracy = 0.7500,       Precision = 0.0000,       Recall = 0.0000,       Specificity = 1.0000,       AUC = 1.0000,       F1 Score = 0.0000
# Confusion matrix:
# [[3 0]
#  [1 0]]
# C:\Anaconda3\envs\xyrus\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 1/30
# 3/3 [==============================] - 4s 911ms/step - loss: 18.5121 - accuracy: 0.5556 - val_loss: 1.3797 - val_accuracy: 0.5000
# Epoch 2/30
# 3/3 [==============================] - 2s 674ms/step - loss: 2.3875 - accuracy: 0.4444 - val_loss: 0.7229 - val_accuracy: 0.5000
# Epoch 3/30
# 3/3 [==============================] - 2s 444ms/step - loss: 0.6464 - accuracy: 0.4722 - val_loss: 0.7035 - val_accuracy: 0.5000
# Epoch 4/30
# 3/3 [==============================] - 2s 664ms/step - loss: 0.6977 - accuracy: 0.4722 - val_loss: 0.6969 - val_accuracy: 0.5000
# Epoch 5/30
# 3/3 [==============================] - 2s 549ms/step - loss: 0.6316 - accuracy: 0.5278 - val_loss: 0.6927 - val_accuracy: 0.7500
# Epoch 6/30
# 3/3 [==============================] - 2s 607ms/step - loss: 0.6849 - accuracy: 0.5556 - val_loss: 0.6946 - val_accuracy: 0.7500
# Epoch 7/30
# 3/3 [==============================] - 2s 635ms/step - loss: 0.6426 - accuracy: 0.6389 - val_loss: 0.6940 - val_accuracy: 0.7500
# Epoch 8/30
# 3/3 [==============================] - 2s 686ms/step - loss: 0.8493 - accuracy: 0.5833 - val_loss: 0.6914 - val_accuracy: 0.7500
# Epoch 9/30
# 3/3 [==============================] - 2s 659ms/step - loss: 0.6561 - accuracy: 0.5556 - val_loss: 0.6937 - val_accuracy: 0.5000
# Epoch 10/30
# 3/3 [==============================] - 2s 658ms/step - loss: 0.6532 - accuracy: 0.5833 - val_loss: 0.6958 - val_accuracy: 0.5000
# Epoch 11/30
# 3/3 [==============================] - ETA: 0s - loss: 0.6892 - accuracy: 0.5833Restoring model weights from the end of the best epoch: 8.
# 3/3 [==============================] - 2s 686ms/step - loss: 0.6892 - accuracy: 0.5833 - val_loss: 0.7004 - val_accuracy: 0.5000
# Epoch 11: early stopping
# 1/1 [==============================] - 0s 349ms/step
# 1/1 [==============================] - 0s 98ms/step - loss: 0.6914 - accuracy: 0.7500
# Fold 3: Accuracy = 0.7500,       Precision = 0.6667,       Recall = 1.0000,       Specificity = 0.5000,       AUC = 0.5000,       F1 Score = 0.8000
# Confusion matrix:
# [[1 1]
#  [0 2]]
# Epoch 1/30
# 3/3 [==============================] - 5s 848ms/step - loss: 8.3595 - accuracy: 0.6111 - val_loss: 87.1926 - val_accuracy: 0.5000
# Epoch 2/30
# 3/3 [==============================] - 2s 430ms/step - loss: 6.2120 - accuracy: 0.5556 - val_loss: 1.8660 - val_accuracy: 0.2500
# Epoch 3/30
# 3/3 [==============================] - 2s 607ms/step - loss: 0.6061 - accuracy: 0.5278 - val_loss: 2.8629 - val_accuracy: 0.5000
# Epoch 4/30
# 3/3 [==============================] - 2s 491ms/step - loss: 0.6137 - accuracy: 0.5278 - val_loss: 3.0006 - val_accuracy: 0.5000
# Epoch 5/30
# 3/3 [==============================] - ETA: 0s - loss: 0.5975 - accuracy: 0.6389Restoring model weights from the end of the best epoch: 2.
# 3/3 [==============================] - 2s 684ms/step - loss: 0.5975 - accuracy: 0.6389 - val_loss: 2.4446 - val_accuracy: 0.5000
# Epoch 5: early stopping
# 1/1 [==============================] - 0s 290ms/step
# 1/1 [==============================] - 0s 109ms/step - loss: 1.8660 - accuracy: 0.2500
# Fold 4: Accuracy = 0.2500,       Precision = 0.3333,       Recall = 0.5000,       Specificity = 0.0000,       AUC = 0
- val_accuracy: 0.5000
# Epoch 7/30
# 3/3 [==============================] - 2s 743ms/step - loss: 0.5384 - accuracy: 0.6667 - val_loss: 1.9110 - val_accuracy: 0.5000
# Epoch 8/30
# 3/3 [==============================] - 3s 778ms/step - loss: 0.5656 - accuracy: 0.6944 - val_loss: 1.3359 - val_accuracy: 0.5000
# Epoch 9/30
# 3/3 [==============================] - 2s 734ms/step - loss: 0.5621 - accuracy: 0.6667 - val_loss: 1.3224 - val_accuracy: 0.5000
# Epoch 10/30
# 3/3 [==============================] - 2s 718ms/step - loss: 0.4842 - accuracy: 0.7222 - val_loss: 1.2128 - val_accuracy: 0.5000
# Epoch 11/30
# 3/3 [==============================] - 2s 674ms/step - loss: 0.3782 - accuracy: 0.8333 - val_loss: 2.1772 - val_accuracy: 0.5000
# Epoch 12/30
# 3/3 [==============================] - 2s 757ms/step - loss: 0.6946 - accuracy: 0.6667 - val_loss: 1.0496 - val_accuracy: 0.5000
# Epoch 13/30
# 3/3 [==============================] - 3s 779ms/step - loss: 0.7042 - accuracy: 0.5556 - val_loss: 0.7894 - val_accuracy: 0.2500
# Epoch 14/30
# 3/3 [==============================] - 2s 714ms/step - loss: 0.4697 - accuracy: 0.7222 - val_loss: 1.0973 - val_accuracy: 0.5000
# Epoch 15/30
# 3/3 [==============================] - 2s 741ms/step - loss: 0.4149 - accuracy: 0.8333 - val_loss: 0.8498 - val_accuracy: 0.2500
# Epoch 16/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3284 - accuracy: 0.8611Restoring model weights from the end of the best epoch: 13.
# 3/3 [==============================] - 2s 688ms/step - loss: 0.3284 - accuracy: 0.8611 - val_loss: 1.2957 - val_accuracy: 0.5000
# Epoch 16: early stopping
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 98ms/step - loss: 0.7894 - accuracy: 0.2500
# Fold 6: Accuracy = 0.2500,       Precision = 0.3333,       Recall = 0.5000,       Specificity = 0.0000,       AUC = 0.5000,       F1 Score = 0.4000
# Confusion matrix:
# [[0 2]
#  [1 1]]
# Epoch 1/30
# 3/3 [==============================] - 4s 966ms/step - loss: 15.7015 - accuracy: 0.5556 - val_loss: 2.4712 - val_accuracy: 0.5000
# Epoch 2/30
# 3/3 [==============================] - 2s 508ms/step - loss: 0.8024 - accuracy: 0.5000 - val_loss: 1.8253 - val_accuracy: 0.5000
# Epoch 3/30
# 3/3 [==============================] - 2s 565ms/step - loss: 0.5929 - accuracy: 0.6667 - val_loss: 0.7231 - val_accuracy: 0.5000
# Epoch 4/30
# 3/3 [==============================] - 2s 597ms/step - loss: 0.5927 - accuracy: 0.6389 - val_loss: 0.7397 - val_accuracy: 0.5000
# Epoch 5/30
# 3/3 [==============================] - 2s 650ms/step - loss: 0.5147 - accuracy: 0.7778 - val_loss: 1.2709 - val_accuracy: 0.5000
# Epoch 6/30
# 3/3 [==============================] - ETA: 0s - loss: 0.5352 - accuracy: 0.7222Restoring model weights from the end of the best epoch: 3.
# 3/3 [==============================] - 2s 710ms/step - loss: 0.5352 - accuracy: 0.7222 - val_loss: 0.9167 - val_accuracy: 0.5000
# Epoch 6: early stopping
# 1/1 [==============================] - 0s 247ms/step
# 1/1 [==============================] - 0s 69ms/step - loss: 0.7231 - accuracy: 0.5000
# Fold 7: Accuracy = 0.5000,       Precision = 0.0000,       Recall = 0.0000,       Specificity = 1.0000,       AUC = 0.0000,       F1 Score = 0.0000
# Confusion matrix:
# [[2 0]
#  [2 0]]
# C:\Anaconda3\envs\xyrus\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 1/30
# 3/3 [==============================] - 5s 1s/step - loss: 22.9317 - accuracy: 0.5278 - val_loss: 17.5081 - val_accuracy: 0.5000
# Epoch 2/30
# 3/3 [==============================] - 2s 788ms/step - loss: 3.2125 - accuracy: 0.5556 - val_loss: 1.5212 - val_accuracy: 0.5000
# Epoch 3/30
# 3/3 [==============================] - 2s 487ms/step - loss: 0.5953 - accuracy: 0.6111 - val_loss: 7.7729 - val_accuracy: 0.5000
# Epoch 4/30
# 3/3 [==============================] - 1s 443ms/step - loss: 0.9358 - accuracy: 0.5278 - val_loss: 3.6885 - val_accuracy: 0.5000
# Epoch 5/30
# 3/3 [==============================] - ETA: 0s - loss: 0.6080 - accuracy: 0.5833Restoring model weights from the end of the best epoch: 2.
# 3/3 [==============================] - 2s 575ms/step - loss: 0.6080 - accuracy: 0.5833 - val_loss: 2.7371 - val_accuracy: 0.5000
# Epoch 5: early stopping
# 1/1 [==============================] - 0s 246ms/step
# 1/1 [==============================] - 0s 110ms/step - loss: 1.5212 - accuracy: 0.5000
# C:\Anaconda3\envs\xyrus\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Fold 8: Accuracy = 0.5000,       Precision = 0.0000,       Recall = 0.0000,       Specificity = 1.0000,       AUC = 0.5000,       F1 Score = 0.0000
# Confusion matrix:
# [[2 0]
#  [2 0]]
# Epoch 1/30
# 3/3 [==============================] - 4s 963ms/step - loss: 13.1993 - accuracy: 0.5278 - val_loss: 84.7345 - val_accuracy: 0.5000
# Epoch 2/30
# 3/3 [==============================] - 2s
- val_accuracy: 0.5000
# Epoch 8/30
# 3/3 [==============================] - 1s 430ms/step - loss: 0.5671 - accuracy: 0.6944 - val_loss: 3.9363 - val_accuracy: 0.5000
# Epoch 9/30
# 3/3 [==============================] - 1s 425ms/step - loss: 0.6067 - accuracy: 0.6111 - val_loss: 3.2105 - val_accuracy: 0.5000
# Epoch 10/30
# 3/3 [==============================] - 1s 423ms/step - loss: 0.5377 - accuracy: 0.6667 - val_loss: 2.7950 - val_accuracy: 0.5000
# Epoch 11/30
# 3/3 [==============================] - 1s 435ms/step - loss: 0.5180 - accuracy: 0.6389 - val_loss: 2.5010 - val_accuracy: 0.5000
# Epoch 12/30
# 3/3 [==============================] - 1s 424ms/step - loss: 0.6142 - accuracy: 0.5833 - val_loss: 2.0617 - val_accuracy: 0.5000
# Epoch 13/30
# 3/3 [==============================] - 1s 417ms/step - loss: 0.5488 - accuracy: 0.5556 - val_loss: 1.7544 - val_accuracy: 0.5000
# Epoch 14/30
# 3/3 [==============================] - 1s 408ms/step - loss: 0.5620 - accuracy: 0.7222 - val_loss: 1.4298 - val_accuracy: 0.5000
# Epoch 15/30
# 3/3 [==============================] - 1s 419ms/step - loss: 0.5840 - accuracy: 0.6389 - val_loss: 1.1892 - val_accuracy: 0.5000
# Epoch 16/30
# 3/3 [==============================] - 1s 424ms/step - loss: 0.5504 - accuracy: 0.7500 - val_loss: 0.9468 - val_accuracy: 0.5000
# Epoch 17/30
# 3/3 [==============================] - 1s 422ms/step - loss: 0.5430 - accuracy: 0.7222 - val_loss: 0.7480 - val_accuracy: 0.5000
# Epoch 18/30
# 3/3 [==============================] - 1s 397ms/step - loss: 0.5331 - accuracy: 0.6944 - val_loss: 0.6114 - val_accuracy: 0.5000
# Epoch 19/30
# 3/3 [==============================] - 1s 399ms/step - loss: 0.5028 - accuracy: 0.7222 - val_loss: 0.5315 - val_accuracy: 0.5000
# Epoch 20/30
# 3/3 [==============================] - 1s 390ms/step - loss: 0.4892 - accuracy: 0.6944 - val_loss: 0.6180 - val_accuracy: 0.5000
# Epoch 21/30
# 3/3 [==============================] - 1s 409ms/step - loss: 0.6042 - accuracy: 0.6389 - val_loss: 0.4988 - val_accuracy: 0.5000
# Epoch 22/30
# 3/3 [==============================] - 1s 407ms/step - loss: 0.4898 - accuracy: 0.7500 - val_loss: 0.4348 - val_accuracy: 1.0000
# Epoch 23/30
# 3/3 [==============================] - 1s 394ms/step - loss: 0.4828 - accuracy: 0.7222 - val_loss: 0.4256 - val_accuracy: 1.0000
# Epoch 24/30
# 3/3 [==============================] - 1s 380ms/step - loss: 0.5005 - accuracy: 0.7222 - val_loss: 0.5189 - val_accuracy: 1.0000
# Epoch 25/30
# 3/3 [==============================] - 1s 371ms/step - loss: 0.4425 - accuracy: 0.7778 - val_loss: 0.5270 - val_accuracy: 0.7500
# Epoch 26/30
# 3/3 [==============================] - ETA: 0s - loss: 0.5222 - accuracy: 0.6389Restoring model weights from the end of the best epoch: 23.
# 3/3 [==============================] - 1s 376ms/step - loss: 0.5222 - accuracy: 0.6389 - val_loss: 0.5949 - val_accuracy: 0.7500
# Epoch 26: early stopping
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4256 - accuracy: 1.0000
# Fold 10: Accuracy = 1.0000,       Precision = 1.0000,       Recall = 1.0000,       Specificity = 1.0000,       AUC = 1.0000,       F1 Score = 1.0000
# Confusion matrix:
# [[2 0]
#  [0 2]]
# Average Accuracy: 0.5500 +/- 0.2449
# Average Precision: 0.2667 +/- 0.3266
# Average Recall/Sensitivity: 0.3500 +/- 0.3905
# Average Specificity: 0.6500 +/- 0.4500
# Average F1-score: 0.3000 +/- 0.3493
# Average ROC_AUC score: 0.4583 +/- 0.3276
# Overall confusion matrix:
# [[15  7]
#  [11  7]]

# %%
import seaborn as sns

sns.set(font_scale=1.4) # adjust font size as needed
sns.heatmap(overall_cm, annot=True, annot_kws={"size": 16}, cmap='Blues', fmt='g')
# Out:
# <AxesSubplot:>
