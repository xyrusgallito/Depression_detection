# %%
# pip install librosa

# %%
# pip install opencv-python

# %%
# #This is for STFT

# import os
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import librosa
# import librosa.display
# from PIL import Image

# # Set the input and output directories
# gen_dir = "/Users/xaichotic/Library/CloudStorage/OneDrive-NorthumbriaUniversity-ProductionAzureAD/Term3/"

# input_folder = os.path.join(gen_dir, "Data_ALL/ECG/ECG_csv_files_labeled_baseline6_pantompkins")
# output_folder = os.path.join(gen_dir, "Data_ALL/ECG_images_baseline6_STFT")

# # Create output directory if it does not exist
# if not os.path.exists(output_folder):
#     os.makedirs(output_folder)

# # Define the parameters for the STFT
# n_fft = 1024
# hop_length = 512

# # Loop through all the CSV files in the folder
# for filename in os.listdir(input_folder):
#     if filename.endswith(".csv"):
#         # Load the CSV file as a NumPy array
#         file_path = os.path.join(input_folder, filename)
#         ecg_signal = pd.read_csv(file_path, header=None).values.flatten()

#         # Compute the STFT
#         stft = librosa.stft(ecg_signal, n_fft=n_fft, hop_length=hop_length)
#         stft_mag_db = librosa.amplitude_to_db(np.abs(stft), ref=np.max)

#         # Normalize the STFT to [0, 1] range
#         stft_norm = (stft_mag_db - np.min(stft_mag_db)) / np.ptp(stft_mag_db)

#         # Convert the STFT to a 8-bit grayscale image
#         stft_img = (stft_norm * 255).astype(np.uint8)

#         # Save the image as a PNG file
#         output_filename = os.path.splitext(filename)[0] + ".png"
#         output_path = os.path.join(output_folder, output_filename)
#         Image.fromarray(stft_img, mode="L").save(output_path)

#         print(f"Processed {filename} and saved {output_filename}")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.11.0

# %%
#counting the length of the files EDA
#62, it matches the number of files in csv

gen_dir = "/Users/w20009829/OneDrive - Northumbria University - Production Azure AD/Term3/"

# Set the input and output directories
#gen_dir = "/Users/xaichotic/Library/CloudStorage/OneDrive-NorthumbriaUniversity-ProductionAzureAD/Term3/"

import os
folder_path = os.path.join(gen_dir, "Data_ALL/ECG_images_baseline6_STFT")

# Count the number of files in the folder
num_files = len([f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))])

print(f"There are {num_files} files in the {folder_path} folder.")
# Out:
# There are 81 files in the /Users/w20009829/OneDrive - Northumbria University - Production Azure AD/Term3/Data_ALL/ECG_images_baseline6_STFT folder.

# %%
#checking for the frequency if each class

import os

data_dir = os.path.join(gen_dir, "Data_ALL/ECG_images_baseline6_STFT")

class_counts = {0: 0, 1: 0}

for file_name in os.listdir(data_dir):
    if file_name.endswith(".png"):
        class_label = int(file_name.split("_")[-1].split(".")[0])
        class_counts[class_label] += 1

print(f"Class 0: {class_counts[0]} files")
print(f"Class 1: {class_counts[1]} files")
# Out:
# Class 0: 56 files
# Class 1: 25 files

# %%
#extracting label from the filename

import cv2
import numpy as np
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

# Set the data directory path
data_dir = os.path.join(gen_dir, "Data_ALL/ECG_images_baseline6_STFT")

X = []
y = []

# Go through all the files in the directory
for file_name in os.listdir(data_dir):
    if file_name.endswith(".png"):
        # Extract the label from the file name
        label = int(file_name.split("_")[-1][0])
        # Load the image file and preprocess it
        file_path = os.path.join(data_dir, file_name)
        img_gray = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
        img_gray = cv2.resize(img_gray, (224, 224))
        img_rgb = cv2.cvtColor(img_gray, cv2.COLOR_GRAY2RGB) # Convert grayscale to RGB
        img_rgb = np.array(img_rgb).reshape(-1)
        # Save the preprocessed image and label in a list
        X.append(img_rgb)
        y.append(label)

# Convert the data to numpy arrays
X = np.array(X)
y = np.array(y)

# %%
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler

# Apply random under-sampling to the data
rus = RandomUnderSampler()
X_resampled, y_resampled = rus.fit_resample(X, y)

# Split the data into training and testing sets, stratified by y_resampled
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42, stratify=y_resampled)

# %%
# Print the shape and class counts of the resampled data
print("Resampled data shape:", X_resampled.shape)
unique, counts = np.unique(y_resampled, return_counts=True)
print("Class counts:", dict(zip(unique, counts)))
# Out:
# Resampled data shape: (50, 150528)
# Class counts: {0: 25, 1: 25}

# %%
# Count the number of instances for each class in the resampled training data
class_counts = np.bincount(y_resampled)
print("Class distribution after Random Undersampling:", class_counts)
# Out:
# Class distribution after Random Undersampling: [25 25]

# %%
# Reshape the data into a 4D tensor
X_train = X_train.reshape((-1, 224, 224, 3))
X_test = X_test.reshape((-1, 224, 224, 3))

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (40, 224, 224, 3)
# (40,)
# (10, 224, 224, 3)
# (10,)

# %%
y_test
# Out:
# array([0, 0, 0, 0, 1, 1, 1, 1, 0, 1])

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, Reshape, LSTM, Bidirectional
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adagrad
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers
from tensorflow.keras.utils import plot_model


import tensorflow as tf
import random

# Set the random seeds for reproducibility
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

batch_size = 16
filter_size = 32
neurons = 256
lstm_units = 32


# Create VGG16 model
vgg_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of VGG16 model
for layer in vgg_model.layers:
    layer.trainable = False

# Add custom layers on top of VGG16 model
model = Sequential()
model.add(vgg_model)
model.add(Flatten())
model.add(Reshape((-1, 256)))
#model.add(LSTM(lstm_units))
model.add(Bidirectional(LSTM(lstm_units)))
model.add(Dropout(0.5))
#model.add(Dense(neurons, activation='relu'))
model.add(Dense(neurons, activation='relu', kernel_regularizer=regularizers.l1(0.001)))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# Compile the model

model.compile(optimizer=RMSprop(learning_rate = 0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Print the model summary
model.summary()

# Set up early stopping
#early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
early_stopping = EarlyStopping(monitor='val_loss', restore_best_weights=True, verbose=1, patience=5)

# Train the model with early stopping
history = model.fit(X_train, y_train, 
                    epochs=50, 
                    batch_size=batch_size, 
                    validation_data=(X_test, y_test), 
                    callbacks=[early_stopping],
                    shuffle = True)

test_loss, test_acc = model.evaluate(X_test, y_test)
print("Test loss:", test_loss)
print("Test accuracy:", test_acc)
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_19 (Flatten)        (None, 25088)             0
#
#  reshape_19 (Reshape)        (None, 98, 256)           0
#
#  bidirectional_19 (Bidirecti  (None, 64)               73984
#  onal)
#
#  dropout_38 (Dropout)        (None, 64)                0
#
#  dense_38 (Dense)            (None, 256)               16640
#
#  dropout_39 (Dropout)        (None, 256)               0
#
#  dense_39 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 14,805,569
# Trainable params: 90,881
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/50
# 3/3 [==============================] - 8s 2s/step - loss: 1.8159 - accuracy: 0.5250 - val_loss: 1.7366 - val_accuracy: 0.7000
# Epoch 2/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.7239 - accuracy: 0.6250 - val_loss: 1.6841 - val_accuracy: 0.7000
# Epoch 3/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.6711 - accuracy: 0.6500 - val_loss: 1.6530 - val_accuracy: 0.6000
# Epoch 4/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.6388 - accuracy: 0.7500 - val_loss: 1.6404 - val_accuracy: 0.7000
# Epoch 5/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.5881 - accuracy: 0.6750 - val_loss: 1.6166 - val_accuracy: 0.7000
# Epoch 6/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.5114 - accuracy: 0.7500 - val_loss: 1.5952 - val_accuracy: 0.7000
# Epoch 7/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.5227 - accuracy: 0.7250 - val_loss: 1.5696 - val_accuracy: 0.7000
# Epoch 8/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.4535 - accuracy: 0.7500 - val_loss: 1.5740 - val_accuracy: 0.7000
# Epoch 9/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.4772 - accuracy: 0.8250 - val_loss: 1.5093 - val_accuracy: 0.7000
# Epoch 10/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.4939 - accuracy: 0.7750 - val_loss: 1.5019 - val_accuracy: 0.7000
# Epoch 11/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.3454 - accuracy: 0.8000 - val_loss: 1.5225 - val_accuracy: 0.7000
# Epoch 12/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.3323 - accuracy: 0.7250 - val_loss: 1.5396 - val_accuracy: 0.5000
# Epoch 13/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.2603 - accuracy: 0.8750 - val_loss: 1.5029 - val_accuracy: 0.5000
# Epoch 14/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.1787 - accuracy: 0.9750 - val_loss: 1.5102 - val_accuracy: 0.6000
# Epoch 15/50
# 3/3 [==============================] - ETA: 0s - loss: 1.2331 - accuracy: 0.7500Restoring model weights from the end of the best epoch: 10.
# 3/3 [==============================] - 5s 2s/step - loss: 1.2331 - accuracy: 0.7500 - val_loss: 1.5114 - val_accuracy: 0.5000
# Epoch 15: early stopping
# 1/1 [==============================] - 1s 965ms/step - loss: 1.5019 - accuracy: 0.7000
# Test loss: 1.5018894672393799
# Test accuracy: 0.699999988079071

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score

# Get the predictions
y_pred = model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)

# Compute the confusion matrix
tn, fp, fn, tp = confusion_matrix(y_test, y_pred_classes).ravel()

# Compute precision, recall, and specificity
precision = tp / (tp + fp)
recall = tp / (tp + fn)
specificity = tn / (tn + fp)

# Compute ROC AUC score
roc_auc = roc_auc_score(y_test, y_pred)

# Compute F1-score
f1 = f1_score(y_test, y_pred_classes)

# Print the metrics
print('Precision:', precision)
print('Recall:', recall)
print('Specificity:', specificity)
print('ROC AUC:', roc_auc)
print('F1-score:', f1)
# Out:
# 1/1 [==============================] - 1s 1s/step
# Precision: 0.625
# Recall: 1.0
# Specificity: 0.4
# ROC AUC: 0.76
# F1-score: 0.7692307692307693

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, Reshape, LSTM, Bidirectional
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adagrad
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers
from tensorflow.keras.utils import plot_model


import tensorflow as tf
import random

# Set the random seeds for reproducibility
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(123)
random.seed(123)
tf.random.set_seed(123)

batch_size = 16
filter_size = 32
neurons = 256
lstm_units = 32


# Create VGG16 model
vgg_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of VGG16 model
for layer in vgg_model.layers:
    layer.trainable = False

# Add custom layers on top of VGG16 model
model = Sequential()
model.add(vgg_model)
model.add(Flatten())
model.add(Reshape((-1, 256)))
#model.add(LSTM(lstm_units))
model.add(Bidirectional(LSTM(lstm_units)))
model.add(Dropout(0.5))
#model.add(Dense(neurons, activation='relu'))
model.add(Dense(neurons, activation='relu', kernel_regularizer=regularizers.l1(0.001)))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# Compile the model

model.compile(optimizer=RMSprop(learning_rate = 0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Print the model summary
model.summary()

# Set up early stopping
#early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
early_stopping = EarlyStopping(monitor='val_loss', restore_best_weights=True, verbose=1, patience=5)

# Train the model with early stopping
history = model.fit(X_train, y_train, 
                    epochs=50, 
                    batch_size=batch_size, 
                    validation_data=(X_test, y_test), 
                    callbacks=[early_stopping],
                    shuffle = True)

test_loss, test_acc = model.evaluate(X_test, y_test)
print("Test loss:", test_loss)
print("Test accuracy:", test_acc)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_3 (Flatten)         (None, 25088)             0
#
#  reshape_3 (Reshape)         (None, 98, 256)           0
#
#  bidirectional_3 (Bidirectio  (None, 64)               73984
#  nal)
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 256)               16640
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 14,805,569
# Trainable params: 90,881
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.8414 - accuracy: 0.5250 - val_loss: 1.7253 - val_accuracy: 0.6000
# Epoch 2/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.8074 - accuracy: 0.4750 - val_loss: 1.6832 - val_accuracy: 0.6000
# Epoch 3/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.6324 - accuracy: 0.7250 - val_loss: 1.6342 - val_accuracy: 0.8000
# Epoch 4/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.6227 - accuracy: 0.6500 - val_loss: 1.6232 - val_accuracy: 0.9000
# Epoch 5/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.5300 - accuracy: 0.7750 - val_loss: 1.5708 - val_accuracy: 0.9000
# Epoch 6/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.5203 - accuracy: 0.8000 - val_loss: 1.5332 - val_accuracy: 0.9000
# Epoch 7/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.4849 - accuracy: 0.7750 - val_loss: 1.4995 - val_accuracy: 0.9000
# Epoch 8/50
# 3/3 [==============================] - 4s 2s/step - loss: 1.3951 - accuracy: 0.8500 - val_loss: 1.4542 - val_accuracy: 0.9000
# Epoch 9/50
# 3/3 [==============================] - 4s 2s/step - loss: 1.3567 - accuracy: 0.9250 - val_loss: 1.4496 - val_accuracy: 0.8000
# Epoch 10/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.2684 - accuracy: 0.9000 - val_loss: 1.4309 - val_accuracy: 0.8000
# Epoch 11/50
# 3/3 [==============================] - 4s 2s/step - loss: 1.2160 - accuracy: 0.9000 - val_loss: 1.3687 - val_accuracy: 0.9000
# Epoch 12/50
# 3/3 [==============================] - 4s 2s/step - loss: 1.1921 - accuracy: 0.9250 - val_loss: 1.4024 - val_accuracy: 0.7000
# Epoch 13/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.2468 - accuracy: 0.8500 - val_loss: 1.3379 - val_accuracy: 0.7000
# Epoch 14/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.1353 - accuracy: 0.9250 - val_loss: 1.2827 - val_accuracy: 0.8000
# Epoch 15/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.1186 - accuracy: 0.9500 - val_loss: 1.2703 - val_accuracy: 0.8000
# Epoch 16/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.0588 - accuracy: 0.9500 - val_loss: 1.2402 - val_accuracy: 0.7000
# Epoch 17/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.0547 - accuracy: 0.9250 - val_loss: 1.2636 - val_accuracy: 0.7000
# Epoch 18/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.9633 - accuracy: 1.0000 - val_loss: 1.1805 - val_accuracy: 0.8000
# Epoch 19/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.9414 - accuracy: 0.9750 - val_loss: 1.1708 - val_accuracy: 0.7000
# Epoch 20/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.8862 - accuracy: 1.0000 - val_loss: 1.1797 - val_accuracy: 0.7000
# Epoch 21/50
# 3/3 [==============================] - 4s 2s/step - loss: 0.8958 - accuracy: 0.9750 - val_loss: 1.0965 - val_accuracy: 0.7000
# Epoch 22/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.8805 - accuracy: 0.9750 - val_loss: 1.1598 - val_accuracy: 0.8000
# Epoch 23/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.8286 - accuracy: 1.0000 - val_loss: 1.0657 - val_accuracy: 0.7000
# Epoch 24/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.8395 - accuracy: 0.9750 - val_loss: 1.1095 - val_accuracy: 0.8000
# Epoch 25/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.8088 - accuracy: 0.9750 - val_loss: 0.9887 - val_accuracy: 0.8000
# Epoch 26/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.7800 - accuracy: 1.0000 - val_loss: 1.0128 - val_accuracy: 0.8000
# Epoch 27/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.7184 - accuracy: 1.0000 - val_loss: 1.0113 - val_accuracy: 0.8000
# Epoch 28/50
# 3/3 [==============================] - 4s 2s/step - loss: 0.7014 - accuracy: 1.0000 - val_loss: 1.0185 - val_accuracy: 0.8000
# Epoch 29/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.7175 - accuracy: 1.0000 - val_loss: 1.0808 - val_accuracy: 0.8000
# Epoch 30/50
# 3/3 [==============================] - ETA: 0s - loss: 0.6453 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 25.
# 3/3 [==============================] - 4s 1s/step - loss: 0.6453 - accuracy: 1.0000 - val_loss: 1.0252 - val_accuracy: 0.8000
# Epoch 30: early stopping
# 1/1 [==============================] - 1s 861ms/step - loss: 0.9887 - accuracy: 0.8000
# Test loss: 0.9887137413024902
# Test accuracy: 0.800000011920929

# %%
# Print the model summary
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_3 (Flatten)         (None, 25088)             0
#
#  reshape_3 (Reshape)         (None, 98, 256)           0
#
#  bidirectional_3 (Bidirectio  (None, 64)               73984
#  nal)
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 256)               16640
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 14,805,569
# Trainable params: 90,881
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score

# Get the predictions
y_pred = model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)

# Print the confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)
print(cm)

# Print the classification report
print(classification_report(y_test, y_pred_classes))

# Print the ROC AUC score
roc_auc = roc_auc_score(y_test, y_pred)
print('ROC AUC:', roc_auc)
# Out:
# 1/1 [==============================] - 1s 1s/step
# [[4 1]
#  [2 3]]
#               precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73         5
#            1       0.75      0.60      0.67         5
#
#     accuracy                           0.70        10
#    macro avg       0.71      0.70      0.70        10
# weighted avg       0.71      0.70      0.70        10
#
# ROC AUC: 0.76

# %%
import matplotlib.pyplot as plt

# Get the training and validation loss and accuracy values from the history object
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# Create the figure and axis objects
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Plot the training and validation loss
ax1.plot(train_loss, label='Training Loss')
ax1.plot(val_loss, label='Validation Loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('Baseline Segment')
ax1.legend()

# Plot the training and validation accuracy
ax2.plot(train_acc, label='Training Accuracy')
ax2.plot(val_acc, label='Validation Accuracy')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.set_title('Baseline Segment')
ax2.legend()

# Show the plot
plt.show()

# %%
import seaborn as sns

# Get the predictions
y_pred = model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)

# Print the classification report
print(classification_report(y_test, y_pred_classes))

# Get the confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)

# Create a heatmap of the confusion matrix using Seaborn
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=['HC', 'DS'], yticklabels=['HC', 'DS'])

# Set the axis labels and title
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix fo ECG Baseline Segment')

# Show the plot
plt.show()
# Out:
# 1/1 [==============================] - 1s 853ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.40      0.57         5
#            1       0.62      1.00      0.77         5
#
#     accuracy                           0.70        10
#    macro avg       0.81      0.70      0.67        10
# weighted avg       0.81      0.70      0.67        10

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score

# Get the predictions
y_pred = model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)

# Compute the confusion matrix
tn, fp, fn, tp = confusion_matrix(y_test, y_pred_classes).ravel()

# Compute precision, recall, and specificity
precision = tp / (tp + fp)
recall = tp / (tp + fn)
specificity = tn / (tn + fp)

# Compute ROC AUC score
roc_auc = roc_auc_score(y_test, y_pred)

# Compute F1-score
f1 = f1_score(y_test, y_pred_classes)

# Print the metrics
print('Precision:', precision)
print('Recall:', recall)
print('Specificity:', specificity)
print('ROC AUC:', roc_auc)
print('F1-score:', f1)
# Out:
# 1/1 [==============================] - 1s 1s/step
# Precision: 0.6666666666666666
# Recall: 0.8
# Specificity: 0.6
# ROC AUC: 0.8
# F1-score: 0.7272727272727272

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score

# Get the predictions
y_pred = model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)

# Print the confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)
print(cm)

# Print the classification report
print(classification_report(y_test, y_pred_classes))

# Print the ROC AUC score
roc_auc = roc_auc_score(y_test, y_pred)
print('ROC AUC:', roc_auc)

import matplotlib.pyplot as plt

# Get the training and validation loss and accuracy values from the history object
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# Create the figure and axis objects
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Plot the training and validation loss
ax1.plot(train_loss, label='Training Loss')
ax1.plot(val_loss, label='Validation Loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()

# Plot the training and validation accuracy
ax2.plot(train_acc, label='Training Accuracy')
ax2.plot(val_acc, label='Validation Accuracy')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()

# Show the plot
plt.show()
# Out:
# 1/1 [==============================] - 1s 760ms/step
# [[4 1]
#  [2 3]]
#               precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73         5
#            1       0.75      0.60      0.67         5
#
#     accuracy                           0.70        10
#    macro avg       0.71      0.70      0.70        10
# weighted avg       0.71      0.70      0.70        10
#
# ROC AUC: 0.76

# %%
from sklearn.model_selection import StratifiedKFold


import tensorflow as tf
import random

# Set the random seeds for reproducibility
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

# Set the number of folds for K-fold cross-validation
k_folds = 5

# Create the K-fold cross-validation splitter
cv = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=42)

# Initialize lists to store the test loss and accuracy for each fold
test_loss_scores = []
test_acc_scores = []

# Iterate over each fold
for fold, (train_index, test_index) in enumerate(cv.split(X, y)):
    # Get the training and testing data for the fold
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    # Create and compile the model
    model = Sequential()
    model.add(vgg_model)
    model.add(Flatten())
    model.add(Reshape((-1, 256)))
    model.add(Bidirectional(LSTM(lstm_units)))
    model.add(Dropout(0.5))
    model.add(Dense(neurons, activation='relu', kernel_regularizer=regularizers.l1(0.001)))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer=RMSprop(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

    # Set up early stopping
    early_stopping = EarlyStopping(monitor='val_loss', restore_best_weights=True, verbose=1, patience=5)

    # Train the model with early stopping
    history = model.fit(X_train, y_train, 
                        epochs=50, 
                        batch_size=batch_size, 
                        validation_data=(X_test, y_test), 
                        callbacks=[early_stopping],
                        shuffle=True)

    # Evaluate the model on the test set for the fold
    test_loss, test_acc = model.evaluate(X_test, y_test)
    print(f"Fold {fold+1} test loss: {test_loss:.4f}")
    print(f"Fold {fold+1} test accuracy: {test_acc:.4f}")
    
    # Append the test loss and accuracy for the fold to the lists
    test_loss_scores.append(test_loss)
    test_acc_scores.append(test_acc)

# Compute the mean and standard deviation of the test loss and accuracy scores across folds
mean_test_loss = np.mean(test_loss_scores)
std_test_loss = np.std(test_loss_scores)
mean_test_acc = np.mean(test_acc_scores)
std_test_acc = np.std(test_acc_scores)

# Print the mean and standard deviation of the test loss and accuracy scores across folds
print(f"\nMean test loss across {k_folds} folds: {mean_test_loss:.4f} +/- {std_test_loss:.4f}")
print(f"Mean test accuracy across {k_folds} folds: {mean_test_acc:.4f} +/- {std_test_acc:.4f}")
# Out:
# Epoch 1/50
# 4/4 [==============================] - 8s 2s/step - loss: 1.7554 - accuracy: 0.6094 - val_loss: 1.6718 - val_accuracy: 0.7059
# Epoch 2/50
# 4/4 [==============================] - 6s 2s/step - loss: 1.5949 - accuracy: 0.7031 - val_loss: 1.6405 - val_accuracy: 0.7059
# Epoch 3/50
# 4/4 [==============================] - 6s 2s/step - loss: 1.5377 - accuracy: 0.7188 - val_loss: 1.6195 - val_accuracy: 0.7059
# Epoch 4/50
# 4/4 [==============================] - 6s 2s/step - loss: 1.5044 - accuracy: 0.7500 - val_loss: 1.5894 - val_accuracy: 0.6471
# Epoch 5/50
# 4/4 [==============================] - 6s 2s/step - loss: 1.4567 - accuracy: 0.7656 - val_loss: 1.5716 - val_accuracy: 0.7059
# Epoch 6/50
# 4/4 [==============================] - 7s 2s/step - loss: 1.4082 - accuracy: 0.7656 - val_loss: 1.5547 - val_accuracy: 0.6471
# Epoch 7/50
# 4/4 [==============================] - 7s 2s/step - loss: 1.3298 - accuracy: 0.7812 - val_loss: 1.5430 - val_accuracy: 0.7059
# Epoch 8/50
# 4/4 [==============================] - 7s 2s/step - loss: 1.3126 - accuracy: 0.7656 - val_loss: 1.5281 - val_accuracy: 0.5882
# Epoch 9/50
# 4/4 [==============================] - 7s 2s/step - loss: 1.2940 - accuracy: 0.7500 - val_loss: 1.5218 - val_accuracy: 0.5882
# Epoch 10/50
# 4/4 [==============================] - 7s 2s/step - loss: 1.2198 - accuracy: 0.8594 - val_loss: 1.5010 - val_accuracy: 0.6471
# Epoch 11/50
# 4/4 [==============================] - 7s 2s/step - loss: 1.1265 - accuracy: 0.8906 - val_loss: 1.5183 - val_accuracy: 0.5882
# Epoch 12/50
# 4/4 [==============================] - 7s 2s/step - loss: 1.1077 - accuracy: 0.9062 - val_loss: 1.4925 - val_accuracy: 0.5882
# Epoch 13/50
# 4/4 [==============================] - 7s 2s/step - loss: 1.0766 - accuracy: 0.8438 - val_loss: 1.5132 - val_accuracy: 0.5882
# Epoch 14/50
# 4/4 [==============================] - 7s 2s/step - loss: 1.0376 - accuracy: 0.9062 - val_loss: 1.4934 - val_accuracy: 0.5882
# Epoch 15/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.9469 - accuracy: 0.9531 - val_loss: 1.5337 - val_accuracy: 0.5882
# Epoch 16/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.9487 - accuracy: 0.9375 - val_loss: 1.5265 - val_accuracy: 0.5882
# Epoch 17/50
# 4/4 [==============================] - ETA: 0s - loss: 0.9129 - accuracy: 0.9375Restoring model weights from the end of the best epoch: 12.
# 4/4 [==============================] - 7s 2s/step - loss: 0.9129 - accuracy: 0.9375 - val_loss: 1.5231 - val_accuracy: 0.5882
# Epoch 17: early stopping
# 1/1 [==============================] - 1s 1s/step - loss: 1.4925 - accuracy: 0.5882
# Fold 1 test loss: 1.4925
# Fold 1 test accuracy: 0.5882
# Epoch 1/50
# 5/5 [==============================] - 11s 2s/step - loss: 1.7831 - accuracy: 0.6000 - val_loss: 1.6541 - val_accuracy: 0.6875
# Epoch 2/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.6953 - accuracy: 0.7077 - val_loss: 1.5840 - val_accuracy: 0.6875
# Epoch 3/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.5630 - accuracy: 0.7385 - val_loss: 1.5569 - val_accuracy: 0.6875
# Epoch 4/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.5556 - accuracy: 0.6615 - val_loss: 1.5079 - val_accuracy: 0.6875
# Epoch 5/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.4961 - accuracy: 0.7077 - val_loss: 1.4612 - val_accuracy: 0.6875
# Epoch 6/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.4724 - accuracy: 0.7538 - val_loss: 1.4267 - val_accuracy: 0.6875
# Epoch 7/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.3860 - accuracy: 0.7538 - val_loss: 1.4130 - val_accuracy: 0.6875
# Epoch 8/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.3222 - accuracy: 0.7538 - val_loss: 1.3823 - val_accuracy: 0.6875
# Epoch 9/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.2786 - accuracy: 0.7846 - val_loss: 1.3516 - val_accuracy: 0.6875
# Epoch 10/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.2390 - accuracy: 0.7846 - val_loss: 1.3362 - val_accuracy: 0.6875
# Epoch 11/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.2126 - accuracy: 0.8000 - val_loss: 1.3161 - val_accuracy: 0.6875
# Epoch 12/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.1260 - accuracy: 0.8308 - val_loss: 1.2806 - val_accuracy: 0.6875
# Epoch 13/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.0664 - accuracy: 0.8462 - val_loss: 1.2774 - val_accuracy: 0.6875
# Epoch 14/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.0456 - accuracy: 0.8308 - val_loss: 1.2346 - val_accuracy: 0.6875
# Epoch 15/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.0297 - accuracy: 0.8769 - val_loss: 1.1837 - val_accuracy: 0.6875
# Epoch 16/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.9464 - accuracy: 0.9231 - val_loss: 1.1789 - val_accuracy: 0.6875
# Epoch 17/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.9422 - accuracy: 0.8462 - val_loss: 1.1250 - val_accuracy: 0.6250
# Epoch 18/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.8937 - accuracy: 0.9231 - val_loss: 1.1104 - val_accuracy: 0.6875
# Epoch 19/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.8706 - accuracy: 0.9231 - val_loss: 1.0943 - val_accuracy: 0.7500
# Epoch 20/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.8157 - accuracy: 0.9692 - val_loss: 1.0922 - val_accuracy: 0.6250
# Epoch 21/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.7277 - accuracy: 0.9692 - val_loss: 1.1090 - val_accuracy: 0.6250
# Epoch 22/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.7027 - accuracy: 0.9846 - val_loss: 1.0852 - val_accuracy: 0.6875
# Epoch 23/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.6884 - accuracy: 0.9538 - val_loss: 1.0495 - val_accuracy: 0.6875
# Epoch 24/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.7062 - accuracy: 0.9385 - val_loss: 1.0450 - val_accuracy: 0.7500
# Epoch 25/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.6455 - accuracy: 0.9385 - val_loss: 1.0303 - val_accuracy: 0.6875
# Epoch 26/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.5889 - accuracy: 0.9846 - val_loss: 0.9947 - val_accuracy: 0.6875
# Epoch 27/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.5820 - accuracy: 0.9692 - val_loss: 0.9481 - val_accuracy: 0.8125
# Epoch 28/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.5587 - accuracy: 0.9846 - val_loss: 0.9639 - val_accuracy: 0.7500
# Epoch 29/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.5325 - accuracy: 1.0000 - val_loss: 0.9208 - val_accuracy: 0.6875
# Epoch 30/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.4886 - accuracy: 1.0000 - val_loss: 0.9075 - val_accuracy: 0.7500
# Epoch 31/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.4774 - accuracy: 0.9692 - val_loss: 0.9253 - val_accuracy: 0.6875
# Epoch 32/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.4718 - accuracy: 0.9846 - val_loss: 0.8961 - val_accuracy: 0.6250
# Epoch 33/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.4532 - accuracy: 1.0000 - val_loss: 0.9438 - val_accuracy: 0.6250
# Epoch 34/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.4218 - accuracy: 1.0000 - val_loss: 0.9431 - val_accuracy: 0.6250
# Epoch 35/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.4380 - accuracy: 0.9692 - val_loss: 1.0108 - val_accuracy: 0.6250
# Epoch 36/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.4075 - accuracy: 0.9846 - val_loss: 0.9357 - val_accuracy: 0.5625
# Epoch 37/50
# 5/5 [==============================] - ETA: 0s - loss: 0.3736 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 32.
# 5/5 [==============================] - 7s 1s/step - loss: 0.3736 - accuracy: 1.0000 - val_loss: 0.9472 - val_accuracy: 0.5625
# Epoch 37: early stopping
# 1/1 [==============================] - 2s 2s/step - loss: 0.8961 - accuracy: 0.6250
# Fold 2 test loss: 0.8961
# Fold 2 test accuracy: 0.6250
# Epoch 1/50
# 5/5 [==============================] - 9s 1s/step - loss: 1.7782 - accuracy: 0.6000 - val_loss: 1.7033 - val_accuracy: 0.6875
# Epoch 2/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.6286 - accuracy: 0.7385 - val_loss: 1.6630 - val_accuracy: 0.6875
# Epoch 3/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.6067 - accuracy: 0.6769 - val_loss: 1.6211 - val_accuracy: 0.6875
# Epoch 4/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.5936 - accuracy: 0.6308 - val_loss: 1.6113 - val_accuracy: 0.6875
# Epoch 5/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.4074 - accuracy: 0.7846 - val_loss: 1.5825 - val_accuracy: 0.6875
# Epoch 6/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.4287 - accuracy: 0.7231 - val_loss: 1.5509 - val_accuracy: 0.6875
# Epoch 7/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.4166 - accuracy: 0.7077 - val_loss: 1.5494 - val_accuracy: 0.6250
# Epoch 8/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.3245 - accuracy: 0.7231 - val_loss: 1.5429 - val_accuracy: 0.6250
# Epoch 9/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.2915 - accuracy: 0.7538 - val_loss: 1.5284 - val_accuracy: 0.6250
# Epoch 10/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.2636 - accuracy: 0.8308 - val_loss: 1.5068 - val_accuracy: 0.6250
# Epoch 11/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.1800 - accuracy: 0.8000 - val_loss: 1.4789 - val_accuracy: 0.6250
# Epoch 12/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.1124 - accuracy: 0.8308 - val_loss: 1.4727 - val_accuracy: 0.6250
# Epoch 13/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.1195 - accuracy: 0.8462 - val_loss: 1.4845 - val_accuracy: 0.6250
# Epoch 14/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.0220 - accuracy: 0.8615 - val_loss: 1.4634 - val_accuracy: 0.5625
# Epoch 15/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.9732 - accuracy: 0.8769 - val_loss: 1.4777 - val_accuracy: 0.5625
# Epoch 16/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.9745 - accuracy: 0.8308 - val_loss: 1.4931 - val_accuracy: 0.5625
# Epoch 17/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.0015 - accuracy: 0.8615 - val_loss: 1.4733 - val_accuracy: 0.5625
# Epoch 18/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.8940 - accuracy: 0.8923 - val_loss: 1.4811 - val_accuracy: 0.5625
# Epoch 19/50
# 5/5 [==============================] - ETA: 0s - loss: 0.8738 - accuracy: 0.8769Restoring model weights from the end of the best epoch: 14.
# 5/5 [==============================] - 7s 1s/step - loss: 0.8738 - accuracy: 0.8769 - val_loss: 1.5063 - val_accuracy: 0.5000
# Epoch 19: early stopping
# 1/1 [==============================] - 2s 2s/step - loss: 1.4634 - accuracy: 0.5625
# Fold 3 test loss: 1.4634
# Fold 3 test accuracy: 0.5625
# Epoch 1/50
# 5/5 [==============================] - 10s 1s/step - loss: 1.7670 - accuracy: 0.6615 - val_loss: 1.6382 - val_accuracy: 0.6875
# Epoch 2/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.6668 - accuracy: 0.6923 - val_loss: 1.5750 - val_accuracy: 0.7500
# Epoch 3/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.5350 - accuracy: 0.7231 - val_loss: 1.5236 - val_accuracy: 0.7500
# Epoch 4/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.4882 - accuracy: 0.7231 - val_loss: 1.4947 - val_accuracy: 0.7500
# Epoch 5/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.4310 - accuracy: 0.7385 - val_loss: 1.4599 - val_accuracy: 0.7500
# Epoch 6/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.3610 - accuracy: 0.7385 - val_loss: 1.4371 - val_accuracy: 0.7500
# Epoch 7/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.3217 - accuracy: 0.7846 - val_loss: 1.3906 - val_accuracy: 0.7500
# Epoch 8/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.2471 - accuracy: 0.7692 - val_loss: 1.3497 - val_accuracy: 0.8125
# Epoch 9/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.2479 - accuracy: 0.8000 - val_loss: 1.3078 - val_accuracy: 0.7500
# Epoch 10/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.2110 - accuracy: 0.7846 - val_loss: 1.2955 - val_accuracy: 0.7500
# Epoch 11/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.1211 - accuracy: 0.8308 - val_loss: 1.2795 - val_accuracy: 0.7500
# Epoch 12/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.0723 - accuracy: 0.8154 - val_loss: 1.2858 - val_accuracy: 0.6250
# Epoch 13/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.0308 - accuracy: 0.8615 - val_loss: 1.2671 - val_accuracy: 0.6875
# Epoch 14/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.9768 - accuracy: 0.9077 - val_loss: 1.1941 - val_accuracy: 0.7500
# Epoch 15/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.9571 - accuracy: 0.8769 - val_loss: 1.1797 - val_accuracy: 0.7500
# Epoch 16/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.9001 - accuracy: 0.9077 - val_loss: 1.1730 - val_accuracy: 0.7500
# Epoch 17/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.9033 - accuracy: 0.8769 - val_loss: 1.1903 - val_accuracy: 0.7500
# Epoch 18/50
# 5/5 [==============================] - 7s 2s/step - loss: 0.8076 - accuracy: 0.9538 - val_loss: 1.1454 - val_accuracy: 0.6875
# Epoch 19/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.7392 - accuracy: 0.9846 - val_loss: 1.1367 - val_accuracy: 0.6875
# Epoch 20/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.7188 - accuracy: 0.9385 - val_loss: 1.1221 - val_accuracy: 0.6875
# Epoch 21/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.7016 - accuracy: 0.9538 - val_loss: 1.0982 - val_accuracy: 0.7500
# Epoch 22/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.6870 - accuracy: 0.9538 - val_loss: 1.0836 - val_accuracy: 0.6875
# Epoch 23/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.6376 - accuracy: 0.9692 - val_loss: 1.0782 - val_accuracy: 0.7500
# Epoch 24/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.5892 - accuracy: 1.0000 - val_loss: 1.0844 - val_accuracy: 0.7500
# Epoch 25/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.5537 - accuracy: 0.9692 - val_loss: 1.0264 - val_accuracy: 0.7500
# Epoch 26/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.5288 - accuracy: 0.9846 - val_loss: 0.9937 - val_accuracy: 0.7500
# Epoch 27/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.5707 - accuracy: 0.9385 - val_loss: 0.9384 - val_accuracy: 0.8125
# Epoch 28/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.4924 - accuracy: 0.9846 - val_loss: 0.9289 - val_accuracy: 0.8125
# Epoch 29/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.4737 - accuracy: 0.9846 - val_loss: 0.9734 - val_accuracy: 0.8125
# Epoch 30/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.4339 - accuracy: 0.9846 - val_loss: 0.8775 - val_accuracy: 0.8125
# Epoch 31/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.4201 - accuracy: 1.0000 - val_loss: 0.9625 - val_accuracy: 0.6875
# Epoch 32/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.4560 - accuracy: 0.9692 - val_loss: 0.9598 - val_accuracy: 0.6875
# Epoch 33/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.4070 - accuracy: 0.9692 - val_loss: 0.8963 - val_accuracy: 0.6875
# Epoch 34/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.3745 - accuracy: 1.0000 - val_loss: 0.9031 - val_accuracy: 0.8125
# Epoch 35/50
# 5/5 [==============================] - ETA: 0s - loss: 0.3831 - accuracy: 0.9846Restoring model weights from the end of the best epoch: 30.
# 5/5 [==============================] - 7s 1s/step - loss: 0.3831 - accuracy: 0.9846 - val_loss: 0.8911 - val_accuracy: 0.8125
# Epoch 35: early stopping
# 1/1 [==============================] - 2s 2s/step - loss: 0.8775 - accuracy: 0.8125
# Fold 4 test loss: 0.8775
# Fold 4 test accuracy: 0.8125
# Epoch 1/50
# 5/5 [==============================] - 9s 1s/step - loss: 1.7979 - accuracy: 0.5692 - val_loss: 1.7097 - val_accuracy: 0.6875
# Epoch 2/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.6656 - accuracy: 0.6462 - val_loss: 1.6513 - val_accuracy: 0.6875
# Epoch 3/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.6341 - accuracy: 0.6615 - val_loss: 1.6068 - val_accuracy: 0.6875
# Epoch 4/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.5115 - accuracy: 0.7385 - val_loss: 1.5730 - val_accuracy: 0.6875
# Epoch 5/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.4356 - accuracy: 0.7692 - val_loss: 1.5457 - val_accuracy: 0.6875
# Epoch 6/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.4436 - accuracy: 0.7077 - val_loss: 1.5135 - val_accuracy: 0.6875
# Epoch 7/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.4028 - accuracy: 0.7385 - val_loss: 1.4567 - val_accuracy: 0.6875
# Epoch 8/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.3049 - accuracy: 0.8308 - val_loss: 1.4331 - val_accuracy: 0.6875
# Epoch 9/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.2560 - accuracy: 0.8308 - val_loss: 1.4137 - val_accuracy: 0.6875
# Epoch 10/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.1313 - accuracy: 0.8615 - val_loss: 1.4165 - val_accuracy: 0.6875
# Epoch 11/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.1448 - accuracy: 0.8154 - val_loss: 1.4257 - val_accuracy: 0.6875
# Epoch 12/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.1357 - accuracy: 0.8154 - val_loss: 1.3503 - val_accuracy: 0.6875
# Epoch 13/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.0530 - accuracy: 0.8769 - val_loss: 1.3410 - val_accuracy: 0.6875
# Epoch 14/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.0065 - accuracy: 0.8615 - val_loss: 1.3107 - val_accuracy: 0.6875
# Epoch 15/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.9469 - accuracy: 0.9231 - val_loss: 1.2989 - val_accuracy: 0.6875
# Epoch 16/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.8811 - accuracy: 0.9385 - val_loss: 1.3201 - val_accuracy: 0.6875
# Epoch 17/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.9306 - accuracy: 0.8769 - val_loss: 1.3423 - val_accuracy: 0.6875
# Epoch 18/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.8387 - accuracy: 0.9077 - val_loss: 1.2805 - val_accuracy: 0.6875
# Epoch 19/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.8042 - accuracy: 0.9385 - val_loss: 1.2678 - val_accuracy: 0.6250
# Epoch 20/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.7862 - accuracy: 0.9077 - val_loss: 1.3281 - val_accuracy: 0.6875
# Epoch 21/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.7839 - accuracy: 0.8923 - val_loss: 1.3616 - val_accuracy: 0.6250
# Epoch 22/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.7816 - accuracy: 0.8923 - val_loss: 1.3264 - val_accuracy: 0.6250
# Epoch 23/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.6839 - accuracy: 0.9385 - val_loss: 1.2580 - val_accuracy: 0.6250
# Epoch 24/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.6236 - accuracy: 0.9846 - val_loss: 1.3488 - val_accuracy: 0.6250
# Epoch 25/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.6169 - accuracy: 0.9692 - val_loss: 1.3179 - val_accuracy: 0.6250
# Epoch 26/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.5824 - accuracy: 0.9538 - val_loss: 1.2573 - val_accuracy: 0.6250
# Epoch 27/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.5842 - accuracy: 0.9692 - val_loss: 1.3620 - val_accuracy: 0.6250
# Epoch 28/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.5244 - accuracy: 0.9846 - val_loss: 1.2803 - val_accuracy: 0.5625
# Epoch 29/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.5360 - accuracy: 0.9538 - val_loss: 1.3631 - val_accuracy: 0.6250
# Epoch 30/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.4781 - accuracy: 0.9846 - val_loss: 1.3101 - val_accuracy: 0.6250
# Epoch 31/50
# 5/5 [==============================] - ETA: 0s - loss: 0.4796 - accuracy: 0.9692Restoring model weights from the end of the best epoch: 26.
# 5/5 [==============================] - 7s 1s/step - loss: 0.4796 - accuracy: 0.9692 - val_loss: 1.4206 - val_accuracy: 0.6250
# Epoch 31: early stopping
# 1/1 [==============================] - 2s 2s/step - loss: 1.2573 - accuracy: 0.6250
# Fold 5 test loss: 1.2573
# Fold 5 test accuracy: 0.6250
#
# Mean test loss across 5 folds: 1.1974 +/- 0.2663
# Mean test accuracy across 5 folds: 0.6426 +/- 0.0882

# %%
import numpy as np
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, BatchNormalization, MaxPooling1D, Dropout, Dense, Flatten
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold

# Set the random seeds for reproducibility
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

# Set the random seeds for reproducibility
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

batch_size = 16
num_folds = 10
n_epochs = 50
neurons = 256
lstm_units = 32

# Create VGG16 model
vgg_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of VGG16 model
for layer in vgg_model.layers:
    layer.trainable = False

# Define the CNN model
def create_model():
    model = Sequential()
    model.add(vgg_model)
    model.add(Flatten())
    model.add(Reshape((-1, 256)))
    #model.add(LSTM(lstm_units))
    model.add(Bidirectional(LSTM(lstm_units)))
    model.add(Dropout(0.5))
    #model.add(Dense(neurons, activation='relu'))
    model.add(Dense(neurons, activation='relu', kernel_regularizer=regularizers.l1(0.001)))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer=RMSprop(learning_rate = 0.001), metrics=['accuracy'])
    return model

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score
import numpy as np
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, BatchNormalization, MaxPooling1D, Dropout, Dense, Flatten
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold

# Set the random seeds for reproducibility
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state = 42)

#K-fold cross-validation lists
score_list = []
precision_list = []
recall_list = []
f1_score_list = []
confusion_matrix_list = []
specificity_list = []
ROC_AUC_list = []


for fold, (train_idx, val_idx) in enumerate(kfold.split(X_train, y_train)):
    #splitting the data into train and validation sets for this fold
    X_train_fold, y_train_fold = X_train[train_idx], y_train[train_idx]
    X_val_fold, y_val_fold = X_train[val_idx], y_train[val_idx]
    
    #defining the early stopping callback
    early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1)
    
    #training the model for this fold
    model = create_model()
    history = model.fit(X_train_fold, y_train_fold, epochs=n_epochs, batch_size=batch_size, 
                        validation_data=(X_val_fold, y_val_fold), callbacks=[early_stop], verbose=1)
    
    #predicting the classes for the validation set for this fold
    y_pred = model.predict(X_val_fold)
    y_pred_classes = (y_pred > 0.5).astype(int)
    
    #calculating precision, recall, specificity, F1 score, AUC, and confusion matrix for this fold
    precision_list.append(precision_score(y_val_fold, y_pred_classes))
    recall_list.append(recall_score(y_val_fold, y_pred_classes))
    f1_score_list.append(f1_score(y_val_fold, y_pred_classes))
    #tp, fp, fn, tn = confusion_matrix(y_val_fold, y_pred_classes).ravel()
    tn, fp, fn, tp = confusion_matrix(y_val_fold, y_pred_classes).ravel()
    specificity = tn / (tn + fp)
    specificity_list.append(specificity)
    ROC_AUC_list.append(roc_auc_score(y_val_fold, y_pred))
    confusion_matrix_list.append(confusion_matrix(y_val_fold, y_pred_classes))

    #evaluating the model on the test set for this fold
    #_, test_acc = model.evaluate(X_test, y_test)
    _, test_acc = model.evaluate(X_val_fold, y_val_fold)

    score_list.append(test_acc)
    
    #printing the metrics and confusion matrix for this fold
    print(f'Fold {fold + 1}: Accuracy = {test_acc:.4f}, \
      Precision = {precision_list[-1]:.4f}, \
      Recall = {recall_list[-1]:.4f}, \
      Specificity = {specificity_list[-1]:.4f}, \
      AUC = {ROC_AUC_list[-1]:.4f}, \
      F1 Score = {f1_score_list[-1]:.4f}')
    print(f'Confusion matrix:\n{confusion_matrix_list[-1]}')
    
#Print the average scores for all folds

print(f'Average Accuracy: {np.mean(score_list):.4f} +/- {np.std(score_list):.4f}')
print(f'Average Precision: {np.mean(precision_list):.4f} +/- {np.std(precision_list):.4f}')
print(f'Average Recall/Sensitivity: {np.mean(recall_list):.4f} +/- {np.std(recall_list):.4f}')
print(f'Average Specificity: {np.mean(specificity_list):.4f} +/- {np.std(specificity_list):.4f}')
print(f'Average F1-score: {np.mean(f1_score_list):.4f} +/- {np.std(f1_score_list):.4f}')
print(f'Average ROC_AUC score: {np.mean(ROC_AUC_list):.4f} +/- {np.std(ROC_AUC_list):.4f}')

#printing the overall confusion matrix

overall_cm = np.sum(confusion_matrix_list, axis=0)
print(f'Overall confusion matrix:\n{overall_cm}')
# Out:
# Epoch 1/50
# 3/3 [==============================] - 6s 1s/step - loss: 1.8677 - accuracy: 0.5556 - val_loss: 1.7181 - val_accuracy: 0.7500
# Epoch 2/50
# 3/3 [==============================] - 3s 929ms/step - loss: 1.7889 - accuracy: 0.5000 - val_loss: 1.6980 - val_accuracy: 0.7500
# Epoch 3/50
# 3/3 [==============================] - 3s 918ms/step - loss: 1.7625 - accuracy: 0.5556 - val_loss: 1.6749 - val_accuracy: 0.7500
# Epoch 4/50
# 3/3 [==============================] - 3s 936ms/step - loss: 1.6840 - accuracy: 0.6389 - val_loss: 1.6593 - val_accuracy: 0.7500
# Epoch 5/50
# 3/3 [==============================] - 3s 943ms/step - loss: 1.6390 - accuracy: 0.6389 - val_loss: 1.6347 - val_accuracy: 0.7500
# Epoch 6/50
# 3/3 [==============================] - 3s 929ms/step - loss: 1.5870 - accuracy: 0.7500 - val_loss: 1.6386 - val_accuracy: 0.5000
# Epoch 7/50
# 3/3 [==============================] - 3s 948ms/step - loss: 1.6105 - accuracy: 0.6389 - val_loss: 1.6163 - val_accuracy: 0.5000
# Epoch 8/50
# 3/3 [==============================] - 3s 946ms/step - loss: 1.5373 - accuracy: 0.7222 - val_loss: 1.5665 - val_accuracy: 0.7500
# Epoch 9/50
# 3/3 [==============================] - 3s 1s/step - loss: 1.5591 - accuracy: 0.6667 - val_loss: 1.5756 - val_accuracy: 0.7500
# Epoch 10/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.5063 - accuracy: 0.7500 - val_loss: 1.5658 - val_accuracy: 0.7500
# Epoch 11/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.3639 - accuracy: 0.8333 - val_loss: 1.5406 - val_accuracy: 0.7500
# Epoch 12/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.4226 - accuracy: 0.7778 - val_loss: 1.5140 - val_accuracy: 0.7500
# Epoch 13/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.3990 - accuracy: 0.8056 - val_loss: 1.4483 - val_accuracy: 0.7500
# Epoch 14/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.3022 - accuracy: 0.8611 - val_loss: 1.4743 - val_accuracy: 0.7500
# Epoch 15/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.2563 - accuracy: 0.9167 - val_loss: 1.4917 - val_accuracy: 0.7500
# Epoch 16/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.2273 - accuracy: 0.9167 - val_loss: 1.4655 - val_accuracy: 0.7500
# Epoch 17/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.2045 - accuracy: 0.9167 - val_loss: 1.4336 - val_accuracy: 0.5000
# Epoch 18/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.1257 - accuracy: 0.9722 - val_loss: 1.4130 - val_accuracy: 0.5000
# Epoch 19/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.2130 - accuracy: 0.8889 - val_loss: 1.3245 - val_accuracy: 0.7500
# Epoch 20/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.0551 - accuracy: 0.9722 - val_loss: 1.3277 - val_accuracy: 0.5000
# Epoch 21/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.1113 - accuracy: 0.8889 - val_loss: 1.3367 - val_accuracy: 0.5000
# Epoch 22/50
# 3/3 [==============================] - 7s 2s/step - loss: 0.9805 - accuracy: 0.9722 - val_loss: 1.3381 - val_accuracy: 0.7500
# Epoch 23/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.1306 - accuracy: 0.8889 - val_loss: 1.3903 - val_accuracy: 0.7500
# Epoch 24/50
# 3/3 [==============================] - ETA: 0s - loss: 0.9754 - accuracy: 0.9722Restoring model weights from the end of the best epoch: 19.
# 3/3 [==============================] - 7s 2s/step - loss: 0.9754 - accuracy: 0.9722 - val_loss: 1.3718 - val_accuracy: 0.7500
# Epoch 24: early stopping
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 1s 786ms/step - loss: 1.3245 - accuracy: 0.7500
# Fold 1: Accuracy = 0.7500,       Precision = 0.6667,       Recall = 1.0000,       Specificity = 0.5000,       AUC = 0.7500,       F1 Score = 0.8000
# Confusion matrix:
# [[1 1]
#  [0 2]]
# Epoch 1/50
# 3/3 [==============================] - 16s 3s/step - loss: 1.8547 - accuracy: 0.4722 - val_loss: 1.7171 - val_accuracy: 0.7500
# Epoch 2/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.7200 - accuracy: 0.5000 - val_loss: 1.6956 - val_accuracy: 0.5000
# Epoch 3/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.6458 - accuracy: 0.7500 - val_loss: 1.6595 - val_accuracy: 0.5000
# Epoch 4/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.6638 - accuracy: 0.6111 - val_loss: 1.6856 - val_accuracy: 0.5000
# Epoch 5/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.5815 - accuracy: 0.6389 - val_loss: 1.6396 - val_accuracy: 0.5000
# Epoch 6/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.5996 - accuracy: 0.6389 - val_loss: 1.6462 - val_accuracy: 0.5000
# Epoch 7/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.5642 - accuracy: 0.6111 - val_loss: 1.6346 - val_accuracy: 0.5000
# Epoch 8/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.3844 - accuracy: 0.8611 - val_loss: 1.6306 - val_accuracy: 0.5000
# Epoch 9/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.3418 - accuracy: 0.8889 - val_loss: 1.5971 - val_accuracy: 0.5000
# Epoch 10/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.3688 - accuracy: 0.7778 - val_loss: 1.6008 - val_accuracy: 0.5000
# Epoch 11/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.2951 - accuracy: 0.8611 - val_loss: 1.6022 - val_accuracy: 0.5000
# Epoch 12/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.3451 - accuracy: 0.7778 - val_loss: 1.5774 - val_accuracy: 0.5000
# Epoch 13/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.2272 - accuracy: 0.8611 - val_loss: 1.4621 - val_accuracy: 0.5000
# Epoch 14/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.1762 - accuracy: 0.9167 - val_loss: 1.4565 - val_accuracy: 0.5000
# Epoch 15/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.1787 - accuracy: 0.8889 - val_loss: 1.4963 - val_accuracy: 0.5000
# Epoch 16/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.1713 - accuracy: 0.8889 - val_loss: 1.4191 - val_accuracy: 0.7500
# Epoch 17/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.0697 - accuracy: 0.9167 - val_loss: 1.4465 - val_accuracy: 0.5000
# Epoch 18/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.0611 - accuracy: 0.8889 - val_loss: 1.3718 - val_accuracy: 0.5000
# Epoch 19/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.0458 - accuracy: 0.9167 - val_loss: 1.4653 - val_accuracy: 0.5000
# Epoch 20/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.9437 - accuracy: 0.9444 - val_loss: 1.5199 - val_accuracy: 0.5000
# Epoch 21/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.9785 - accuracy: 0.9444 - val_loss: 1.5173 - val_accuracy: 0.5000
# Epoch 22/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.9737 - accuracy: 0.8611 - val_loss: 1.6760 - val_accuracy: 0.5000
# Epoch 23/50
# 3/3 [==============================] - ETA: 0s - loss: 0.9016 - accuracy: 0.9722Restoring model weights from the end of the best epoch: 18.
# 3/3 [==============================] - 4s 1s/step - loss: 0.9016 - accuracy: 0.9722 - val_loss: 1.4942 - val_accuracy: 0.2500
# Epoch 23: early stopping
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001855C389EE8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 947ms/step
# 1/1 [==============================] - 0s 359ms/step - loss: 1.3718 - accuracy: 0.5000
# Fold 2: Accuracy = 0.5000,       Precision = 0.5000,       Recall = 0.5000,       Specificity = 0.5000,       AUC = 0.5000,       F1 Score = 0.5000
# Confusion matrix:
# [[1 1]
#  [1 1]]
# Epoch 1/50
# 3/3 [==============================] - 7s 1s/step - loss: 1.8781 - accuracy: 0.3333 - val_loss: 1.7747 - val_accuracy: 0.2500
# Epoch 2/50
# 3/3 [==============================] - 3s 1s/step - loss: 1.7256 - accuracy: 0.6667 - val_loss: 1.7514 - val_accuracy: 0.5000
# Epoch 3/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.7060 - accuracy: 0.5556 - val_loss: 1.6851 - val_accuracy: 0.7500
# Epoch 4/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.6669 - accuracy: 0.5278 - val_loss: 1.6170 - val_accuracy: 0.7500
# Epoch 5/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.6118 - accuracy: 0.5833 - val_loss: 1.5964 - val_accuracy: 0.7500
# Epoch 6/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.5472 - accuracy: 0.6667 - val_loss: 1.5804 - val_accuracy: 0.7500
# Epoch 7/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.5109 - accuracy: 0.6944 - val_loss: 1.5727 - val_accuracy: 0.7500
# Epoch 8/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.4670 - accuracy: 0.7222 - val_loss: 1.5532 - val_accuracy: 0.7500
# Epoch 9/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.4309 - accuracy: 0.8333 - val_loss: 1.5733 - val_accuracy: 0.7500
# Epoch 10/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.3617 - accuracy: 0.8611 - val_loss: 1.5521 - val_accuracy: 0.7500
# Epoch 11/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.3648 - accuracy: 0.7500 - val_loss: 1.5140 - val_accuracy: 0.7500
# Epoch 12/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.2800 - accuracy: 0.9167 - val_loss: 1.4838 - val_accuracy: 0.7500
# Epoch 13/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.3000 - accuracy: 0.8333 - val_loss: 1.4644 - val_accuracy: 0.7500
# Epoch 14/50
# 3/3 [==============================] - 3s 1s/step - loss: 1.2446 - accuracy: 0.8056 - val_loss: 1.5088 - val_accuracy: 0.7500
# Epoch 15/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.1525 - accuracy: 0.9444 - val_loss: 1.5075 - val_accuracy: 0.7500
# Epoch 16/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.1535 - accuracy: 0.8889 - val_loss: 1.4749 - val_accuracy: 0.7500
# Epoch 17/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.1070 - accuracy: 0.9444 - val_loss: 1.4365 - val_accuracy: 0.7500
# Epoch 18/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.0408 - accuracy: 0.9722 - val_loss: 1.4554 - val_accuracy: 0.7500
# Epoch 19/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.9718 - accuracy: 0.9722 - val_loss: 1.3722 - val_accuracy: 0.7500
# Epoch 20/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.0206 - accuracy: 0.9167 - val_loss: 1.3957 - val_accuracy: 0.7500
# Epoch 21/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.0035 - accuracy: 0.9722 - val_loss: 1.3742 - val_accuracy: 0.7500
# Epoch 22/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.9641 - accuracy: 0.9167 - val_loss: 1.3006 - val_accuracy: 0.7500
# Epoch 23/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.9001 - accuracy: 0.9722 - val_loss: 1.3799 - val_accuracy: 0.5000
# Epoch 24/50
# 3/3 [==============================] - 7s 2s/step - loss: 0.8591 - accuracy: 0.9722 - val_loss: 1.2878 - val_accuracy: 0.7500
# Epoch 25/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.9010 - accuracy: 0.8889 - val_loss: 1.2478 - val_accuracy: 0.7500
# Epoch 26/50
# 3/3 [==============================] - 7s 2s/step - loss: 0.8463 - accuracy: 0.9444 - val_loss: 1.2401 - val_accuracy: 0.7500
# Epoch 27/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.8328 - accuracy: 0.9444 - val_loss: 1.4125 - val_accuracy: 0.5000
# Epoch 28/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.7757 - accuracy: 1.0000 - val_loss: 1.3295 - val_accuracy: 0.5000
# Epoch 29/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.7516 - accuracy: 0.9722 - val_loss: 1.2945 - val_accuracy: 0.5000
# Epoch 30/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.6706 - accuracy: 1.0000 - val_loss: 1.2482 - val_accuracy: 0.5000
# Epoch 31/50
# 3/3 [==============================] - ETA: 0s - loss: 0.6410 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 26.
# 3/3 [==============================] - 7s 2s/step - loss: 0.6410 - accuracy: 1.0000 - val_loss: 1.2431 - val_accuracy: 0.5000
# Epoch 31: early stopping
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000018558B84798> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 691ms/step - loss: 1.2401 - accuracy: 0.7500
# Fold 3: Accuracy = 0.7500,       Precision = 1.0000,       Recall = 0.5000,       Specificity = 1.0000,       AUC = 0.7500,       F1 Score = 0.6667
# Confusion matrix:
# [[2 0]
#  [1 1]]
# Epoch 1/50
# 3/3 [==============================] - 17s 3s/step - loss: 1.7995 - accuracy: 0.5556 - val_loss: 1.8130 - val_accuracy: 0.5000
# Epoch 2/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.7708 - accuracy: 0.5278 - val_loss: 1.7908 - val_accuracy: 0.5000
# Epoch 3/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.6762 - accuracy: 0.7222 - val_loss: 1.7801 - val_accuracy: 0.5000
# Epoch 4/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.7100 - accuracy: 0.5833 - val_loss: 1.7465 - val_accuracy: 0.5000
# Epoch 5/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.5748 - accuracy: 0.6944 - val_loss: 1.7438 - val_accuracy: 0.2500
# Epoch 6/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.5512 - accuracy: 0.6944 - val_loss: 1.7386 - val_accuracy: 0.5000
# Epoch 7/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.4851 - accuracy: 0.7778 - val_loss: 1.6876 - val_accuracy: 0.5000
# Epoch 8/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.5337 - accuracy: 0.6944 - val_loss: 1.6553 - val_accuracy: 0.5000
# Epoch 9/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.4123 - accuracy: 0.8333 - val_loss: 1.6569 - val_accuracy: 0.5000
# Epoch 10/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.4305 - accuracy: 0.7500 - val_loss: 1.6558 - val_accuracy: 0.5000
# Epoch 11/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.3584 - accuracy: 0.8889 - val_loss: 1.6412 - val_accuracy: 0.5000
# Epoch 12/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.3047 - accuracy: 0.8611 - val_loss: 1.6573 - val_accuracy: 0.5000
# Epoch 13/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.2726 - accuracy: 0.8889 - val_loss: 1.6160 - val_accuracy: 0.5000
# Epoch 14/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.2945 - accuracy: 0.7500 - val_loss: 1.6103 - val_accuracy: 0.5000
# Epoch 15/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.1608 - accuracy: 0.9167 - val_loss: 1.6262 - val_accuracy: 0.5000
# Epoch 16/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.1190 - accuracy: 0.9167 - val_loss: 1.6262 - val_accuracy: 0.5000
# Epoch 17/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.1262 - accuracy: 0.9167 - val_loss: 1.6223 - val_accuracy: 0.5000
# Epoch 18/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.0401 - accuracy: 0.9444 - val_loss: 1.6372 - val_accuracy: 0.5000
# Epoch 19/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.0443 - accuracy: 0.9167 - val_loss: 1.6058 - val_accuracy: 0.2500
# Epoch 20/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.9892 - accuracy: 0.9444 - val_loss: 1.6284 - val_accuracy: 0.2500
# Epoch 21/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.0051 - accuracy: 0.9444 - val_loss: 1.6303 - val_accuracy: 0.2500
# Epoch 22/50
# 3/3 [==============================] - 7s 2s/step - loss: 0.9039 - accuracy: 0.9722 - val_loss: 1.5734 - val_accuracy: 0.2500
# Epoch 23/50
# 3/3 [==============================] - 7s 2s/step - loss: 0.8949 - accuracy: 0.9444 - val_loss: 1.5901 - val_accuracy: 0.2500
# Epoch 24/50
# 3/3 [==============================] - 7s 2s/step - loss: 0.8762 - accuracy: 0.9444 - val_loss: 1.5757 - val_accuracy: 0.5000
# Epoch 25/50
# 3/3 [==============================] - 7s 2s/step - loss: 0.8119 - accuracy: 1.0000 - val_loss: 1.5741 - val_accuracy: 0.5000
# Epoch 26/50
# 3/3 [==============================] - 7s 2s/step - loss: 0.8015 - accuracy: 0.9722 - val_loss: 1.6308 - val_accuracy: 0.2500
# Epoch 27/50
# 3/3 [==============================] - ETA: 0s - loss: 0.8234 - accuracy: 0.9167Restoring model weights from the end of the best epoch: 22.
# 3/3 [==============================] - 7s 2s/step - loss: 0.8234 - accuracy: 0.9167 - val_loss: 1.6330 - val_accuracy: 0.2500
# Epoch 27: early stopping
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 1s 731ms/step - loss: 1.5734 - accuracy: 0.2500
# Fold 4: Accuracy = 0.2500,       Precision = 0.3333,       Recall = 0.5000,       Specificity = 0.0000,       AUC = 0.5000,       F1 Score = 0.4000
# Confusion matrix:
# [[0 2]
#  [1 1]]
# Epoch 1/50
# 3/3 [==============================] - 15s 2s/step - loss: 1.8187 - accuracy: 0.5556 - val_loss: 1.7278 - val_accuracy: 0.5000
# Epoch 2/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.7736 - accuracy: 0.5278 - val_loss: 1.7268 - val_accuracy: 0.2500
# Epoch 3/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.7040 - accuracy: 0.6111 - val_loss: 1.6926 - val_accuracy: 0.2500
# Epoch 4/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.5830 - accuracy: 0.7778 - val_loss: 1.6631 - val_accuracy: 0.5000
# Epoch 5/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.6174 - accuracy: 0.6111 - val_loss: 1.5800 - val_accuracy: 0.7500
# Epoch 6/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.5712 - accuracy: 0.6111 - val_loss: 1.5481 - val_accuracy: 0.5000
# Epoch 7/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.4925 - accuracy: 0.7500 - val_loss: 1.5211 - val_accuracy: 0.5000
# Epoch 8/50
# 3/3 [==============================] - 5s 1s/step - loss: 1.5082 - accuracy: 0.7222 - val_loss: 1.4973 - val_accuracy: 0.5000
# Epoch 9/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.4870 - accuracy: 0.7222 - val_loss: 1.4446 - val_accuracy: 0.7500
# Epoch 10/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.4228 - accuracy: 0.7778 - val_loss: 1.4139 - val_accuracy: 0.7500
# Epoch 11/50
# 3/3 [==============================] - 4s 2s/step - loss: 1.3700 - accuracy: 0.7500 - val_loss: 1.4068 - val_accuracy: 0.5000
# Epoch 12/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.3397 - accuracy: 0.7500 - val_loss: 1.4185 - val_accuracy: 0.7500
# Epoch 13/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.2745 - accuracy: 0.9444 - val_loss: 1.4331 - val_accuracy: 0.5000
# Epoch 14/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.3168 - accuracy: 0.7778 - val_loss: 1.4221 - val_accuracy: 0.7500
# Epoch 15/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.1830 - accuracy: 0.9167 - val_loss: 1.4105 - val_accuracy: 0.7500
# Epoch 16/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.1946 - accuracy: 0.9167 - val_loss: 1.3559 - val_accuracy: 0.7500
# Epoch 17/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.1103 - accuracy: 0.9722 - val_loss: 1.3464 - val_accuracy: 0.5000
# Epoch 18/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.1474 - accuracy: 0.8611 - val_loss: 1.3126 - val_accuracy: 0.7500
# Epoch 19/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.0397 - accuracy: 1.0000 - val_loss: 1.3216 - val_accuracy: 0.5000
# Epoch 20/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.0471 - accuracy: 0.9444 - val_loss: 1.2426 - val_accuracy: 0.5000
# Epoch 21/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.0161 - accuracy: 0.9722 - val_loss: 1.2734 - val_accuracy: 0.5000
# Epoch 22/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.0091 - accuracy: 0.8611 - val_loss: 1.2850 - val_accuracy: 0.5000
# Epoch 23/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.9231 - accuracy: 0.9722 - val_loss: 1.2954 - val_accuracy: 0.5000
# Epoch 24/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.9146 - accuracy: 0.9722 - val_loss: 1.2253 - val_accuracy: 0.5000
# Epoch 25/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.8877 - accuracy: 0.9722 - val_loss: 1.2908 - val_accuracy: 0.5000
# Epoch 26/50
# 3/3 [==============================] - 7s 2s/step - loss: 0.8357 - accuracy: 0.9722 - val_loss: 1.2727 - val_accuracy: 0.5000
# Epoch 27/50
# 3/3 [==============================] - 7s 2s/step - loss: 0.8737 - accuracy: 0.9167 - val_loss: 1.2554 - val_accuracy: 0.5000
# Epoch 28/50
# 3/3 [==============================] - 7s 2s/step - loss: 0.7743 - accuracy: 1.0000 - val_loss: 1.2767 - val_accuracy: 0.5000
# Epoch 29/50
# 3/3 [==============================] - ETA: 0s - loss: 0.7554 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 24.
# 3/3 [==============================] - 7s 2s/step - loss: 0.7554 - accuracy: 1.0000 - val_loss: 1.2863 - val_accuracy: 0.5000
# Epoch 29: early stopping
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 1s 847ms/step - loss: 1.2253 - accuracy: 0.5000
# Fold 5: Accuracy = 0.5000,       Precision = 0.5000,       Recall = 0.5000,       Specificity = 0.5000,       AUC = 0.7500,       F1 Score = 0.5000
# Confusion matrix:
# [[1 1]
#  [1 1]]
# Epoch 1/50
# 3/3 [==============================] - 18s 3s/step - loss: 1.8344 - accuracy: 0.3889 - val_loss: 1.7931 - val_accuracy: 0.5000
# Epoch 2/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.7732 - accuracy: 0.4722 - val_loss: 1.7957 - val_accuracy: 0.5000
# Epoch 3/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.5736 - accuracy: 0.8056 - val_loss: 1.7913 - val_accuracy: 0.5000
# Epoch 4/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.6010 - accuracy: 0.6667 - val_loss: 1.7643 - val_accuracy: 0.5000
# Epoch 5/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.5108 - accuracy: 0.7778 - val_loss: 1.7918 - val_accuracy: 0.5000
# Epoch 6/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.4533 - accuracy: 0.7778 - val_loss: 1.7743 - val_accuracy: 0.2500
# Epoch 7/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.4030 - accuracy: 0.8056 - val_loss: 1.8075 - val_accuracy: 0.2500
# Epoch 8/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.4765 - accuracy: 0.7222 - val_loss: 1.8761 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 3/3 [==============================] - ETA: 0s - loss: 1.3010 - accuracy: 0.8889Restoring model weights from the end of the best epoch: 4.
# 3/3 [==============================] - 7s 2s/step - loss: 1.3010 - accuracy: 0.8889 - val_loss: 2.0184 - val_accuracy: 0.0000e+00
# Epoch 9: early stopping
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 377ms/step - loss: 1.7643 - accuracy: 0.5000
# Fold 6: Accuracy = 0.5000,       Precision = 0.5000,       Recall = 0.5000,       Specificity = 0.5000,       AUC = 0.2500,       F1 Score = 0.5000
# Confusion matrix:
# [[1 1]
#  [1 1]]
# Epoch 1/50
# 3/3 [==============================] - 8s 2s/step - loss: 1.8228 - accuracy: 0.4444 - val_loss: 1.7636 - val_accuracy: 0.5000
# Epoch 2/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.7778 - accuracy: 0.5833 - val_loss: 1.6713 - val_accuracy: 1.0000
# Epoch 3/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.6482 - accuracy: 0.6667 - val_loss: 1.6854 - val_accuracy: 0.5000
# Epoch 4/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.6460 - accuracy: 0.6111 - val_loss: 1.7066 - val_accuracy: 0.5000
# Epoch 5/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.5399 - accuracy: 0.6944 - val_loss: 1.6436 - val_accuracy: 0.2500
# Epoch 6/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.5867 - accuracy: 0.6389 - val_loss: 1.6695 - val_accuracy: 0.5000
# Epoch 7/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.5390 - accuracy: 0.6944 - val_loss: 1.6168 - val_accuracy: 0.2500
# Epoch 8/50
# 3/3 [==============================] - 5s 1s/step - loss: 1.4842 - accuracy: 0.7778 - val_loss: 1.6328 - val_accuracy: 0.2500
# Epoch 9/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.4200 - accuracy: 0.8333 - val_loss: 1.5478 - val_accuracy: 0.7500
# Epoch 10/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.3769 - accuracy: 0.8056 - val_loss: 1.5284 - val_accuracy: 0.7500
# Epoch 11/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.4515 - accuracy: 0.7778 - val_loss: 1.5323 - val_accuracy: 0.5000
# Epoch 12/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.2711 - accuracy: 0.8889 - val_loss: 1.4767 - val_accuracy: 0.5000
# Epoch 13/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.2686 - accuracy: 0.8889 - val_loss: 1.5071 - val_accuracy: 0.2500
# Epoch 14/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.2301 - accuracy: 0.8611 - val_loss: 1.5087 - val_accuracy: 0.5000
# Epoch 15/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.2241 - accuracy: 0.8611 - val_loss: 1.5208 - val_accuracy: 0.5000
# Epoch 16/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.1633 - accuracy: 0.9167 - val_loss: 1.4906 - val_accuracy: 0.5000
# Epoch 17/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.1000 - accuracy: 0.9167 - val_loss: 1.4445 - val_accuracy: 0.5000
# Epoch 18/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.1410 - accuracy: 0.8611 - val_loss: 1.4683 - val_accuracy: 0.5000
# Epoch 19/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.0461 - accuracy: 0.9167 - val_loss: 1.4390 - val_accuracy: 0.5000
# Epoch 20/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.0289 - accuracy: 0.9167 - val_loss: 1.5199 - val_accuracy: 0.5000
# Epoch 21/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.9406 - accuracy: 0.9722 - val_loss: 1.5164 - val_accuracy: 0.5000
# Epoch 22/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.9974 - accuracy: 0.9444 - val_loss: 1.5357 - val_accuracy: 0.5000
# Epoch 23/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.9499 - accuracy: 0.9722 - val_loss: 1.6116 - val_accuracy: 0.5000
# Epoch 24/50
# 3/3 [==============================] - ETA: 0s - loss: 0.9076 - accuracy: 0.9722Restoring model weights from the end of the best epoch: 19.
# 3/3 [==============================] - 4s 1s/step - loss: 0.9076 - accuracy: 0.9722 - val_loss: 1.4924 - val_accuracy: 0.5000
# Epoch 24: early stopping
# 1/1 [==============================] - 1s 932ms/step
# 1/1 [==============================] - 0s 375ms/step - loss: 1.4390 - accuracy: 0.5000
# Fold 7: Accuracy = 0.5000,       Precision = 0.5000,       Recall = 0.5000,       Specificity = 0.5000,       AUC = 0.5000,       F1 Score = 0.5000
# Confusion matrix:
# [[1 1]
#  [1 1]]
# Epoch 1/50
# 3/3 [==============================] - 7s 1s/step - loss: 1.8558 - accuracy: 0.3611 - val_loss: 1.7311 - val_accuracy: 0.7500
# Epoch 2/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.7828 - accuracy: 0.5278 - val_loss: 1.7130 - val_accuracy: 0.7500
# Epoch 3/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.7002 - accuracy: 0.4722 - val_loss: 1.6992 - val_accuracy: 0.5000
# Epoch 4/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.6463 - accuracy: 0.6111 - val_loss: 1.6723 - val_accuracy: 0.5000
# Epoch 5/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.5821 - accuracy: 0.7500 - val_loss: 1.6768 - val_accuracy: 0.5000
# Epoch 6/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.6215 - accuracy: 0.6667 - val_loss: 1.6715 - val_accuracy: 0.5000
# Epoch 7/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.5359 - accuracy: 0.7500 - val_loss: 1.6633 - val_accuracy: 0.5000
# Epoch 8/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.4447 - accuracy: 0.8333 - val_loss: 1.6197 - val_accuracy: 0.5000
# Epoch 9/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.4115 - accuracy: 0.8333 - val_loss: 1.6102 - val_accuracy: 0.5000
# Epoch 10/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.3633 - accuracy: 0.8889 - val_loss: 1.6360 - val_accuracy: 0.5000
# Epoch 11/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.3586 - accuracy: 0.7222 - val_loss: 1.6308 - val_accuracy: 0.5000
# Epoch 12/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.2427 - accuracy: 0.8889 - val_loss: 1.6094 - val_accuracy: 0.2500
# Epoch 13/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.1878 - accuracy: 0.9444 - val_loss: 1.6731 - val_accuracy: 0.2500
# Epoch 14/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.2157 - accuracy: 0.8611 - val_loss: 1.5560 - val_accuracy: 0.5000
# Epoch 15/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.1347 - accuracy: 0.9444 - val_loss: 1.5856 - val_accuracy: 0.5000
# Epoch 16/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.1400 - accuracy: 0.8889 - val_loss: 1.6286 - val_accuracy: 0.2500
# Epoch 17/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.0457 - accuracy: 0.9722 - val_loss: 1.6835 - val_accuracy: 0.2500
# Epoch 18/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.0172 - accuracy: 0.9722 - val_loss: 1.6889 - val_accuracy: 0.2500
# Epoch 19/50
# 3/3 [==============================] - ETA: 0s - loss: 1.0408 - accuracy: 0.8611Restoring model weights from the end of the best epoch: 14.
# 3/3 [==============================] - 7s 2s/step - loss: 1.0408 - accuracy: 0.8611 - val_loss: 1.6679 - val_accuracy: 0.2500
# Epoch 19: early stopping
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 1s 737ms/step - loss: 1.5560 - accuracy: 0.5000
# Fold 8: Accuracy = 0.5000,       Precision = 0.5000,       Recall = 0.5000,       Specificity = 0.5000,       AUC = 0.5000,       F1 Score = 0.5000
# Confusion matrix:
# [[1 1]
#  [1 1]]
# Epoch 1/50
# 3/3 [==============================] - 16s 2s/step - loss: 1.8943 - accuracy: 0.3889 - val_loss: 1.7174 - val_accuracy: 0.5000
# Epoch 2/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.7371 - accuracy: 0.4722 - val_loss: 1.6357 - val_accuracy: 1.0000
# Epoch 3/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.6813 - accuracy: 0.5833 - val_loss: 1.5717 - val_accuracy: 1.0000
# Epoch 4/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.6592 - accuracy: 0.5833 - val_loss: 1.5190 - val_accuracy: 1.0000
# Epoch 5/50
# 3/3 [==============================] - 6s 1s/step - loss: 1.5697 - accuracy: 0.7500 - val_loss: 1.4895 - val_accuracy: 1.0000
# Epoch 6/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.5911 - accuracy: 0.7222 - val_loss: 1.4968 - val_accuracy: 1.0000
# Epoch 7/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.4842 - accuracy: 0.7500 - val_loss: 1.4762 - val_accuracy: 0.7500
# Epoch 8/50
# 3/3 [==============================] - 8s 2s/step - loss: 1.4623 - accuracy: 0.7500 - val_loss: 1.4255 - val_accuracy: 1.0000
# Epoch 9/50
# 3/3 [==============================] - 8s 2s/step - loss: 1.4020 - accuracy: 0.7500 - val_loss: 1.4418 - val_accuracy: 1.0000
# Epoch 10/50
# 3/3 [==============================] - 8s 3s/step - loss: 1.4039 - accuracy: 0.7778 - val_loss: 1.3923 - val_accuracy: 1.0000
# Epoch 11/50
# 3/3 [==============================] - 8s 3s/step - loss: 1.2732 - accuracy: 0.8611 - val_loss: 1.3578 - val_accuracy: 1.0000
# Epoch 12/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.3369 - accuracy: 0.7778 - val_loss: 1.3361 - val_accuracy: 1.0000
# Epoch 13/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.2103 - accuracy: 0.9722 - val_loss: 1.3243 - val_accuracy: 0.7500
# Epoch 14/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.2705 - accuracy: 0.8056 - val_loss: 1.3081 - val_accuracy: 1.0000
# Epoch 15/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.1932 - accuracy: 0.8611 - val_loss: 1.2764 - val_accuracy: 1.0000
# Epoch 16/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.1787 - accuracy: 0.8056 - val_loss: 1.2236 - val_accuracy: 1.0000
# Epoch 17/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.0714 - accuracy: 0.9722 - val_loss: 1.1887 - val_accuracy: 1.0000
# Epoch 18/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.0564 - accuracy: 0.9444 - val_loss: 1.1724 - val_accuracy: 1.0000
# Epoch 19/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.0360 - accuracy: 0.9444 - val_loss: 1.1588 - val_accuracy: 1.0000
# Epoch 20/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.0121 - accuracy: 0.9444 - val_loss: 1.1141 - val_accuracy: 1.0000
# Epoch 21/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.0495 - accuracy: 0.9167 - val_loss: 1.0799 - val_accuracy: 1.0000
# Epoch 22/50
# 3/3 [==============================] - 7s 2s/step - loss: 0.9279 - accuracy: 0.9444 - val_loss: 1.0351 - val_accuracy: 1.0000
# Epoch 23/50
# 3/3 [==============================] - 7s 2s/step - loss: 0.9528 - accuracy: 0.9444 - val_loss: 0.9980 - val_accuracy: 1.0000
# Epoch 24/50
# 3/3 [==============================] - 7s 2s/step - loss: 0.9175 - accuracy: 0.9444 - val_loss: 0.9623 - val_accuracy: 1.0000
# Epoch 25/50
# 3/3 [==============================] - 7s 2s/step - loss: 0.8217 - accuracy: 1.0000 - val_loss: 0.9577 - val_accuracy: 1.0000
# Epoch 26/50
# 3/3 [==============================] - 7s 2s/step - loss: 0.8475 - accuracy: 0.9722 - val_loss: 0.9222 - val_accuracy: 1.0000
# Epoch 27/50
# 3/3 [==============================] - 7s 2s/step - loss: 0.8130 - accuracy: 0.9167 - val_loss: 0.9119 - val_accuracy: 1.0000
# Epoch 28/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.8086 - accuracy: 0.9722 - val_loss: 0.8752 - val_accuracy: 1.0000
# Epoch 29/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.7407 - accuracy: 1.0000 - val_loss: 0.8622 - val_accuracy: 1.0000
# Epoch 30/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.7824 - accuracy: 0.9722 - val_loss: 0.8124 - val_accuracy: 1.0000
# Epoch 31/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.6822 - accuracy: 1.0000 - val_loss: 0.7673 - val_accuracy: 1.0000
# Epoch 32/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.6576 - accuracy: 1.0000 - val_loss: 0.7436 - val_accuracy: 1.0000
# Epoch 33/50
# 3/3 [==============================] - 7s 2s/step - loss: 0.6788 - accuracy: 0.9722 - val_loss: 0.8020 - val_accuracy: 0.7500
# Epoch 34/50
# 3/3 [==============================] - 7s 2s/step - loss: 0.6212 - accuracy: 1.0000 - val_loss: 0.7123 - val_accuracy: 1.0000
# Epoch 35/50
# 3/3 [==============================] - 7s 2s/step - loss: 0.6091 - accuracy: 1.0000 - val_loss: 0.6854 - val_accuracy: 1.0000
# Epoch 36/50
# 3/3 [==============================] - 7s 2s/step - loss: 0.6214 - accuracy: 0.9722 - val_loss: 0.6633 - val_accuracy: 1.0000
# Epoch 37/50
# 3/3 [==============================] - 8s 2s/step - loss: 0.6178 - accuracy: 0.9722 - val_loss: 0.6055 - val_accuracy: 1.0000
# Epoch 38/50
# 3/3 [==============================] - 8s 2s/step - loss: 0.5949 - accuracy: 1.0000 - val_loss: 0.5917 - val_accuracy: 1.0000
# Epoch 39/50
# 3/3 [==============================] - 8s 3s/step - loss: 0.5724 - accuracy: 1.0000 - val_loss: 0.5764 - val_accuracy: 1.0000
# Epoch 40/50
# 3/3 [==============================] - 8s 2s/step - loss: 0.5394 - accuracy: 1.0000 - val_loss: 0.5834 - val_accuracy: 1.0000
# Epoch 41/50
# 3/3 [==============================] - 8s 2s/step - loss: 0.5293 - accuracy: 1.0000 - val_loss: 0.6044 - val_accuracy: 1.0000
# Epoch 42/50
# 3/3 [==============================] - 8s 2s/step - loss: 0.5064 - accuracy: 1.0000 - val_loss: 0.5244 - val_accuracy: 1.0000
# Epoch 43/50
# 3/3 [==============================] - 8s 3s/step - loss: 0.4801 - accuracy: 1.0000 - val_loss: 0.5230 - val_accuracy: 1.0000
# Epoch 44/50
# 3/3 [==============================] - 8s 2s/step - loss: 0.4623 - accuracy: 1.0000 - val_loss: 0.5032 - val_accuracy: 1.0000
# Epoch 45/50
# 3/3 [==============================] - 8s 3s/step - loss: 0.4479 - accuracy: 1.0000 - val_loss: 0.4908 - val_accuracy: 1.0000
# Epoch 46/50
# 3/3 [==============================] - 8s 2s/step - loss: 0.4433 - accuracy: 1.0000 - val_loss: 0.5253 - val_accuracy: 1.0000
# Epoch 47/50
# 3/3 [==============================] - 8s 2s/step - loss: 0.4121 - accuracy: 1.0000 - val_loss: 0.5131 - val_accuracy: 1.0000
# Epoch 48/50
# 3/3 [==============================] - 7s 2s/step - loss: 0.4140 - accuracy: 1.0000 - val_loss: 0.4616 - val_accuracy: 1.0000
# Epoch 49/50
# 3/3 [==============================] - 7s 2s/step - loss: 0.4103 - accuracy: 1.0000 - val_loss: 0.4735 - val_accuracy: 1.0000
# Epoch 50/50
# 3/3 [==============================] - 7s 2s/step - loss: 0.3943 - accuracy: 1.0000 - val_loss: 0.4286 - val_accuracy: 1.0000
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 849ms/step - loss: 0.4286 - accuracy: 1.0000
# Fold 9: Accuracy = 1.0000,       Precision = 1.0000,       Recall = 1.0000,       Specificity = 1.0000,       AUC = 1.0000,       F1 Score = 1.0000
# Confusion matrix:
# [[2 0]
#  [0 2]]
# Epoch 1/50
# 3/3 [==============================] - 9s 2s/step - loss: 1.8749 - accuracy: 0.5000 - val_loss: 1.8800 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 3/3 [==============================] - 5s 1s/step - loss: 1.7608 - accuracy: 0.5556 - val_loss: 1.8174 - val_accuracy: 0.5000
# Epoch 3/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.7082 - accuracy: 0.5833 - val_loss: 1.7953 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.6364 - accuracy: 0.6667 - val_loss: 1.8383 - val_accuracy: 0.5000
# Epoch 5/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.5827 - accuracy: 0.8056 - val_loss: 1.8524 - val_accuracy: 0.5000
# Epoch 6/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.5582 - accuracy: 0.6944 - val_loss: 1.8080 - val_accuracy: 0.5000
# Epoch 7/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.5034 - accuracy: 0.6389 - val_loss: 1.7914 - val_accuracy: 0.5000
# Epoch 8/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.4922 - accuracy: 0.7778 - val_loss: 1.7259 - val_accuracy: 0.5000
# Epoch 9/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.5274 - accuracy: 0.7500 - val_loss: 1.7664 - val_accuracy: 0.5000
# Epoch 10/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.5222 - accuracy: 0.6944 - val_loss: 1.6991 - val_accuracy: 0.2500
# Epoch 11/50
# 3/3 [==============================] - 5s 1s/step - loss: 1.4100 - accuracy: 0.7778 - val_loss: 1.7384 - val_accuracy: 0.5000
# Epoch 12/50
# 3/3 [==============================] - 5s 1s/step - loss: 1.3827 - accuracy: 0.8333 - val_loss: 1.7481 - val_accuracy: 0.5000
# Epoch 13/50
# 3/3 [==============================] - 4s 1s/step - loss: 1.3445 - accuracy: 0.8333 - val_loss: 1.7243 - val_accuracy: 0.5000
# Epoch 14/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.3201 - accuracy: 0.8056 - val_loss: 1.6849 - val_accuracy: 0.2500
# Epoch 15/50
# 3/3 [==============================] - 5s 1s/step - loss: 1.2813 - accuracy: 0.8333 - val_loss: 1.6776 - val_accuracy: 0.2500
# Epoch 16/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.3036 - accuracy: 0.8333 - val_loss: 1.6864 - val_accuracy: 0.5000
# Epoch 17/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.2583 - accuracy: 0.8889 - val_loss: 1.7051 - val_accuracy: 0.5000
# Epoch 18/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.1526 - accuracy: 0.9167 - val_loss: 1.6175 - val_accuracy: 0.2500
# Epoch 19/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.1324 - accuracy: 0.9167 - val_loss: 1.6025 - val_accuracy: 0.5000
# Epoch 20/50
# 3/3 [==============================] - 7s 2s/step - loss: 1.0842 - accuracy: 0.9167 - val_loss: 1.7150 - val_accuracy: 0.5000
# Epoch 21/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.0928 - accuracy: 0.9167 - val_loss: 1.7633 - val_accuracy: 0.2500
# Epoch 22/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.0219 - accuracy: 1.0000 - val_loss: 1.8284 - val_accuracy: 0.2500
# Epoch 23/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.0041 - accuracy: 0.9167 - val_loss: 1.7672 - val_accuracy: 0.2500
# Epoch 24/50
# 3/3 [==============================] - ETA: 0s - loss: 0.9296 - accuracy: 0.9722Restoring model weights from the end of the best epoch: 19.
# 3/3 [==============================] - 5s 2s/step - loss: 0.9296 - accuracy: 0.9722 - val_loss: 1.6766 - val_accuracy: 0.2500
# Epoch 24: early stopping
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 505ms/step - loss: 1.6025 - accuracy: 0.5000
# Fold 10: Accuracy = 0.5000,       Precision = 0.5000,       Recall = 0.5000,       Specificity = 0.5000,       AUC = 0.2500,       F1 Score = 0.5000
# Confusion matrix:
# [[1 1]
#  [1 1]]
# Average Accuracy: 0.5750 +/- 0.1953
# Average Precision: 0.6000 +/- 0.2134
# Average Recall/Sensitivity: 0.6000 +/- 0.2000
# Average Specificity: 0.5500 +/- 0.2693
# Average F1-score: 0.5867 +/- 0.1740
# Average ROC_AUC score: 0.5750 +/- 0.2250
# Overall confusion matrix:
# [[11  9]
#  [ 8 12]]
